# %%
import random
import helpers
import numpy as np
import pandas as pd
from copy import copy
from genetic import Experiment,Population,Chromosome,Gen
from joblib import Parallel, delayed,parallel_backend
import time
from ExperimentBase2 import ExperimentBaseModel,Transformer,CAModel
from Visualization import Visualization
import matplotlib.pyplot as plt
import math

# %%
class Experiment1(ExperimentBaseModel):
    def __init__(self,data,name,path,verbose):
        ExperimentBaseModel.__init__(self,data,name,path,verbose)
        self.mem = {}
    
    def setupChromosome(self,chromosome,goal):
        keys = list(self.domain.keys())
        keys = sorted(keys)
        for key in keys:
            if len(self.domain[key]) > 10:
                noChoices = random.randint(1,10)
            else:
                noChoices = random.randint(1,len(self.domain[key]))
            vals = set(random.choices(self.domain[key],k=noChoices))
            chromosome.genes.append(Gen(key,vals))
    
    def mutate(self,chromosome):
        if random.random() < self.mutationRate:
            index = random.randint(0,len(chromosome.genes)-1)
            identifier = chromosome.genes[index].identifier
            proportion =  len(self.domain[identifier]) - len(chromosome.genes[index].value)
            if proportion < random.random():
                val = random.choice(self.domain[identifier])
                chromosome.genes[index].value.add(val)
            else:
                if len(chromosome.genes[index].value) > 0:
                    el = random.choice(list(chromosome.genes[index].value))
                    chromosome.genes[index].value.remove(el)
    
    def crossover(self,parent1,parent2,population):
        setup = lambda x: self.setupChromosome(x,population.goal)
        crossover = lambda p1,p2: self.crossover(p1,p2,population)
        chromosome1 = Chromosome(setup,self.express,crossover,self.mutate,population.generation)
        chromosome2 = Chromosome(setup,self.express,crossover,self.mutate,population.generation)
        chromosome1.parents = [parent1,parent2]
        chromosome2.parents = [parent1,parent2]
        iGenes = list(range(len(parent1.genes)))#list(self.domain.keys())
        random.shuffle(iGenes)
        mid = len(iGenes)//2
        genes1 = [Gen(parent1.genes[x].identifier,copy(parent1.genes[x].value)) for x in iGenes[:mid]]
        genes1 += [Gen(parent2.genes[x].identifier,copy(parent2.genes[x].value)) for x in iGenes[mid:]]
        chromosome1.genes = sorted(genes1,key=lambda x: x.identifier)
        genes2 = [Gen(parent2.genes[x].identifier,copy(parent2.genes[x].value)) for x in iGenes[:mid]]
        genes2 += [Gen(parent1.genes[x].identifier,copy(parent1.genes[x].value)) for x in iGenes[mid:]]
        chromosome2.genes = sorted(genes2,key=lambda x: x.identifier)
        return [chromosome1,chromosome2]
    
    def express(self,chromosome):
        rule = "lambda summary2,goal: ["
        pos = []
        neg = []
        posMatch = []
        negMatch = []
        notZero = 0
        for gen in chromosome.genes:
            temp2 = []
            temp3 = []
            isZero = True
            for val in gen.value:
                if val != -1:
                    isZero=False
                    temp = f"summary2[{gen.identifier}][{val}][goal] if goal in summary2[{gen.identifier}][{val}] else set()"
                    temp2.append(temp)
                    for goal in self.goals:
                        if goal != -1:
                            temp3.append(f"summary2[{gen.identifier}][{val}][{goal}] if goal != {goal} and {goal} in summary2[{gen.identifier}][{val}] else set()")
            notZero += 1 if not isZero else 0
            pos.append(f"set([]).union(*[{','.join(temp2)}])")
            neg.append(f"set([]).union(*[{','.join(temp3)}])")
        rule += f"[{','.join(pos)}],[{','.join(neg)}],{notZero if notZero > 0 else 100000}"+"]"
        return rule
    
    def getTotalMatch(self,phenotype,goal):
        totalNeg = 0
        totalPos = 0
        matchProportion = eval(phenotype)
        totalPosMatch,totalNegMatch,noChromosomes = matchProportion(self.summarized2,goal)
        countPosMatch = 0
        for row in totalPosMatch:
            for col in row:
                countPosMatch += self.matrix[col][1]
        countPosMatch = countPosMatch / noChromosomes
        countNegMatch = 0
        for row in totalNegMatch:
            for col in row:
                countNegMatch += self.matrix[col][1]
        countNegMatch = countNegMatch / noChromosomes
        totalPos = self.summarized["total"][goal]
        totalNeg = self.summarized["total"]["total"]-self.summarized["total"][goal]
        totalExamples = totalNeg+totalPos
        posProp = (totalPos/totalExamples) 
        negProp = (totalNeg/totalExamples) 
        total = (countPosMatch * negProp) + (-1*countNegMatch * posProp)
        maxTotal = (totalPos * negProp)
        res = total/maxTotal
        return res
    
    def regulation(self,population):
        population.chromosomes = sorted(population.chromosomes,key = lambda x:x.fitness,reverse = True)
        mid = self.noChromosomes // 2
        indexes = [x for x in range(1,len(population.chromosomes))]
        random.shuffle(indexes)
        indexes = indexes[:self.noChromosomes]
        firstHalf = indexes[:mid]
        secondHalf = indexes[mid:]
        selected = [population.chromosomes[0]]
        selected += (np.array(population.chromosomes)[firstHalf]).tolist()
        selected += (np.array(population.chromosomes)[secondHalf]).tolist()
        population.chromosomes = selected
    
    def setup(self):
        self.radious = 1
        self.neighborhood = helpers.moore([self.radious,self.radious])
        self.mutationRate = .5
        self.noChromosomes = 25
        self.noIterations = 200
        super().setup()

# %%
class Testing1():
    def __init__(self,data,model,verbose=0):
        self.data = data
        self.model = model
        self.verbose = verbose
    
    def testRow(self,row_prev,row,row_pred):
        totalMatchDynamic = 0
        totalMatchStatic = 0
        totalStatic = 0
        totalDynamic = 0
        for cell0,cell1,cell2 in zip(row_prev,row,row_pred):
            totalMatchDynamic += (cell0 != cell1 and cell1 == cell2)
            totalMatchStatic += (cell0 == cell1 and cell1 == cell2)
            totalStatic += (cell0 == cell1)
            totalDynamic += (cell0 != cell1)
        totalStatic = totalStatic if totalStatic > 0 else 0
        totalDynamic = totalDynamic if totalDynamic > 0 else 0
        return [totalStatic,totalDynamic,totalMatchStatic,totalMatchDynamic]
            
    def run(self):
        res = []
        backend = "threading"
        with Parallel(n_jobs=4,backend=backend) as parallel:
            if self.verbose >= 1: print("Testing:")
            for i in range(1,len(data)):
                if self.verbose >= 1: print(f"state {i}/{len(data)}")
                prediction = next(model.run(data[i-1],1))
                rowsTotal = parallel(delayed(self.testRow)(row0,row1,row2) for row0,row1,row2 in zip(data[i-1],data[i],prediction[1]))
                summation = np.sum(rowsTotal,axis=0)
                if self.verbose >= 1: 
                    print(f"Static : {summation[2]}/{summation[0]}")
                    print(f"Dynamic : {summation[3]}/{summation[1]}")
                totalStatic = summation[2]/summation[0] if summation[0] > 0 else 0
                totalDynamic = summation[3]/summation[1] if summation[1] > 0 else 0
                res.append([totalStatic,totalDynamic])
        self.result = np.array(res)
    
    def plot(self):
        plt.plot(range(len(self.result)),self.result[:,0])
        plt.plot(range(len(self.result)),self.result[:,1])
        return plt

# %% [markdown]
# dataframe = pd.read_csv("data/2_square.csv")
# data  = dataframe.values
# exp = Experiment1(data,"Experiment1","path")
# exp.run()

# %%
data  = np.load("data2/data_evoloops.npy")
data = data[:,100:300,200:500]
print(np.shape(data))
train = math.floor(len(data) * 0.8)
print(np.shape(data[:train]))
exp2 = Experiment1(data[:train],"ExperimentEvoloopsGA","experimentEvoloopsGA",verbose=2)
exp2.run()
# Out:
# (600, 200, 300)
# (480, 200, 300)
# start setup
# Start 1 (200, 300)Start 2 (200, 300)
#
# Start 3 (200, 300)Start 4 (200, 300)
#
# middle 39.46842908859253
# middle 39.797054052352905
# middle 40.01493501663208
# middle 40.272425174713135
# End 4 40.439334869384766
# Start 5 (200, 300)
# End 1 41.31780409812927
# Start 6 (200, 300)
# End 3 41.66839909553528
# Start 7 (200, 300)
# End 2 41.836925983428955
# Start 8 (200, 300)
# middle 36.20329785346985
# middle 35.733893156051636
# middle 35.901100873947144
# middle 37.12481093406677
# End 6 38.281205892562866
# End 8 37.9300000667572
# Start 9 (200, 300)
# Start 10 (200, 300)
# End 7 38.227001905441284
# Start 11 (200, 300)
# End 5 39.48946785926819
# Start 12 (200, 300)
# middle 36.66026592254639
# middle 36.93061876296997
# middle 36.76968193054199middle 36.92390179634094
#
# End 10 38.828465700149536
# End 11 38.80878472328186End 12 38.72373676300049
#
# Start 13 (200, 300)
# Start 15 (200, 300)Start 14 (200, 300)
#
# End 9 39.19029784202576
# Start 16 (200, 300)
# middle 35.983012199401855
# middle 36.195215940475464
# middle 36.130393743515015
# middle 37.01328706741333
# End 14 37.92883038520813
# Start 17 (200, 300)
# End 15 38.15295696258545
# Start 18 (200, 300)
# End 16 38.235071897506714
# Start 19 (200, 300)
# End 13 38.73245692253113
# Start 20 (200, 300)
# middle 39.17876720428467
# middle 38.83273696899414
# middle 38.84056282043457
# End 19 40.2751350402832
# Start 21 (200, 300)End 17 40.84690713882446
#
# Start 22 (200, 300)
# End 20 40.35226893424988
# Start 23 (200, 300)
# middle 41.02163791656494
# End 18 41.59779381752014
# Start 24 (200, 300)
# middle 37.056718826293945
# middle 37.37824368476868
# middle 37.29072093963623
# End 23 38.454715728759766
# End 21 38.89623975753784
# Start 25 (200, 300)
# Start 26 (200, 300)
# End 22 38.98940992355347
# Start 27 (200, 300)
# middle 38.318371057510376
# End 24 38.884345054626465
# Start 28 (200, 300)
# middle 37.269816160202026
# End 27 37.83944010734558
# Start 29 (200, 300)
# middle 38.307777881622314
# middle 38.1946759223938
# middle 37.6400032043457
# End 26 39.3286509513855
# Start 30 (200, 300)
# End 25 39.74244403839111
# Start 31 (200, 300)
# End 28 38.85944199562073
# Start 32 (200, 300)
# middle 36.620051860809326
# End 29 37.201452016830444
# Start 33 (200, 300)
# middle 35.37366795539856
# End 32 35.95243787765503
# Start 34 (200, 300)
# middle 36.40907883644104
# End 31 36.972450971603394
# Start 35 (200, 300)
# middle 37.458576917648315
# End 30 38.05020594596863
# Start 36 (200, 300)
# middle 36.52430486679077
# End 33 37.08756709098816
# Start 37 (200, 300)
# middle 36.60770797729492
# End 34 37.17091202735901
# Start 38 (200, 300)
# middle 36.512434244155884
# End 35 37.07569909095764
# Start 39 (200, 300)
# middle 36.69523096084595
# End 36 37.28554177284241
# Start 40 (200, 300)
# middle 40.02505016326904
# End 37 40.60982036590576
# Start 41 (200, 300)
# middle 40.27011799812317
# End 38 40.88126301765442
# Start 42 (200, 300)middle 40.2955048084259
#
# End 39 40.869473934173584
# Start 43 (200, 300)
# middle 40.173081159591675
# End 40 40.76883006095886
# Start 44 (200, 300)
# middle 37.15032887458801
# End 41 37.74778389930725
# Start 45 (200, 300)
# middle 37.13553595542908
# End 42 37.694456815719604
# Start 46 (200, 300)
# middle 37.35037016868591
# End 43 37.93018388748169
# Start 47 (200, 300)
# middle 37.38501477241516
# End 44 37.99212193489075
# Start 48 (200, 300)
# middle 40.782164096832275
# End 45 41.397074937820435
# Start 49 (200, 300)
# middle 40.74439191818237
# End 46 41.32044696807861
# Start 50 (200, 300)
# middle 41.13510298728943
# End 47 41.70800995826721middle 40.61211180686951
#
# Start 51 (200, 300)
# End 48 41.29266095161438
# Start 52 (200, 300)
# middle 38.22159290313721
# middle 37.82323670387268
# End 49 38.87707710266113
# Start 53 (200, 300)
# End 50 38.55570101737976
# Start 54 (200, 300)
# middle 37.92606735229492
# middle 37.515172719955444
# End 51 38.77209806442261
# Start 55 (200, 300)
# End 52 38.482393741607666
# Start 56 (200, 300)
# middle 36.46174478530884middle 36.984050035476685
#
# End 53 38.007959842681885
# Start 57 (200, 300)End 54 37.614500761032104
#
# Start 58 (200, 300)
# middle 36.50568413734436
# middle 37.386171102523804
# End 56 37.158271074295044
# Start 59 (200, 300)
# End 55 38.08510780334473
# Start 60 (200, 300)
# middle 36.28155279159546
# middle 36.62889504432678
# End 57 36.986281871795654
# Start 61 (200, 300)
# End 58 37.40030097961426
# Start 62 (200, 300)
# middle 36.24706196784973
# End 60 36.850412130355835
# Start 63 (200, 300)
# middle 37.57256507873535
# End 59 38.13797187805176
# Start 64 (200, 300)
# middle 36.79395413398743
# middle 36.76167321205139
# End 61 37.43176603317261
# Start 65 (200, 300)
# End 62 37.538130044937134
# Start 66 (200, 300)
# middle 36.94961404800415
# End 63 37.562443017959595
# Start 67 (200, 300)
# middle 37.09868788719177
# End 64 37.79862308502197
# Start 68 (200, 300)
# middle 36.986310720443726
# middle 36.46513485908508
# End 65 38.05571889877319
# End 66 37.60943603515625Start 69 (200, 300)
#
# Start 70 (200, 300)
# middle 37.008800983428955
# End 67 37.615894079208374
# Start 71 (200, 300)
# middle 36.90780591964722
# End 68 37.46497368812561
# Start 72 (200, 300)
# middle 36.11591720581055
# End 70 36.72685122489929
# Start 73 (200, 300)
# middle 36.98390769958496
# End 69 37.55216574668884
# Start 74 (200, 300)
# middle 36.66271114349365
# End 71 37.260637283325195
# Start 75 (200, 300)
# middle 36.79287600517273
# End 72 37.37188100814819
# Start 76 (200, 300)
# middle 36.720584869384766
# End 73 37.334557056427
# Start 77 (200, 300)
# middle 36.76781415939331
# End 74 37.3528950214386
# Start 78 (200, 300)
# middle 36.936944246292114
# End 75 37.55085730552673
# Start 79 (200, 300)
# middle 36.85610580444336
# End 76 37.432987689971924
# Start 80 (200, 300)
# middle 39.17188286781311
# End 77 39.76403093338013
# Start 81 (200, 300)
# middle 39.181885957717896
# End 78 39.763683795928955
# Start 82 (200, 300)
# middle 39.17805814743042
# End 79 39.761327266693115
# Start 83 (200, 300)
# middle 39.186068058013916
# End 80 39.74506616592407
# Start 84 (200, 300)
# middle 39.085171937942505
# middle 38.76055693626404
# End 81 39.78433895111084
# Start 85 (200, 300)
# End 82 39.58157992362976
# Start 86 (200, 300)
# middle 39.08431529998779
# End 83 39.67600417137146
# Start 87 (200, 300)
# middle 39.210124015808105
# End 84 39.77772903442383
# Start 88 (200, 300)
# middle 37.701770067214966
# End 85 38.56594491004944
# Start 89 (200, 300)
# middle 38.21662521362305
# End 86 38.86004996299744
# Start 90 (200, 300)
# middle 38.72191095352173
# End 87 39.3304979801178
# Start 91 (200, 300)
# middle 38.67040681838989
# End 88 39.277076959609985
# Start 92 (200, 300)
# middle 44.80187392234802
# middle 44.82115411758423End 89 45.782841205596924
#
# Start 93 (200, 300)
# End 90 45.493558168411255
# Start 94 (200, 300)
# middle 44.88429284095764
# End 91 45.72970485687256
# Start 95 (200, 300)
# middle 45.2336688041687
# End 92 45.80971908569336
# Start 96 (200, 300)
# middle 43.85916614532471middle 43.21957588195801
#
# End 93 45.06830096244812
# Start 97 (200, 300)
# End 94 44.568150997161865
# Start 98 (200, 300)
# middle 42.81416893005371
# middle 43.81134796142578
# End 96 43.938457012176514
# Start 99 (200, 300)
# End 95 45.08731293678284
# Start 100 (200, 300)
# middle 43.39667892456055
# End 97 44.05205512046814
# Start 101 (200, 300)
# middle 44.26221680641174
# End 98 44.83037996292114
# Start 102 (200, 300)
# middle 43.55393719673157
# middle 43.94170022010803
# End 100 44.410913944244385
# Start 103 (200, 300)
# End 99 44.88973021507263
# Start 104 (200, 300)
# middle 42.257550954818726
# middle 43.19941186904907
# End 102 43.33032989501953
# End 101 44.33949065208435Start 105 (200, 300)
#
# Start 106 (200, 300)
# middle 42.39386010169983middle 42.14837098121643
#
# End 104 43.15944790840149
# Start 107 (200, 300)
# End 103 43.56841421127319
# Start 108 (200, 300)
# middle 38.074037075042725
# middle 38.495375871658325
# End 106 39.05439114570618
# Start 109 (200, 300)
# End 105 39.44886779785156
# Start 110 (200, 300)
# middle 38.456355810165405middle 38.58061909675598
#
# End 107 39.74080276489258
# Start 111 (200, 300)End 108 39.74134182929993
#
# Start 112 (200, 300)
# middle 40.05026197433472
# middle 40.20379590988159
# End 109 40.81005597114563
# Start 113 (200, 300)
# End 110 40.98849105834961
# Start 114 (200, 300)
# middle 39.14341902732849
# End 111 39.73612117767334
# middle 39.73134803771973Start 115 (200, 300)
#
# End 112 40.29851412773132
# Start 116 (200, 300)
# middle 36.619544982910156
# End 113 37.19448399543762
# Start 117 (200, 300)
# middle 37.150360107421875
# End 114 37.70580291748047
# Start 118 (200, 300)
# middle 36.685153007507324
# middle 36.167200803756714
# End 115 37.649720191955566
# Start 119 (200, 300)
# End 116 37.20293569564819
# Start 120 (200, 300)
# middle 40.30131196975708
# End 117 41.05977392196655
# Start 121 (200, 300)
# middle 40.43460297584534
# End 118 41.10705208778381
# Start 122 (200, 300)
# middle 40.181875228881836middle 40.32696795463562
#
# End 120 41.4453980922699End 119 41.60191512107849
#
# Start 123 (200, 300)
# Start 124 (200, 300)
# middle 48.762267112731934
# End 121 49.41575503349304
# Start 125 (200, 300)
# middle 48.849376916885376
# End 122 49.457422971725464
# Start 126 (200, 300)
# middle 48.00649809837341
# middle 48.3134491443634
# End 124 49.02740120887756
# Start 127 (200, 300)
# End 123 49.34573292732239
# Start 128 (200, 300)
# middle 39.86285376548767
# End 125 40.44425082206726
# Start 129 (200, 300)
# middle 39.71588492393494
# End 126 40.314528942108154
# Start 130 (200, 300)
# middle 39.309504985809326
# End 127 39.90142107009888
# Start 131 (200, 300)
# middle 40.32764291763306
# End 128 40.91971492767334
# Start 132 (200, 300)
# middle 42.09439516067505
# End 129 42.76275300979614
# Start 133 (200, 300)
# middle 42.18555283546448
# End 130 42.86209487915039
# Start 134 (200, 300)
# middle 42.50585603713989
# End 131 43.27402210235596
# Start 135 (200, 300)
# middle 42.597736120224
# End 132 43.25996518135071
# Start 136 (200, 300)
# middle 42.34829902648926
# End 133 42.94071698188782
# Start 137 (200, 300)
# middle 42.251112937927246
# End 134 42.8167941570282
# Start 138 (200, 300)
# middle 41.03893780708313
# middle 42.25281310081482
# End 136 42.06612515449524
# Start 139 (200, 300)
# End 135 43.398829221725464
# Start 140 (200, 300)
# middle 44.765815019607544
# End 137 45.35405111312866
# Start 141 (200, 300)
# middle 44.91656017303467
# End 138 45.4854850769043
# Start 142 (200, 300)
# middle 44.819106101989746
# middle 44.67842197418213
# End 140 45.78116726875305
# End 139 46.01703906059265Start 143 (200, 300)
#
# Start 144 (200, 300)
# middle 40.75813603401184
# End 141 41.59415102005005
# Start 145 (200, 300)
# middle 41.25134015083313
# End 142 42.090697288513184
# Start 146 (200, 300)
# middle 40.50014328956604
# End 143 41.087881326675415
# Start 147 (200, 300)
# middle 41.305639028549194
# End 144 41.89909791946411
# Start 148 (200, 300)
# middle 37.801044940948486
# End 145 38.40029716491699
# Start 149 (200, 300)
# middle 37.939717292785645
# End 146 38.49520206451416
# Start 150 (200, 300)
# middle 37.280094146728516
# End 147 37.895668268203735
# Start 151 (200, 300)
# middle 37.402191162109375
# End 148 38.01574397087097
# Start 152 (200, 300)
# middle 40.33038806915283
# End 149 40.961188077926636
# Start 153 (200, 300)
# middle 40.54481792449951
# End 150 41.165266036987305
# Start 154 (200, 300)
# middle 40.651252031326294
# End 151 41.257211208343506
# Start 155 (200, 300)
# middle 40.655144929885864
# End 152 41.302292823791504
# Start 156 (200, 300)
# middle 39.00180196762085
# End 153 39.589958906173706
# Start 157 (200, 300)
# middle 38.96881985664368
# End 154 39.57714772224426
# Start 158 (200, 300)
# middle 39.283729791641235
# End 155 39.926344871520996
# Start 159 (200, 300)
# middle 39.07322812080383
# End 156 39.684300899505615
# Start 160 (200, 300)
# middle 40.276509046554565
# End 157 40.87375211715698
# Start 161 (200, 300)
# middle 40.08687496185303
# End 158 40.681050062179565
# Start 162 (200, 300)
# middle 40.03351807594299
# End 159 40.624497175216675
# Start 163 (200, 300)
# middle 40.00888180732727
# End 160 40.60956001281738
# Start 164 (200, 300)
# middle 40.7790253162384
# End 161 41.375524282455444
# Start 165 (200, 300)
# middle 40.760138273239136
# End 162 41.43538308143616
# Start 166 (200, 300)
# middle 40.95161724090576
# middle 40.52982783317566
# End 163 41.884905099868774
# Start 167 (200, 300)
# End 164 41.43657398223877
# Start 168 (200, 300)
# middle 37.950523138046265
# End 165 38.536041021347046
# Start 169 (200, 300)
# middle 37.85470223426819
# End 166 38.500893354415894
# Start 170 (200, 300)
# middle 37.22841787338257
# End 168 37.82181477546692
# Start 171 (200, 300)
# middle 38.31351375579834
# End 167 38.90232872962952
# Start 172 (200, 300)
# middle 37.71658802032471
# End 169 38.299750328063965
# Start 173 (200, 300)
# middle 37.58238410949707
# End 170 38.16199207305908
# Start 174 (200, 300)
# middle 37.59892010688782
# End 171 38.1780469417572
# Start 175 (200, 300)
# middle 37.81422519683838
# End 172 38.3983690738678
# Start 176 (200, 300)
# middle 37.41169214248657
# End 173 37.99646592140198
# Start 177 (200, 300)
# middle 37.20958685874939
# End 174 37.779540061950684
# Start 178 (200, 300)
# middle 37.2044939994812
# End 175 37.765458822250366
# Start 179 (200, 300)
# middle 37.179301261901855
# End 176 37.79204511642456
# Start 180 (200, 300)
# middle 36.72305107116699
# End 177 37.29595923423767
# Start 181 (200, 300)
# middle 36.62700390815735
# End 178 37.19687104225159
# Start 182 (200, 300)
# middle 36.63924503326416
# End 179 37.204540967941284
# Start 183 (200, 300)
# middle 36.89954423904419
# End 180 37.67454218864441
# Start 184 (200, 300)
# middle 37.14601683616638
# End 181 37.74104189872742
# Start 185 (200, 300)
# middle 37.05443096160889
# End 182 37.885266065597534
# Start 186 (200, 300)
# middle 37.429564237594604
# End 183 38.032058000564575
# Start 187 (200, 300)
# middle 37.261427879333496
# End 184 37.81578588485718
# Start 188 (200, 300)
# middle 40.32876896858215
# End 185 41.10912799835205
# Start 189 (200, 300)
# middle 40.180622816085815
# End 186 40.77894878387451
# Start 190 (200, 300)
# middle 40.34487223625183
# End 187 40.93374800682068
# Start 191 (200, 300)
# middle 40.26105093955994
# End 188 40.93131613731384
# Start 192 (200, 300)
# middle 42.688421964645386
# End 189 43.27437901496887
# Start 193 (200, 300)
# middle 42.89514684677124
# End 190 43.51957607269287
# Start 194 (200, 300)
# middle 42.82872009277344
# End 191 43.489973068237305
# Start 195 (200, 300)
# middle 42.82161211967468
# End 192 43.44301915168762
# Start 196 (200, 300)
# middle 46.761866092681885
# End 193 47.32317900657654
# Start 197 (200, 300)
# middle 46.569870948791504
# End 194 47.14528298377991
# Start 198 (200, 300)
# middle 46.46972107887268
# End 195 47.07847499847412
# Start 199 (200, 300)
# middle 46.34473395347595
# End 196 46.9793438911438
# Start 200 (200, 300)
# middle 37.424375772476196
# End 197 38.00559997558594
# Start 201 (200, 300)
# middle 37.43008303642273
# End 198 38.00905799865723
# Start 202 (200, 300)
# middle 37.40483593940735
# End 199 37.98227000236511
# Start 203 (200, 300)
# middle 37.79773783683777
# End 200 38.54708385467529
# Start 204 (200, 300)
# middle 40.582929849624634
# End 201 41.211901903152466
# Start 205 (200, 300)
# middle 40.74486184120178
# End 202 41.45308589935303
# Start 206 (200, 300)
# middle 40.98059892654419
# End 203 41.57776379585266
# Start 207 (200, 300)
# middle 40.48155403137207
# End 204 41.08080196380615
# Start 208 (200, 300)
# middle 41.151381969451904
# End 205 41.77521300315857
# Start 209 (200, 300)
# middle 41.578428983688354
# End 206 42.189589977264404
# Start 210 (200, 300)
# middle 41.07433605194092
# End 207 41.7098491191864
# Start 211 (200, 300)
# middle 40.99490308761597
# End 208 41.619077920913696
# Start 212 (200, 300)
# middle 40.87626504898071
# End 209 41.60192084312439
# Start 213 (200, 300)
# middle 41.31547021865845
# End 210 41.9979248046875
# Start 214 (200, 300)
# middle 41.259511947631836
# End 211 41.969820976257324
# Start 215 (200, 300)
# middle 41.574962854385376
# End 212 42.2150719165802
# Start 216 (200, 300)
# middle 55.35315799713135
# End 213 55.95771288871765
# Start 217 (200, 300)
# middle 55.05498003959656
# End 214 55.65158796310425
# Start 218 (200, 300)
# middle 54.929975748062134
# End 215 55.53162384033203
# Start 219 (200, 300)
# middle 54.75676488876343
# End 216 55.40844178199768
# Start 220 (200, 300)
# middle 44.5547411441803
# End 217 45.14418888092041
# Start 221 (200, 300)
# middle 44.438891887664795
# End 218 45.02874803543091
# Start 222 (200, 300)
# middle 44.63106036186218
# End 219 45.26195931434631
# Start 223 (200, 300)
# middle 44.615031719207764
# End 220 45.20041084289551
# Start 224 (200, 300)
# middle 45.290616035461426
# End 221 45.881415128707886
# Start 225 (200, 300)
# middle 45.49654698371887
# End 222 46.09529900550842
# Start 226 (200, 300)
# middle 45.36403203010559
# End 223 45.97430419921875
# Start 227 (200, 300)
# middle 45.47420787811279
# End 224 46.07348084449768
# Start 228 (200, 300)
# middle 40.627387046813965
# End 225 41.393901109695435
# Start 229 (200, 300)
# middle 40.727481842041016
# End 226 41.33242082595825
# Start 230 (200, 300)
# middle 40.95084476470947
# End 227 41.5981559753418
# Start 231 (200, 300)
# middle 40.81954026222229
# End 228 41.432828187942505
# Start 232 (200, 300)
# middle 49.23450183868408
# End 229 49.95810389518738
# Start 233 (200, 300)
# middle 49.25729298591614
# End 230 50.0203058719635
# Start 234 (200, 300)
# middle 49.38307189941406
# End 231 50.71795606613159
# Start 235 (200, 300)
# middle 50.29879689216614
# End 232 50.92244100570679
# Start 236 (200, 300)
# middle 43.139532804489136
# End 233 43.76230192184448
# Start 237 (200, 300)
# middle 43.65484380722046
# End 234 44.241286754608154
# Start 238 (200, 300)
# middle 42.77286911010742
# End 235 43.354212045669556
# Start 239 (200, 300)
# middle 42.74761605262756
# End 236 43.35720705986023
# Start 240 (200, 300)
# middle 39.54516887664795
# End 237 40.14542007446289
# Start 241 (200, 300)
# middle 39.306111097335815
# End 238 39.92144513130188
# Start 242 (200, 300)
# middle 39.22905969619751
# End 239 39.85744786262512
# Start 243 (200, 300)
# middle 39.43140411376953
# End 240 40.03248596191406
# Start 244 (200, 300)
# middle 38.87070631980896
# End 241 39.52701115608215
# Start 245 (200, 300)
# middle 39.01132011413574
# End 242 39.616700172424316
# Start 246 (200, 300)
# middle 38.967236042022705
# End 243 39.56523585319519
# Start 247 (200, 300)
# middle 38.77822995185852
# End 244 39.54129981994629
# Start 248 (200, 300)
# middle 41.05503296852112
# End 245 41.64905309677124
# Start 249 (200, 300)
# middle 40.63387894630432
# End 246 41.29052710533142
# Start 250 (200, 300)
# middle 40.70417785644531
# End 247 41.268614768981934
# Start 251 (200, 300)
# middle 40.34120297431946
# End 248 40.936357259750366
# Start 252 (200, 300)
# middle 36.958279848098755
# End 249 37.55078601837158
# Start 253 (200, 300)
# middle 36.91494011878967
# End 250 37.63709115982056
# Start 254 (200, 300)
# middle 37.36483979225159
# End 252 38.136234998703
# Start 255 (200, 300)
# middle 39.650062084198
# End 251 40.40939998626709
# Start 256 (200, 300)
# middle 48.47077512741089
# End 253 49.12689709663391
# Start 257 (200, 300)
# middle 48.841851234436035
# End 254 49.65535616874695
# Start 258 (200, 300)
# middle 48.57764196395874
# End 255 49.46534204483032
# Start 259 (200, 300)
# middle 48.73141407966614
# End 256 49.666404008865356
# Start 260 (200, 300)
# middle 44.67944288253784
# End 257 45.63153886795044
# Start 261 (200, 300)
# middle 44.70238900184631
# End 258 45.30390024185181
# Start 262 (200, 300)
# middle 43.84582281112671
# End 259 44.55154466629028
# Start 263 (200, 300)
# middle 44.1173210144043
# End 260 44.73111033439636
# Start 264 (200, 300)
# middle 41.10737490653992
# End 261 41.71728587150574
# Start 265 (200, 300)
# middle 41.09965801239014
# End 262 41.68724489212036
# Start 266 (200, 300)
# middle 40.81537699699402
# End 263 41.40156316757202
# Start 267 (200, 300)
# middle 40.674569845199585
# End 264 41.27540993690491
# Start 268 (200, 300)
# middle 38.8503098487854
# End 265 39.46729397773743
# Start 269 (200, 300)
# middle 38.586689949035645
# End 266 39.245115995407104
# Start 270 (200, 300)
# middle 38.67393779754639
# End 267 39.27871894836426
# Start 271 (200, 300)
# middle 38.77930688858032
# End 268 39.39829993247986
# Start 272 (200, 300)
# middle 39.90095782279968
# End 269 40.674792766571045
# Start 273 (200, 300)
# middle 40.1416380405426
# End 270 40.73418402671814
# Start 274 (200, 300)
# middle 40.31037092208862
# End 271 40.913480043411255
# Start 275 (200, 300)
# middle 40.29157519340515
# End 272 40.904468297958374
# Start 276 (200, 300)
# middle 39.83328104019165
# End 273 40.45796084403992
# Start 277 (200, 300)
# middle 40.178622245788574
# End 274 40.8296000957489
# Start 278 (200, 300)
# middle 40.21288824081421
# End 275 40.82327103614807
# Start 279 (200, 300)
# middle 40.29777693748474
# End 276 40.90005111694336
# Start 280 (200, 300)
# middle 39.99376201629639
# End 277 40.604629039764404
# Start 281 (200, 300)
# middle 39.54650807380676
# End 278 40.190144062042236
# Start 282 (200, 300)
# middle 39.18940281867981
# End 279 39.809157848358154
# Start 283 (200, 300)
# middle 39.32341814041138
# End 280 40.059327125549316
# Start 284 (200, 300)
# middle 42.02051568031311
# End 281 42.795283794403076
# Start 285 (200, 300)
# middle 42.48691391944885
# End 282 43.163573026657104
# Start 286 (200, 300)
# middle 42.80118012428284
# End 283 43.8758499622345
# Start 287 (200, 300)
# middle 43.45543193817139
# End 284 44.02771306037903
# Start 288 (200, 300)
# middle 38.22992205619812
# End 285 38.823344230651855
# Start 289 (200, 300)
# middle 37.585445165634155
# End 286 38.15992498397827
# Start 290 (200, 300)
# middle 36.811614990234375
# End 287 37.377299070358276
# Start 291 (200, 300)
# middle 36.504756927490234
# End 288 37.07226490974426
# Start 292 (200, 300)
# middle 37.141108989715576middle 38.520384073257446
#
# End 289 39.49647903442383
# Start 293 (200, 300)
# End 290 38.31203579902649
# Start 294 (200, 300)
# middle 37.66029906272888
# End 291 38.25057625770569
# Start 295 (200, 300)
# middle 37.856868267059326
# End 292 38.4572491645813
# Start 296 (200, 300)
# middle 37.93962788581848middle 37.813005208969116
#
# End 293 38.981318950653076
# Start 297 (200, 300)
# End 294 38.98926401138306
# Start 298 (200, 300)
# middle 38.38802695274353
# End 295 38.95833897590637
# Start 299 (200, 300)
# middle 38.35008478164673
# End 296 38.96406888961792
# Start 300 (200, 300)
# middle 37.75427198410034
# End 298 38.350120306015015
# Start 301 (200, 300)
# middle 38.75970506668091
# End 297 39.44120407104492
# Start 302 (200, 300)
# middle 38.55065321922302
# End 299 39.14379096031189
# Start 303 (200, 300)
# middle 38.642653942108154
# End 300 39.2283411026001
# Start 304 (200, 300)
# middle 38.21387004852295
# End 301 38.82194185256958
# Start 305 (200, 300)
# middle 38.258827924728394
# End 302 39.192280769348145
# Start 306 (200, 300)
# middle 38.60451126098633
# End 303 39.224934101104736
# Start 307 (200, 300)
# middle 38.95857310295105
# End 304 39.80046486854553
# Start 308 (200, 300)
# middle 40.247408866882324
# End 305 40.921722650527954
# Start 309 (200, 300)
# middle 39.77912402153015
# End 306 40.382169246673584
# Start 310 (200, 300)
# middle 39.966378927230835
# End 307 40.53958010673523
# Start 311 (200, 300)
# middle 39.27158498764038
# End 308 39.85550093650818
# Start 312 (200, 300)
# middle 38.05238080024719
# End 309 38.66168689727783
# Start 313 (200, 300)
# middle 38.04920816421509
# End 310 38.649924993515015
# Start 314 (200, 300)
# middle 38.17241168022156
# End 311 38.74694776535034
# Start 315 (200, 300)
# middle 38.50097727775574
# End 312 39.09418821334839
# Start 316 (200, 300)
# middle 43.4679160118103middle 44.24597907066345
#
# End 314 44.5493860244751
# Start 317 (200, 300)
# End 313 45.487602949142456
# Start 318 (200, 300)
# middle 43.93495297431946
# End 315 44.4998140335083
# Start 319 (200, 300)
# middle 43.78118395805359
# End 316 44.37263107299805
# Start 320 (200, 300)
# middle 36.63559174537659middle 36.76205515861511
#
# End 318 37.72533082962036End 317 37.865947246551514
#
# Start 322 (200, 300)Start 321 (200, 300)
#
# middle 37.13820791244507
# End 319 37.73375582695007
# Start 323 (200, 300)
# middle 37.22831678390503
# End 320 37.872782707214355
# Start 324 (200, 300)
# middle 36.5112681388855middle 36.5113410949707
#
# End 321 37.54423785209656
# Start 325 (200, 300)End 322 37.682976961135864
#
# Start 326 (200, 300)
# middle 36.98526191711426
# End 323 37.5761079788208
# Start 327 (200, 300)
# middle 36.93066692352295
# End 324 37.74104189872742
# Start 328 (200, 300)
# middle 37.3341281414032
# End 325 38.06575894355774
# Start 329 (200, 300)
# middle 38.46890377998352
# middle 37.29332494735718
# End 327 38.34355187416077
# End 326 39.659663677215576Start 330 (200, 300)
#
# Start 331 (200, 300)
# middle 38.36989688873291
# End 328 38.97764468193054
# Start 332 (200, 300)
# middle 38.6223258972168
# End 329 39.57462978363037
# Start 333 (200, 300)
# middle 38.396427154541016
# End 331 38.991894006729126
# Start 334 (200, 300)
# middle 39.67178273200989
# End 330 40.281341791152954
# Start 335 (200, 300)
# middle 39.159223794937134
# End 332 39.801865100860596
# Start 336 (200, 300)
# middle 39.76339411735535
# End 333 40.97819709777832
# Start 337 (200, 300)
# middle 40.94473600387573
# End 334 41.57274293899536
# Start 338 (200, 300)
# middle 41.61069416999817
# End 335 42.23965120315552
# Start 339 (200, 300)
# middle 41.723631143569946
# End 336 42.30904006958008
# Start 340 (200, 300)
# middle 39.06801199913025
# End 337 39.62780523300171
# Start 341 (200, 300)
# middle 38.92891812324524
# End 338 39.50395607948303
# Start 342 (200, 300)
# middle 38.618557929992676
# End 339 39.200034618377686
# Start 343 (200, 300)
# middle 37.906079053878784
# End 340 38.50943207740784
# Start 344 (200, 300)
# middle 37.75148797035217
# End 341 38.465779066085815
# Start 345 (200, 300)
# middle 37.60688018798828
# End 342 38.191161155700684
# Start 346 (200, 300)
# middle 37.61212205886841
# End 343 38.198837995529175
# Start 347 (200, 300)
# middle 37.60656785964966
# End 344 38.185023069381714
# Start 348 (200, 300)
# middle 36.973994970321655
# End 345 37.52915906906128
# Start 349 (200, 300)
# middle 36.94001531600952
# End 346 37.51582908630371
# Start 350 (200, 300)
# middle 37.03129172325134
# End 347 37.70817685127258
# Start 351 (200, 300)
# middle 37.11950206756592
# End 348 37.70255517959595
# Start 352 (200, 300)
# middle 36.69523477554321
# End 349 37.29162287712097
# Start 353 (200, 300)
# middle 36.719701051712036
# End 350 37.31811189651489
# Start 354 (200, 300)
# middle 36.63441276550293
# End 351 37.30843186378479
# Start 355 (200, 300)
# middle 36.7482807636261
# End 352 37.329147815704346
# Start 356 (200, 300)
# middle 38.04377222061157
# middle 39.45764493942261
# End 354 38.94323205947876
# Start 357 (200, 300)
# End 353 40.473532915115356
# Start 358 (200, 300)
# middle 38.49144101142883
# End 355 39.08421206474304
# Start 359 (200, 300)
# middle 38.487557888031006
# End 356 39.06943202018738
# Start 360 (200, 300)
# middle 36.79110026359558
# End 357 37.37334132194519
# Start 361 (200, 300)
# middle 37.383816957473755
# End 358 37.961623668670654
# Start 362 (200, 300)
# middle 37.15806603431702
# End 359 37.83508491516113
# Start 363 (200, 300)
# middle 37.16189694404602
# End 360 37.740598917007446
# Start 364 (200, 300)
# middle 38.081565380096436
# End 361 38.879953145980835
# Start 365 (200, 300)
# middle 38.31251287460327
# End 362 38.899446964263916
# Start 366 (200, 300)
# middle 38.32522702217102
# End 363 38.91836619377136
# Start 367 (200, 300)
# middle 38.23299717903137
# End 364 38.813446283340454
# Start 368 (200, 300)
# middle 43.17816686630249
# End 365 43.87205672264099
# Start 369 (200, 300)
# middle 43.69083213806152
# End 366 44.2773220539093
# Start 370 (200, 300)
# middle 43.698310136795044
# End 367 44.35593390464783
# Start 371 (200, 300)
# middle 43.99008011817932
# End 368 44.625078201293945
# Start 372 (200, 300)
# middle 40.84925603866577
# End 369 41.475579261779785
# Start 373 (200, 300)
# middle 40.914079904556274
# End 370 41.49090099334717
# Start 374 (200, 300)
# middle 40.63534116744995
# End 371 41.21414113044739
# Start 375 (200, 300)
# middle 40.67593026161194
# End 372 41.25724816322327
# Start 376 (200, 300)
# middle 38.27238202095032
# middle 37.39182710647583
# End 373 39.12263035774231
# Start 377 (200, 300)
# End 374 38.28528809547424
# Start 378 (200, 300)
# middle 37.70617890357971
# End 375 38.33872985839844
# Start 379 (200, 300)
# middle 37.7525098323822
# End 376 38.33676314353943
# Start 380 (200, 300)
# middle 39.96892213821411
# middle 40.33527612686157
# End 378 41.15757393836975End 377 41.47900915145874
#
# Start 381 (200, 300)
# Start 382 (200, 300)
# middle 40.50520205497742
# End 379 41.08946204185486
# Start 383 (200, 300)
# middle 40.993805170059204
# End 380 41.56610107421875
# Start 384 (200, 300)
# middle 39.37057399749756
# middle 39.40952706336975
# End 382 40.50085401535034
# End 381 40.60498785972595
# Start 385 (200, 300)Start 386 (200, 300)
#
# middle 40.79508924484253
# End 383 41.4909770488739
# Start 387 (200, 300)
# middle 40.63346195220947
# End 384 41.374523878097534
# Start 388 (200, 300)
# middle 42.32824182510376
# middle 42.44489908218384
# End 386 43.318042039871216
# Start 389 (200, 300)
# End 385 43.51849174499512
# Start 390 (200, 300)
# middle 42.43000292778015
# End 387 43.122254848480225
# Start 391 (200, 300)
# middle 42.05584907531738
# End 388 42.64940285682678
# Start 392 (200, 300)
# middle 36.48637318611145
# End 389 37.06834530830383
# Start 393 (200, 300)
# middle 37.11950492858887
# End 390 37.791553020477295
# Start 394 (200, 300)
# middle 36.89851403236389
# End 391 37.45640802383423
# Start 395 (200, 300)
# middle 37.17013692855835
# End 392 37.824110984802246
# Start 396 (200, 300)
# middle 36.26391100883484
# End 393 36.83860993385315
# Start 397 (200, 300)
# middle 36.471550941467285
# End 394 37.07424306869507
# Start 398 (200, 300)
# middle 36.21186017990112
# End 395 36.77863812446594
# Start 399 (200, 300)
# middle 36.84431004524231
# End 396 37.686481952667236
# Start 400 (200, 300)
# middle 42.61687994003296
# End 397 43.25045585632324
# Start 401 (200, 300)
# middle 42.450446128845215
# End 398 43.02859687805176
# Start 402 (200, 300)
# middle 42.384077072143555
# End 399 43.079211950302124
# Start 403 (200, 300)
# middle 42.56196618080139
# End 400 43.135539054870605
# Start 404 (200, 300)
# middle 37.3914589881897
# End 401 37.97051191329956
# Start 405 (200, 300)
# middle 37.77739071846008
# End 402 38.413949966430664
# Start 406 (200, 300)
# middle 37.69330406188965
# End 403 38.27910089492798
# Start 407 (200, 300)
# middle 37.04835510253906
# End 404 37.60438919067383
# Start 408 (200, 300)
# middle 36.92025303840637
# End 405 37.49286723136902
# Start 409 (200, 300)
# middle 36.57875919342041
# End 406 37.1537561416626
# Start 410 (200, 300)
# middle 36.67407488822937
# End 407 37.76802396774292
# Start 411 (200, 300)
# middle 37.234371185302734
# End 408 37.86380696296692
# Start 412 (200, 300)
# middle 39.266478061676025
# End 409 39.883185148239136
# Start 413 (200, 300)
# middle 39.305315017700195
# End 410 39.96052384376526
# Start 414 (200, 300)
# middle 39.09947896003723
# End 411 39.719637870788574
# Start 415 (200, 300)
# middle 39.64060306549072
# End 412 40.2719521522522
# Start 416 (200, 300)
# middle 39.046128273010254
# End 413 39.64763021469116
# Start 417 (200, 300)
# middle 38.99641966819763
# End 414 39.599082946777344
# Start 418 (200, 300)
# middle 39.148273944854736
# End 415 39.716816902160645
# Start 419 (200, 300)
# middle 38.60812497138977
# End 416 39.20791506767273
# Start 420 (200, 300)
# middle 53.143091917037964
# End 417 53.753007888793945
# Start 421 (200, 300)
# middle 53.05804991722107
# End 418 53.64838910102844
# Start 422 (200, 300)
# middle 53.09846210479736
# End 419 53.70611906051636
# Start 423 (200, 300)
# middle 53.03559231758118
# End 420 53.61280012130737
# Start 424 (200, 300)
# middle 39.87062692642212
# End 421 40.47603988647461
# Start 425 (200, 300)
# middle 39.98368000984192
# End 422 40.64516019821167
# Start 426 (200, 300)
# middle 39.940678119659424
# End 423 40.649877071380615
# Start 427 (200, 300)
# middle 40.166457653045654
# End 424 40.772419691085815
# Start 428 (200, 300)
# middle 40.81650519371033
# End 425 41.40314435958862
# Start 429 (200, 300)
# middle 40.733187198638916
# End 426 41.38205814361572
# Start 430 (200, 300)
# middle 40.80763792991638
# End 427 42.094191789627075
# Start 431 (200, 300)
# middle 42.24229621887207
# End 428 43.05507516860962
# Start 432 (200, 300)
# middle 49.38302493095398
# End 429 50.24768590927124
# Start 433 (200, 300)
# middle 49.47569704055786
# End 430 50.441285848617554
# Start 434 (200, 300)
# middle 49.45435810089111
# End 431 50.43710803985596
# Start 435 (200, 300)
# middle 49.993321895599365
# End 432 51.10678291320801
# Start 436 (200, 300)
# middle 44.576732873916626
# End 433 45.199836015701294
# Start 437 (200, 300)
# middle 44.345603227615356
# End 434 44.9769082069397
# Start 438 (200, 300)
# middle 43.97284698486328
# End 435 44.56643605232239
# Start 439 (200, 300)
# middle 42.69771122932434
# End 436 43.75863313674927
# Start 440 (200, 300)
# middle 44.61851716041565
# End 437 45.42197513580322
# Start 441 (200, 300)
# middle 45.35705280303955
# End 438 46.17133975028992
# Start 442 (200, 300)
# middle 45.645628929138184
# End 439 46.26369905471802
# Start 443 (200, 300)
# middle 45.41960072517395
# End 440 46.013996839523315
# Start 444 (200, 300)
# middle 46.1200909614563
# End 441 47.15278172492981
# Start 445 (200, 300)
# middle 46.62925314903259
# End 442 47.65714192390442
# Start 446 (200, 300)
# middle 46.2085177898407
# End 443 47.02307891845703
# Start 447 (200, 300)
# middle 46.635558128356934
# End 444 47.20635795593262
# Start 448 (200, 300)
# middle 43.77281427383423
# End 445 44.45908784866333
# Start 449 (200, 300)
# middle 43.30218005180359
# End 446 43.90872311592102
# Start 450 (200, 300)
# middle 43.20218276977539
# End 447 43.87458777427673
# Start 451 (200, 300)
# middle 42.86500000953674
# End 448 43.4464898109436
# Start 452 (200, 300)
# middle 41.32771396636963
# End 449 42.02104306221008
# Start 453 (200, 300)
# middle 41.61763000488281
# End 450 42.24694299697876
# Start 454 (200, 300)
# middle 41.354068994522095
# End 451 42.20291590690613
# Start 455 (200, 300)
# middle 41.96868896484375
# End 452 42.55300998687744
# Start 456 (200, 300)
# middle 40.405277967453
# End 453 41.04817223548889
# Start 457 (200, 300)
# middle 40.11596393585205
# End 454 40.8304181098938
# Start 458 (200, 300)
# middle 39.97346091270447
# End 455 40.59565210342407
# Start 459 (200, 300)
# middle 40.08775997161865
# End 456 40.794739961624146
# Start 460 (200, 300)
# middle 41.139435052871704
# End 457 41.85685086250305
# Start 461 (200, 300)
# middle 41.04318118095398
# End 458 41.662577867507935
# Start 462 (200, 300)
# middle 41.24167990684509
# End 459 42.05076599121094
# Start 463 (200, 300)
# middle 40.84800696372986
# End 460 41.42146706581116
# Start 464 (200, 300)
# middle 40.4659628868103
# End 461 41.09018278121948
# Start 465 (200, 300)
# middle 40.45940566062927
# End 462 41.07149386405945
# Start 466 (200, 300)
# middle 40.33963704109192
# End 463 40.94932699203491
# Start 467 (200, 300)
# middle 40.60868501663208
# End 464 41.22393298149109
# Start 468 (200, 300)
# middle 50.55675268173218
# End 465 53.60055494308472
# Start 469 (200, 300)
# middle 52.68457508087158
# middle 53.760966062545776
# End 466 56.28436207771301
# Start 470 (200, 300)
# End 467 56.08791208267212
# Start 471 (200, 300)
# middle 56.74018120765686
# End 468 57.712459087371826
# Start 472 (200, 300)
# middle 56.87637400627136
# End 469 57.62714719772339
# Start 473 (200, 300)
# middle 54.90793180465698
# middle 53.96487593650818
# End 470 55.99653387069702
# Start 474 (200, 300)End 471 55.17730689048767
#
# Start 475 (200, 300)
# middle 52.977516889572144
# End 472 53.73886203765869
# Start 476 (200, 300)
# middle 42.51709794998169
# End 473 43.09380602836609
# Start 477 (200, 300)
# middle 41.42399191856384
# middle 41.52422285079956
# End 474 42.569546937942505End 475 42.49746489524841
#
# Start 478 (200, 300)Start 479 (200, 300)
#
# middle 41.61275601387024
# End 476 42.168115854263306
# middle 2334.9470942020416
# End 477 2336.059118270874
# middle 2335.178689956665middle 2335.179267883301
#
# End 478 2336.900205850601End 479 2336.9178528785706
#
# 7261.224633693695
# (1046, 3)
# 7261.717015743256
# 7261.859200000763
# 7262.161404848099
# 8 goals
# end setup
# config saved at experimentEvoloopsGA/17_01_20_16_04_15/config.json
# iteration 1
# goal = 0goal = 76goal = 105goal = 149
#
#
#
# goal 149 elapsed time: 5.119623184204102goal 76 elapsed time: 5.180994033813477
#
# goal = 29goal = 255
#
# goal 0 elapsed time: 5.279836893081665goal 105 elapsed time: 5.265994071960449
#
# goal = 178
# goal = 225
# goal 178 elapsed time: 3.0341310501098633goal 29 elapsed time: 3.085157871246338
#
# goal 255 elapsed time: 3.1409189701080322
# goal 225 elapsed time: 3.1385111808776855
# {'generation': 1, 'elapsedTime': 8.563614845275879, 'fitness': {0: [0.05135935859954564, 0.04075640350926596, 0.2325586511812758], 76: [0.11444551140941085, 0.05015211895787484, 0.5685474793234986], 105: [0.06641953595429798, 0.1219691042018147, 0.2622465922385602], 149: [0.03430055056594094, 0.07686251469071957, 0.4630899606137269], 29: [0.05136287538194268, 0.028115475963475387, 0.3783562412661624], 255: [0.09821264831673203, -0.04046512050889578, 0.45030635888711407], 178: [0.025820113036698886, 0.025129509261334063, 0.28965898119138084], 225: [0.1051340803934451, 0.2966523474050384, 0.41070709356629076]}}
# iteration 2
# goal = 0
# goal = 76
# goal = 105goal = 149
#
# goal 76 elapsed time: 0.6226241588592529goal 105 elapsed time: 0.6255311965942383goal 149 elapsed time: 0.626378059387207
#
# goal = 29
#
# goal = 255goal 0 elapsed time: 0.6478118896484375
# goal = 178
# goal = 225
#
# goal 178 elapsed time: 0.5814778804779053goal 29 elapsed time: 0.6023118495941162
#
# goal 225 elapsed time: 0.7294049263000488
# goal 255 elapsed time: 0.7681410312652588
# {'generation': 2, 'elapsedTime': 1.4967410564422607, 'fitness': {0: [0.06993305768451673, 0.06470689997211074, 0.25123275449971266], 76: [0.16513693301169202, 0.2103767822190321, 0.5685474793234986], 105: [0.1013438953108184, 0.09297123265625307, 0.306409452469526], 149: [0.08972917787401388, 0.053795730279319165, 0.46314573210318866], 29: [0.082708647771618, 0.032741714244101605, 0.5134115919555411], 255: [0.14420985219479424, -0.028432448423659704, 0.5775666252522871], 178: [0.05784758105774464, 0.04107052926401457, 0.305102983160953], 225: [0.1321024283417593, 0.15795257286739203, 0.41070709356629076]}}
# iteration 3
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 105 elapsed time: 1.579653024673462goal 0 elapsed time: 1.6108908653259277goal 76 elapsed time: 1.6131768226623535
#
# goal = 29goal = 255
#
#
# goal = 178
# goal 149 elapsed time: 1.668895959854126
# goal = 225
# goal 178 elapsed time: 0.6388940811157227goal 29 elapsed time: 0.6725478172302246goal 225 elapsed time: 0.6346580982208252
# goal 255 elapsed time: 0.6750087738037109
#
#
# {'generation': 3, 'elapsedTime': 2.329885959625244, 'fitness': {0: [0.08559940006301045, 0.04282258675955413, 0.3004512851051405], 76: [0.21078389223864294, 0.299563726133311, 0.5685474793234986], 105: [0.11850633248009214, 0.10630285238946044, 0.3679484626905073], 149: [0.12011149071965486, -0.18160597600433517, 0.5856925368374266], 29: [0.10497002614715399, 0.22499878671966717, 0.5134115919555411], 255: [0.2231753381978402, 0.10585768743728635, 0.6030277196179391], 178: [0.05236940235006952, 0.05662232340522163, 0.3567289977080665], 225: [0.15399878787777393, 0.16098569964380005, 0.5993073115217551]}}
# iteration 4
# goal = 0goal = 76
# goal = 105
#
# goal = 149
# goal 0 elapsed time: 0.5503890514373779
# goal = 29
# goal 76 elapsed time: 0.6800739765167236
# goal 105 elapsed time: 0.7076728343963623goal = 255
# goal = 178
#
# goal 149 elapsed time: 0.742419958114624
# goal = 225
# goal 29 elapsed time: 0.6731100082397461goal 178 elapsed time: 0.6324210166931152
#
# goal 255 elapsed time: 0.7260138988494873
# goal 225 elapsed time: 0.7023999691009521
# {'generation': 4, 'elapsedTime': 1.482353925704956, 'fitness': {0: [0.10027348813833149, 0.09250444910820964, 0.3004512851051405], 76: [0.2567604978269251, 0.22036533584641887, 0.5685474793234986], 105: [0.14837683946820235, 0.043154668673994714, 0.3679484626905073], 149: [0.18278834587420734, 0.2894642362445333, 0.5856925368374266], 29: [0.13010638530404706, 0.25061542479206217, 0.5134115919555411], 255: [0.2738092119127938, 0.4288523680937045, 0.6835163697769457], 178: [0.07948326819681449, 0.06419008621438246, 0.3567289977080665], 225: [0.25178241724057515, 0.39579637115845756, 0.5993073115217551]}}
# iteration 5
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 0 elapsed time: 0.8911349773406982goal 76 elapsed time: 0.9049968719482422
#
# goal = 29
# goal = 255goal 105 elapsed time: 0.9645440578460693
#
# goal 149 elapsed time: 1.0024769306182861
# goal = 178goal = 225
#
# goal 255 elapsed time: 0.4241306781768799
# goal 225 elapsed time: 0.5901248455047607
# goal 178 elapsed time: 0.6207408905029297goal 29 elapsed time: 0.7118139266967773
#
# {'generation': 5, 'elapsedTime': 1.6518301963806152, 'fitness': {0: [0.13302520879959598, 0.09751761958567368, 0.36621537478579147], 76: [0.3070500323275049, 0.2851320536382286, 0.5685474793234986], 105: [0.18839315194419576, 0.18826022965846997, 0.37473257824429873], 149: [0.244515319429383, 0.27132123485604404, 0.5970015710814266], 29: [0.1753514612251496, 0.10186910578168339, 0.5237482621967718], 255: [0.29038397405169075, 0.14621039727220467, 0.6861959551326381], 178: [0.12953048407690052, 0.1570912444656966, 0.3567289977080665], 225: [0.3001488054053245, 0.2166548919738963, 0.7306292858127715]}}
# iteration 6
# goal = 0
# goal = 76goal = 105
#
# goal = 149
# goal 76 elapsed time: 0.6780598163604736goal 0 elapsed time: 0.6919419765472412
#
# goal = 29
# goal 149 elapsed time: 0.7227580547332764goal = 255
# goal = 178
# goal 105 elapsed time: 0.7347989082336426
#
# goal = 225
# goal 225 elapsed time: 0.63720703125goal 255 elapsed time: 0.6683530807495117goal 29 elapsed time: 0.7069180011749268
#
#
# goal 178 elapsed time: 0.7042009830474854
# {'generation': 6, 'elapsedTime': 1.5284101963043213, 'fitness': {0: [0.1601581602907694, 0.28963460838523514, 0.36621537478579147], 76: [0.3679981329959446, 0.3303748751638933, 0.5714523888326846], 105: [0.21422377136155732, 0.12226732999369816, 0.3857421032058686], 149: [0.2879359001002222, 0.25643903250568645, 0.6237896373951431], 29: [0.2625201113944249, 0.22586535266958996, 0.5237482621967718], 255: [0.334666050536471, 0.3009387528965237, 0.6861959551326381], 178: [0.17615288172174243, 0.14860887449394158, 0.3673585715613884], 225: [0.3520547369948031, 0.4003104099678941, 0.7306292858127715]}}
# iteration 7
# goal = 0goal = 76
# goal = 105goal = 149
#
#
# goal 0 elapsed time: 0.9338288307189941goal 149 elapsed time: 0.952725887298584
#
# goal = 29goal = 255goal 105 elapsed time: 0.9991490840911865
#
#
# goal = 178
# goal 76 elapsed time: 1.0075700283050537
# goal = 225
# goal 255 elapsed time: 0.5855281352996826
# goal 225 elapsed time: 0.6113510131835938
# goal 178 elapsed time: 0.6606237888336182
# goal 29 elapsed time: 0.7149851322174072
# {'generation': 7, 'elapsedTime': 1.7217490673065186, 'fitness': {0: [0.19216034483054606, 0.020265758384187357, 0.36621537478579147], 76: [0.42068312111554584, 0.3531335672049236, 0.635596531615932], 105: [0.2652119543771087, 0.21190490588341457, 0.4148525207392273], 149: [0.31276656339522696, 0.3520243605838888, 0.6237896373951431], 29: [0.285646574881828, 0.5104178758606901, 0.6263980941997694], 255: [0.3827337664417247, 0.37399934234087195, 0.6861959551326381], 178: [0.23779849365803418, 0.294308914745323, 0.39732093299972765], 225: [0.365816546547069, 0.4378073209264153, 0.7306292858127715]}}
# iteration 8
# goal = 0goal = 76
# goal = 105goal = 149
#
#
# goal 76 elapsed time: 0.6916790008544922goal 105 elapsed time: 0.6954691410064697goal 0 elapsed time: 0.6977453231811523
#
#
# goal = 29
# goal = 255
# goal = 178
# goal 149 elapsed time: 0.7412412166595459
# goal = 225
# goal 225 elapsed time: 0.5709590911865234goal 255 elapsed time: 0.6074681282043457
#
# goal 178 elapsed time: 0.6158981323242188
# goal 29 elapsed time: 0.6716055870056152
# {'generation': 8, 'elapsedTime': 1.4661409854888916, 'fitness': {0: [0.2338517387881907, 0.2249221902383926, 0.5047768788413357], 76: [0.4535114251581167, 0.4678961415388403, 0.635596531615932], 105: [0.2850419873363214, 0.273546128936457, 0.4148525207392273], 149: [0.32997882531538936, 0.34238297180247607, 0.6237896373951431], 29: [0.3511476657282984, 0.1586743023065087, 0.6263980941997694], 255: [0.3932934394945047, 0.4313795958556326, 0.6861959551326381], 178: [0.2511415482531809, 0.16222513321667462, 0.5268203328828144], 225: [0.3822999999638427, 0.6130033077626194, 0.7306292858127715]}}
# iteration 9
# goal = 0goal = 76goal = 105
# goal = 149
#
#
# goal 0 elapsed time: 0.43389105796813965
# goal = 29
# goal 105 elapsed time: 0.7919631004333496
# goal = 255
# goal 149 elapsed time: 1.114922285079956
# goal = 178goal 76 elapsed time: 1.2064077854156494
#
# goal = 225
# goal 29 elapsed time: 0.8255650997161865
# goal 255 elapsed time: 0.553945779800415
# goal 225 elapsed time: 0.45284199714660645
# goal 178 elapsed time: 0.5229172706604004
# {'generation': 9, 'elapsedTime': 1.761692762374878, 'fitness': {0: [0.2715996079138374, 0.1735018162536356, 0.5477152546791579], 76: [0.47273268039758093, 0.4772374931638169, 0.635596531615932], 105: [0.3063827840298978, 0.3349928823050906, 0.4148525207392273], 149: [0.36720478704577897, 0.330726181211041, 0.6237896373951431], 29: [0.39216798863950303, 0.38158249178337694, 0.6263980941997694], 255: [0.417174808178278, 0.26906672505434276, 0.6895191493619277], 178: [0.2844471168769301, 0.2980268250180418, 0.5268203328828144], 225: [0.42317972522136577, 0.4513152341762322, 0.7430816467343129]}}
# iteration 10
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 0 elapsed time: 0.3814818859100342
# goal = 29
# goal 105 elapsed time: 0.5967319011688232
# goal = 255goal 76 elapsed time: 0.6400260925292969
# goal = 178
# goal 149 elapsed time: 0.6775140762329102
#
# goal = 225
# goal 29 elapsed time: 0.38170599937438965
# goal 255 elapsed time: 0.6154868602752686
# goal 225 elapsed time: 0.5807769298553467goal 178 elapsed time: 0.6255078315734863
#
# {'generation': 10, 'elapsedTime': 1.377676010131836, 'fitness': {0: [0.32734553194383764, 0.2755071609300805, 0.5477152546791579], 76: [0.5161212601413623, 0.5333557763603659, 0.635596531615932], 105: [0.3135836438448206, 0.3748633159532786, 0.4148525207392273], 149: [0.4016782414117356, 0.4403132114383397, 0.6237896373951431], 29: [0.4425304509637644, 0.3605089361369958, 0.6263980941997694], 255: [0.43958463876432907, 0.44912724915110086, 0.6895191493619277], 178: [0.3177811235697553, 0.4573957105508972, 0.5268203328828144], 225: [0.47038944119154114, 0.40382501727953557, 0.7430816467343129]}}
# iteration 11
# goal = 0goal = 76
# goal = 105goal = 149
#
#
# goal 0 elapsed time: 0.5635628700256348goal 76 elapsed time: 0.5862178802490234
#
# goal = 29goal 149 elapsed time: 0.6154568195343018goal = 255
#
#
# goal = 178
# goal 105 elapsed time: 0.6825611591339111
# goal = 225
# goal 29 elapsed time: 0.5106661319732666
# goal 178 elapsed time: 0.5830709934234619
# goal 225 elapsed time: 0.6285200119018555
# goal 255 elapsed time: 0.7451450824737549
# {'generation': 11, 'elapsedTime': 1.4519319534301758, 'fitness': {0: [0.3442107927618896, 0.3293187391732339, 0.5477152546791579], 76: [0.5296908089911375, 0.5031171131220434, 0.635596531615932], 105: [0.3289745393972438, 0.31648667928226587, 0.4148525207392273], 149: [0.4264971190600704, 0.4988230745852228, 0.6237896373951431], 29: [0.48923442149830165, 0.37127753719215995, 0.6263980941997694], 255: [0.4895071465448523, 0.567982136355063, 0.7778953376712744], 178: [0.3492522897941762, 0.4316837623055513, 0.5268203328828144], 225: [0.48486283455347723, 0.6177825167075588, 0.7430816467343129]}}
# iteration 12
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 76 elapsed time: 0.48650074005126953
# goal = 29
# goal 105 elapsed time: 0.5995707511901855goal 0 elapsed time: 0.621345043182373
#
# goal = 255goal 149 elapsed time: 0.6291570663452148goal = 178
# goal = 225
#
#
# goal 178 elapsed time: 0.46358299255371094
# goal 29 elapsed time: 0.6151549816131592goal 255 elapsed time: 0.5347611904144287
#
# goal 225 elapsed time: 0.5607178211212158
# {'generation': 12, 'elapsedTime': 1.2910411357879639, 'fitness': {0: [0.3621119403788414, 0.361041521263759, 0.5477152546791579], 76: [0.5378449524239077, 0.4963334622971992, 0.635596531615932], 105: [0.33420127090459584, 0.3785107958498047, 0.468886439621884], 149: [0.4617878414178215, 0.39189558921800427, 0.6409335335331736], 29: [0.5107746050104787, 0.5409427906053014, 0.6347260812898167], 255: [0.525601445145818, 0.44066202775103536, 0.7778953376712744], 178: [0.3670429329379268, 0.15866544936148047, 0.5559390798022193], 225: [0.5339139425443455, 0.43972953110835344, 0.7430816467343129]}}
# iteration 13
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 105 elapsed time: 0.6123127937316895goal 76 elapsed time: 0.6471998691558838goal 149 elapsed time: 0.6601507663726807
#
# goal = 29
# goal = 255goal = 178goal 0 elapsed time: 0.6843109130859375
#
# goal = 225
#
#
# goal 178 elapsed time: 0.29583191871643066
# goal 255 elapsed time: 0.48348212242126465
# goal 29 elapsed time: 0.5762741565704346goal 225 elapsed time: 0.5765628814697266
#
# ...
# iteration 185
# goal = 0goal = 76
#
# goal = 105goal = 149
#
# goal 0 elapsed time: 0.04124593734741211
# goal = 29
# goal 105 elapsed time: 0.6394093036651611
# goal = 255
# goal 149 elapsed time: 0.7118289470672607
# goal 76 elapsed time: 0.737969160079956goal = 178
#
# goal = 225
# goal 29 elapsed time: 0.9686720371246338goal 178 elapsed time: 0.4079620838165283
#
# goal 255 elapsed time: 0.5713438987731934
# goal 225 elapsed time: 0.5609402656555176
# {'generation': 185, 'elapsedTime': 1.3972890377044678, 'fitness': {0: [0.8994446502904233, 0.8994446502904233, 0.8994446502904233], 76: [0.7206584332391343, 0.7310643005217758, 0.7369383163079837], 105: [0.6270762036948241, 0.6384549973148815, 0.6384549973148815], 149: [0.7309219374013007, 0.6382076996724979, 0.7607985392515517], 29: [0.6837725763329399, 0.6745735704321508, 0.6981888296727747], 255: [0.8458025443105193, 0.8233759891695024, 0.8653761321209128], 178: [0.7961484608780498, 0.7202676699987743, 0.8120109603254962], 225: [0.7481612850491778, 0.725457124131738, 0.760024478721681]}}
# iteration 186
# goal = 0goal = 76goal = 105
#
# goal = 149
#
# goal 0 elapsed time: 0.12597393989562988
# goal = 29
# goal 105 elapsed time: 0.4601001739501953
# goal 149 elapsed time: 0.5329830646514893goal = 255
#
# goal = 178
# goal 76 elapsed time: 0.8424921035766602goal 178 elapsed time: 0.3204329013824463
#
# goal = 225
# goal 29 elapsed time: 0.8106639385223389goal 255 elapsed time: 0.4613051414489746
#
# goal 225 elapsed time: 0.3303868770599365
# {'generation': 186, 'elapsedTime': 1.3003346920013428, 'fitness': {0: [0.8994430495552894, 0.8994446502904233, 0.8994446502904233], 76: [0.720207451467815, 0.6961020503239924, 0.7369383163079837], 105: [0.6266603436725886, 0.6138633928518165, 0.6384549973148815], 149: [0.7308993764797762, 0.7607985392515517, 0.7607985392515517], 29: [0.6851483168628006, 0.6923018145591967, 0.6981888296727747], 255: [0.8511103665920511, 0.8653761321209128, 0.8653761321209128], 178: [0.7995093843145648, 0.8120109603254962, 0.8120109603254962], 225: [0.7484639828148989, 0.7579390929379466, 0.760024478721681]}}
# iteration 187
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 0 elapsed time: 0.1601719856262207
# goal = 29
# goal 105 elapsed time: 0.7189202308654785
# goal 149 elapsed time: 0.7209610939025879goal = 255
#
# goal 76 elapsed time: 0.815648078918457
# goal = 178goal = 225
#
# goal 29 elapsed time: 1.0536329746246338goal 178 elapsed time: 0.42800021171569824
#
# goal 255 elapsed time: 0.6279900074005127
# goal 225 elapsed time: 0.5356500148773193
# {'generation': 187, 'elapsedTime': 1.4975342750549316, 'fitness': {0: [0.8994430495552894, 0.8994446502904233, 0.8994446502904233], 76: [0.7248956668270394, 0.7369383163079837, 0.7369383163079837], 105: [0.6220922716954521, 0.5911415718556843, 0.6384549973148815], 149: [0.7371847348240645, 0.6790444945231022, 0.7607985392515517], 29: [0.6881548700032963, 0.6923018145591967, 0.6981888296727747], 255: [0.8524759763535429, 0.8522788839424831, 0.8653761321209128], 178: [0.7984167779595097, 0.7836024450396004, 0.8120109603254962], 225: [0.7438161478084446, 0.760024478721681, 0.760024478721681]}}
# iteration 188
# goal = 0goal = 76
# goal = 105
#
# goal = 149
# goal 0 elapsed time: 0.04240226745605469
# goal = 29
# goal 105 elapsed time: 0.522939920425415
# goal = 255
# goal 149 elapsed time: 0.641577959060669
# goal = 178
# goal 76 elapsed time: 0.8254380226135254
# goal = 225
# goal 29 elapsed time: 1.2409982681274414
# goal 178 elapsed time: 0.7494888305664062goal 255 elapsed time: 0.966526985168457
#
# goal 225 elapsed time: 0.9192287921905518
# {'generation': 188, 'elapsedTime': 1.8196430206298828, 'fitness': {0: [0.8994414488201555, 0.8994446502904233, 0.8994446502904233], 76: [0.7249733816371204, 0.7369383163079837, 0.7369383163079837], 105: [0.6289000274837859, 0.6384549973148815, 0.6384549973148815], 149: [0.7329856379136186, 0.7198812893737065, 0.7607985392515517], 29: [0.6946776846233885, 0.698167200607985, 0.6981888296727747], 255: [0.8549040805139071, 0.8391816357640534, 0.8653761321209128], 178: [0.7997092274850556, 0.7978070777097814, 0.8120109603254962], 225: [0.7507824281876254, 0.760024478721681, 0.760024478721681]}}
# iteration 189
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 0 elapsed time: 0.039537906646728516
# goal = 29
# goal 149 elapsed time: 0.5063669681549072goal 76 elapsed time: 0.6058440208435059
# goal 105 elapsed time: 0.6309201717376709goal = 255
#
#
# goal = 178
# goal = 225
# goal 29 elapsed time: 0.8348889350891113
# goal 178 elapsed time: 0.3227393627166748
# goal 255 elapsed time: 0.5467538833618164
# goal 225 elapsed time: 0.6640801429748535
# {'generation': 189, 'elapsedTime': 1.3566009998321533, 'fitness': {0: [0.8994398480850214, 0.8994446502904233, 0.8994446502904233], 76: [0.7276585196005911, 0.7369058733578733, 0.7369383163079837], 105: [0.6322254663968708, 0.6138633928518165, 0.6384549973148815], 149: [0.7329794490653689, 0.7607985392515517, 0.7607985392515517], 29: [0.6977192989274539, 0.6981888296727747, 0.6981888296727747], 255: [0.854270236061138, 0.8497699803689777, 0.8653761321209128], 178: [0.7981982451491992, 0.8120109603254962, 0.8120109603254962], 225: [0.74972843706013, 0.760024478721681, 0.760024478721681]}}
# iteration 190
# goal = 0goal = 76
# goal = 105goal = 149
#
#
# goal 0 elapsed time: 0.12439298629760742
# goal = 29
# goal 105 elapsed time: 0.44846200942993164
# goal = 255
# goal 76 elapsed time: 0.595012903213501
# goal = 178
# goal 149 elapsed time: 0.6768670082092285goal 29 elapsed time: 0.5544130802154541
#
# goal = 225
# goal 178 elapsed time: 0.2773869037628174
# goal 255 elapsed time: 0.4670858383178711
# goal 225 elapsed time: 0.3439910411834717
# {'generation': 190, 'elapsedTime': 1.1375486850738525, 'fitness': {0: [0.8994430495552894, 0.8994238407336823, 0.8994446502904233], 76: [0.7257372868872991, 0.7369383163079837, 0.7369383163079837], 105: [0.6298889249190999, 0.6384549973148815, 0.6384549973148815], 149: [0.7340032906870652, 0.7605052472717335, 0.7607985392515517], 29: [0.6861252097901173, 0.6747484293991353, 0.6981888296727747], 255: [0.8514453870312645, 0.8653761321209128, 0.8653761321209128], 178: [0.7988275084568333, 0.8120109603254962, 0.8120109603254962], 225: [0.7536142279848357, 0.7432178856096329, 0.760024478721681]}}
# iteration 191
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 0 elapsed time: 0.04568290710449219
# goal = 29
# goal 105 elapsed time: 0.22930693626403809
# goal = 255
# goal 76 elapsed time: 0.45690083503723145
# goal 149 elapsed time: 0.459047794342041goal = 178
# goal = 225
#
# goal 29 elapsed time: 0.4350240230560303
# goal 255 elapsed time: 0.47322607040405273goal 178 elapsed time: 0.2833728790283203
#
# goal 225 elapsed time: 0.3057570457458496
# {'generation': 191, 'elapsedTime': 0.8812689781188965, 'fitness': {0: [0.8994414488201555, 0.8994446502904233, 0.8994446502904233], 76: [0.7257347912757524, 0.6961020503239924, 0.7369383163079837], 105: [0.6315242279564697, 0.63774217041639, 0.6384549973148815], 149: [0.7291484559284964, 0.7607985392515517, 0.7607985392515517], 29: [0.6890163831313522, 0.6923234436239865, 0.6981888296727747], 255: [0.8510499173125532, 0.8653761321209128, 0.8653761321209128], 178: [0.8027422940096073, 0.8120109603254962, 0.8120109603254962], 225: [0.753441911775445, 0.7432178856096329, 0.760024478721681]}}
# iteration 192
# goal = 0goal = 76
# goal = 105goal = 149
#
#
# goal 0 elapsed time: 0.052921295166015625
# goal = 29
# goal 105 elapsed time: 0.22114992141723633
# goal 149 elapsed time: 0.26000094413757324
# goal = 255
# goal = 178
# goal 76 elapsed time: 0.5057790279388428
# goal = 225
# goal 255 elapsed time: 0.31101322174072266goal 29 elapsed time: 0.49900317192077637
#
# goal 178 elapsed time: 0.3341031074523926
# goal 225 elapsed time: 0.18293523788452148
# {'generation': 192, 'elapsedTime': 0.7785298824310303, 'fitness': {0: [0.8994414488201555, 0.8994238407336823, 0.8994446502904233], 76: [0.7301524984452917, 0.7369383163079837, 0.7369383163079837], 105: [0.6277813258665608, 0.6138633928518165, 0.6384549973148815], 149: [0.736172709278534, 0.7605052472717335, 0.7607985392515517], 29: [0.6858409406831691, 0.6731299145534955, 0.6981888296727747], 255: [0.8514929329270484, 0.8521140613126916, 0.8653761321209128], 178: [0.8013668555057063, 0.7708182756364373, 0.8120109603254962], 225: [0.753744609541166, 0.7411324998258983, 0.760024478721681]}}
# iteration 193
# goal = 0goal = 76
#
# goal = 105goal = 149
#
# goal 0 elapsed time: 0.12193894386291504
# goal = 29
# goal 149 elapsed time: 0.2130138874053955goal 105 elapsed time: 0.2322831153869629
#
# goal = 255
# goal = 178
# goal 76 elapsed time: 0.37002992630004883
# goal 178 elapsed time: 0.2704019546508789goal = 225
#
# goal 255 elapsed time: 0.4424169063568115goal 29 elapsed time: 0.5379481315612793
#
# goal 225 elapsed time: 0.24821782112121582
# {'generation': 193, 'elapsedTime': 0.7975502014160156, 'fitness': {0: [0.8994430495552894, 0.8994446502904233, 0.8994446502904233], 76: [0.7362126079252493, 0.7340429237734242, 0.7369383163079837], 105: [0.6216510785864414, 0.6380985838656358, 0.6384549973148815], 149: [0.732115691971027, 0.7199617444009474, 0.7607985392515517], 29: [0.6831093631762151, 0.6977495616570697, 0.6981888296727747], 255: [0.8575687912065415, 0.8497699803689777, 0.8653761321209128], 178: [0.798243212215819, 0.7657224945433536, 0.8120109603254962], 225: [0.7548853444379555, 0.7517603628444304, 0.760024478721681]}}
# iteration 194
# goal = 0goal = 76
# goal = 105goal = 149
#
#
# goal 0 elapsed time: 0.09476280212402344
# goal = 29
# goal 149 elapsed time: 0.26581406593322754
# goal = 255
# goal 105 elapsed time: 0.31319308280944824
# goal = 178goal 76 elapsed time: 0.35074281692504883
#
# goal = 225
# goal 29 elapsed time: 0.42335009574890137
# goal 255 elapsed time: 0.31876182556152344
# goal 225 elapsed time: 0.3314521312713623
# goal 178 elapsed time: 0.3880350589752197
# {'generation': 194, 'elapsedTime': 0.8314230442047119, 'fitness': {0: [0.8994414488201555, 0.8994446502904233, 0.8994446502904233], 76: [0.736212863688631, 0.736873430407763, 0.7369383163079837], 105: [0.6242255386180049, 0.6384549973148815, 0.6384549973148815], 149: [0.7407652864171025, 0.7607985392515517, 0.7607985392515517], 29: [0.6848899864674618, 0.6981595623609231, 0.6981888296727747], 255: [0.8578840800356334, 0.8653761321209128, 0.8653761321209128], 178: [0.797150605860764, 0.7401541557370277, 0.8120109603254962], 225: [0.7560973905189597, 0.760024478721681, 0.760024478721681]}}
# iteration 195
# goal = 0goal = 76
# goal = 105
# goal = 149
#
# goal 0 elapsed time: 0.03049612045288086
# goal = 29
# goal 149 elapsed time: 0.28493595123291016
# goal = 255
# goal 105 elapsed time: 0.4842851161956787
# goal 76 elapsed time: 0.5194389820098877goal = 178
# goal = 225
#
# goal 178 elapsed time: 0.3600759506225586
# goal 255 elapsed time: 0.6370377540588379
# goal 225 elapsed time: 0.4470539093017578goal 29 elapsed time: 0.9283962249755859
#
# {'generation': 195, 'elapsedTime': 1.0566859245300293, 'fitness': {0: [0.8994430495552894, 0.8994446502904233, 0.8994446502904233], 76: [0.7322463459262603, 0.7369153025854303, 0.7369383163079837], 105: [0.6218889971402338, 0.6132508689209231, 0.6384549973148815], 149: [0.7453702412521696, 0.7607985392515517, 0.7607985392515517], 29: [0.6851840393113721, 0.6981888296727747, 0.6981888296727747], 255: [0.8584863623660802, 0.8653761321209128, 0.8653761321209128], 178: [0.7891287793717054, 0.8120109603254962, 0.8120109603254962], 225: [0.7505404992050073, 0.7244071300727419, 0.760024478721681]}}
# iteration 196
# goal = 0goal = 76
# goal = 105
#
# goal 0 elapsed time: 0.013640165328979492goal = 149
# goal = 29
#
# goal 105 elapsed time: 0.33663511276245117goal 149 elapsed time: 0.36266303062438965
# goal = 255
#
# goal = 178
# goal 76 elapsed time: 0.4036900997161865
# goal = 225
# goal 29 elapsed time: 0.5678489208221436
# goal 178 elapsed time: 0.21360278129577637goal 255 elapsed time: 0.23352599143981934
#
# goal 225 elapsed time: 0.2707388401031494
# {'generation': 196, 'elapsedTime': 0.7786300182342529, 'fitness': {0: [0.8994430495552893, 0.8994446502904233, 0.8994446502904233], 76: [0.736666341071497, 0.7369383163079837, 0.7369383163079837], 105: [0.6274672705135534, 0.6047472931266005, 0.6384549973148815], 149: [0.7510323276743129, 0.7607985392515517, 0.7607985392515517], 29: [0.6862985736069243, 0.6981888296727747, 0.6981888296727747], 255: [0.8596887697725666, 0.8491768667127183, 0.8653761321209128], 178: [0.8017325921808792, 0.8120109603254962, 0.8120109603254962], 225: [0.754008720072586, 0.760024478721681, 0.760024478721681]}}
# iteration 197
# goal = 0goal = 76
# goal = 105goal = 149
#
#
# goal 0 elapsed time: 0.04347872734069824
# goal = 29
# goal 76 elapsed time: 0.22428512573242188goal 105 elapsed time: 0.22704696655273438
#
# goal = 255
# goal = 178
# goal 149 elapsed time: 0.5049118995666504
# goal = 225
# goal 255 elapsed time: 0.3385441303253174goal 29 elapsed time: 0.4946098327636719
#
# goal 225 elapsed time: 0.24422311782836914goal 178 elapsed time: 0.4998459815979004
#
# {'generation': 197, 'elapsedTime': 0.8001449108123779, 'fitness': {0: [0.8994430495552893, 0.8994446502904233, 0.8994446502904233], 76: [0.7299806616651083, 0.7369153025854303, 0.7369383163079837], 105: [0.6268511450009276, 0.6384549973148815, 0.6384549973148815], 149: [0.7509581930173774, 0.7607985392515517, 0.7607985392515517], 29: [0.6846224272232134, 0.6981888296727747, 0.6981888296727747], 255: [0.8512567584998458, 0.8653761321209128, 0.8653761321209128], 178: [0.7984547154192169, 0.8120109603254962, 0.8120109603254962], 225: [0.7527233093942816, 0.760024478721681, 0.760024478721681]}}
# iteration 198
# goal = 0goal = 76
# goal = 105
#
# goal = 149
# goal 0 elapsed time: 0.1703338623046875
# goal = 29
# goal 105 elapsed time: 0.3816990852355957
# goal = 255
# goal 149 elapsed time: 0.6067447662353516goal 76 elapsed time: 0.6118900775909424
# goal = 178
#
# goal = 225
# goal 29 elapsed time: 0.46546196937561035
# goal 178 elapsed time: 0.1114802360534668
# goal 225 elapsed time: 0.27489423751831055goal 255 elapsed time: 0.5362508296966553
#
# {'generation': 198, 'elapsedTime': 1.0017797946929932, 'fitness': {0: [0.8648506252792532, 0.8994446502904233, 0.8994446502904233], 76: [0.7302794186070283, 0.7369383163079837, 0.7369383163079837], 105: [0.63464425713216, 0.6384549973148815, 0.6384549973148815], 149: [0.7474801531618254, 0.7598347887113921, 0.7607985392515517], 29: [0.6884381779807995, 0.6587454765925029, 0.6981888296727747], 255: [0.8530611274690382, 0.8497699803689777, 0.8653761321209128], 178: [0.8039821619260222, 0.8120109603254962, 0.8120109603254962], 225: [0.7527233093942816, 0.7517603628444304, 0.760024478721681]}}
# iteration 199
# goal = 0goal = 76
#
# goal = 105goal = 149
#
# goal 0 elapsed time: 0.05398201942443848
# goal = 29
# goal 76 elapsed time: 0.12323498725891113
# goal = 255
# goal 105 elapsed time: 0.2805449962615967
# goal = 178
# goal 149 elapsed time: 0.3383150100708008
# goal = 225goal 255 elapsed time: 0.3609459400177002
#
# goal 29 elapsed time: 0.488415002822876
# goal 178 elapsed time: 0.3261909484863281
# goal 225 elapsed time: 0.42097902297973633
# {'generation': 199, 'elapsedTime': 0.8108789920806885, 'fitness': {0: [0.864850625279253, 0.8994446502904233, 0.8994446502904233], 76: [0.7258669102964325, 0.7369383163079837, 0.7369383163079837], 105: [0.6324079149657869, 0.6380985838656358, 0.6384549973148815], 149: [0.7414209489770189, 0.7607985392515517, 0.7607985392515517], 29: [0.6871945865498379, 0.6981888296727747, 0.6981888296727747], 255: [0.8522312936653814, 0.8653761321209128, 0.8653761321209128], 178: [0.8075691482633306, 0.8110844340891381, 0.8120109603254962], 225: [0.7543500569789644, 0.758974484662685, 0.760024478721681]}}

# %%
transformer = Transformer(exp2)
model = transformer.getModel()

# %%
prediction = []
for it in model.run(data[0],50):
    prediction.append(it[1])

# %%
helpers.animate(prediction)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img18d155ace3764d9489f048f75a9c9e3b">
#   <div class="anim-controls">
#     <input id="_anim_slider18d155ace3764d9489f048f75a9c9e3b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim18d155ace3764d9489f048f75a9c9e3b.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select18d155ace3764d9489f048f75a9c9e3b" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_18d155ace3764d9489f048f75a9c9e3b"
#              >
#       <label for="_anim_radio1_18d155ace3764d9489f048f75a9c9e3b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_18d155ace3764d9489f048f75a9c9e3b"
#              checked>
#       <label for="_anim_radio2_18d155ace3764d9489f048f75a9c9e3b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_18d155ace3764d9489f048f75a9c9e3b"
#              >
#       <label for="_anim_radio3_18d155ace3764d9489f048f75a9c9e3b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img18d155ace3764d9489f048f75a9c9e3b";
#     var slider_id = "_anim_slider18d155ace3764d9489f048f75a9c9e3b";
#     var loop_select_id = "_anim_loop_select18d155ace3764d9489f048f75a9c9e3b";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8QZhcZAAAgAElEQVR4nOzdQYhdZ/038N+tNymIlrTaGSZz66Im\
# yBg1rRkNgkpjCIKURGxpKy5GWmf+Czepmxb0tbjRKCoWdDOXLIJKC3aRSJoG2gYX/0IIF1pdpEjA\
# FHvvG9qmbRDRkun0votKqE36co7eX55zZj6f3VzPPOd7nuc5Z5Jvj5POeDweBwAAAAAATNg1pQMA\
# AAAAALA2KaABAAAAAEihgAYAAAAAIIUCGgAAAACAFApoAAAAAABSKKABAAAAAEihgAYAAAAAIIUC\
# GgAAAACAFApoAAAAAABSKKABAAAAAEihgAYAAAAAIIUCGgAAAACAFApoAAAAAABSKKABAAAAAEih\
# gAYAAAAAIIUCGgAAAACAFApoAAAAAABSKKABAAAAAEihgAYAAAAAIIUCGgAAAACAFApoAAAAAABS\
# KKABAAAAAEihgAYAAAAAIIUCGg

# %%
test1 = Testing1(data,model,verbose=1)
test1.run()
test1.plot()
# Out:
# Testing:
# state 1/50
# [2 4]
# state 2/50
# [2 7]
# state 3/50
# [2 9]
# state 4/50
# [ 3 10]
# state 5/50
# [2 9]
# state 6/50
# [3 8]
# state 7/50
# [2 8]
# state 8/50
# [0 8]
# state 9/50
# [0 8]
# state 10/50
# [2 8]
# state 11/50
# [ 5 12]
# state 12/50
# [ 4 17]
# state 13/50
# [ 5 17]
# state 14/50
# [ 2 13]
# state 15/50
# [ 4 11]
# state 16/50
# [ 5 15]
# state 17/50
# [ 4 20]
# state 18/50
# [ 6 21]
# state 19/50
# [ 7 21]
# state 20/50
# [ 8 25]
# state 21/50
# [14 34]
# state 22/50
# [12 39]
# state 23/50
# [ 7 34]
# state 24/50
# [ 7 26]
# state 25/50
# [ 3 19]
# state 26/50
# [ 5 16]
# state 27/50
# [ 2 14]
# state 28/50
# [ 5 13]
# state 29/50
# [ 5 17]
# state 30/50
# [ 9 23]
# state 31/50
# [12 28]
# state 32/50
# [11 31]
# state 33/50
# [10 31]
# state 34/50
# [ 8 27]
# state 35/50
# [ 7 25]
# state 36/50
# [10 29]
# state 37/50
# [ 7 27]
# state 38/50
# [ 7 26]
# state 39/50
# [ 5 27]
# state 40/50
# [10 30]
# state 41/50
# [12 40]
# state 42/50
# [12 41]
# state 43/50
# [ 9 36]
# state 44/50
# [ 7 28]
# state 45/50
# [ 6 20]
# state 46/50
# [ 7 19]
# state 47/50
# [ 7 21]
# state 48/50
# [ 6 22]
# state 49/50
# [10 25]
# <module 'matplotlib.pyplot' from '/Users/hectormoreno/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
visualization = Visualization("experimentEvoloopsGA/17_01_20_13_15_22")

# %%
visualization.getFitnessGraph("0")

# %%
visualization.getFitnessGraph("1")

# %%
visualization.getFitnessGraph("2")

# %%
transformer.lmstr
# Out:
# {0: 'lambda x: (x[12] in {0} if x[12] != -1 else True) and (x[13] in {0, 2} if x[13] != -1 else True)',
#  1: 'lambda x: (x[8] in {1, 2} if x[8] != -1 else True) and (x[12] in {1} if x[12] != -1 else True)',
#  2: 'lambda x: (x[12] in {1} if x[12] != -1 else True) and (x[17] in {2} if x[17] != -1 else True)'}

# %%
exp2.world.toDict()
# Out:
# {'generation': 99,
#  'populations': [{'generation': 99,
#    'goal': '0',
#    'chromosomes': [{'uuid': '69864558-f3a0-41fa-b837-91d64974b952',
#      'generation': 95,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['a485cef6-0869-408f-8601-d9cbcac30fae',
#       'a485cef6-0869-408f-8601-d9cbcac30fae']},
#     {'uuid': '182f4b4e-87bb-4751-b0ba-3f156dd5a6fd',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{0, -1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '7486.437653846154',
#      'parents': ['4bcd7154-bb7c-4af8-a230-286a6a428c8f',
#       '69864558-f3a0-41fa-b837-91d64974b952']},
#     {'uuid': '482d63f0-7313-4b18-8682-081f2061ce97',
#      'generation': 92,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': '{0}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{0, -1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '6731.394871794457',
#      'parents': ['59925098-05ee-4771-af15-ea2ed6b9d4a8',
#       'f20a68f8-87a5-4e9f-afbd-482d8950c66a']},
#     {'uuid': '5185e8d8-8f45-4c1d-b3ed-538ab3811685',
#      'generation': 96,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '8885.048290598605',
#      'parents': ['88f74373-0441-4885-b8e9-7d425e76fcc0',
#       '69864558-f3a0-41fa-b837-91d64974b952']},
#     {'uuid': 'e9afd745-9726-4bce-9728-f0656764555e',
#      'generation': 95,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '8885.048290598605',
#      'parents': ['50f25052-f8e8-4ec9-928f-965511d569d3',
#       'a485cef6-0869-408f-8601-d9cbcac30fae']},
#     {'uuid': '91612b63-7105-4926-ad83-9047f8bc4ca2',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['6795e1da-4c8d-43d6-84a1-e70e83d83311',
#       'c87f3ec5-2f80-4331-896f-539320a97a3e']},
#     {'uuid': 'd1b07e71-5a51-4bc5-99b1-4e097272ef71',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': '{0}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '10108.858307692593',
#      'parents': ['6795e1da-4c8d-43d6-84a1-e70e83d83311',
#       'c87f3ec5-2f80-4331-896f-539320a97a3e']},
#     {'uuid': '81268ffc-2218-4eaf-835c-c51d9fc21908',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '8885.048290598605',
#      'parents': ['5185e8d8-8f45-4c1d-b3ed-538ab3811685',
#       '5185e8d8-8f45-4c1d-b3ed-538ab3811685']},
#     {'uuid': 'b4203eb7-13f4-4996-b9c0-53500c103b7a',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['91612b63-7105-4926-ad83-9047f8bc4ca2',
#       '6795e1da-4c8d-43d6-84a1-e70e83d83311']},
#     {'uuid': 'f97fccb4-32e8-43ca-9915-ab79656068d6',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['d1b07e71-5a51-4bc5-99b1-4e097272ef71',
#       '91612b63-7105-4926-ad83-9047f8bc4ca2']},
#     {'uuid': '70eeebe3-9bcb-429f-9eaf-dd27126cac75',
#      'generation': 91,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': '{0}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{0, -1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '6731.394871794457',
#      'parents': ['c1dbfea8-c450-48eb-b01a-d0a266836985',
#       'aa5e8f39-82cd-4755-b6b6-fed4e1436cea']}],
#    'best': 13307.67558974359,
#    'average': 10085.812085081621,
#    'median': 10108.858307692593,
#    'std': 2613.0551099648296},
#   {'generation': 99,
#    'goal': '1',
#    'chromosomes': [{'uuid': '0f84120e-a534-4252-a4ac-89af40e49a1d',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['cc5b7e32-cef8-400e-9ec2-8f790824549a',
#       'c2c934b8-e298-43e4-aaee-350d52255e73']},
#     {'uuid': '99204fcb-79d5-416c-8924-5bbb95956610',
#      'generation': 96,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['c2c934b8-e298-43e4-aaee-350d52255e73',
#       '458a8c45-27a7-4a3e-98d7-324057c58065']},
#     {'uuid': '7d81459a-fb85-4de1-8493-21afe3a5ca42',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['0f84120e-a534-4252-a4ac-89af40e49a1d',
#       '0f84120e-a534-4252-a4ac-89af40e49a1d']},
#     {'uuid': 'c4eee5ec-98bd-426c-aa5c-d757a3e49c8e',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['00ec00a2-2d27-4c22-ba95-9f7195fc31d6',
#       '00ec00a2-2d27-4c22-ba95-9f7195fc31d6']},
#     {'uuid': 'e5c6d47b-b38d-4fa6-a572-aa6b396fa804',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['146612d3-1e53-4695-b21d-e500863ae5ae',
#       'cc5b7e32-cef8-400e-9ec2-8f790824549a']},
#     {'uuid': 'b41ba72f-6739-48f9-aff6-6fe6696c41b9',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['e5c6d47b-b38d-4fa6-a572-aa6b396fa804',
#       '0f84120e-a534-4252-a4ac-89af40e49a1d']},
#     {'uuid': '00ec00a2-2d27-4c22-ba95-9f7195fc31d6',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['0f84120e-a534-4252-a4ac-89af40e49a1d',
#       '50808483-b942-4941-b778-366292302f00']},
#     {'uuid': '418b2a63-cc3d-4414-bbaf-0fee52ca6d54',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['e5c6d47b-b38d-4fa6-a572-aa6b396fa804',
#       '00ec00a2-2d27-4c22-ba95-9f7195fc31d6']},
#     {'uuid': 'de13735e-09e5-4f58-9146-342b7d3942b0',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['0f84120e-a534-4252-a4ac-89af40e49a1d',
#       '99204fcb-79d5-416c-8924-5bbb95956610']},
#     {'uuid': '9124a335-d7d4-472b-8493-c1519b6b24b9',
#      'generation': 90,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['458a8c45-27a7-4a3e-98d7-324057c58065',
#       'e4004a24-4442-4d22-b15e-e1819601fee0']},
#     {'uuid': 'cc5b7e32-cef8-400e-9ec2-8f790824549a',
#      'generation': 95,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['c2c934b8-e298-43e4-aaee-350d52255e73',
#       '458a8c45-27a7-4a3e-98d7-324057c58065']}],
#    'best': 6815.082687179489,
#    'average': 6810.326231794892,
#    'median': 6815.082687179489,
#    'std': 6.2921990349071395},
#   {'generation': 99,
#    'goal': '2',
#    'chromosomes': [{'uuid': '11e2e040-f2ff-4f73-8e01-73b08dc3b406',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{-1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '128.6118153846142',
#      'parents': ['a97eaa26-f4bd-4937-b868-996df2de2f24',
#       '6fa73d44-c4da-4e60-841a-18eb06130d46']},
#     {'uuid': '2af10dd6-a0a5-4fe5-9a16-fa4f0f052489',
#      'generation': 96,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['29c7d8c6-d3c6-4e56-9925-bbd67d72db08',
#       '0020e50a-3d28-4008-80ef-2585cb54d9de']},
#     {'uuid': '1b808a0d-43c5-4a4e-b0f8-e7562f0a0059',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['29c7d8c6-d3c6-4e56-9925-bbd67d72db08',
#       '29c7d8c6-d3c6-4e56-9925-bbd67d72db08']},
#     {'uuid': 'a62025f2-396d-4e9f-b10a-77b4873ef7a3',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['a97eaa26-f4bd-4937-b868-996df2de2f24',
#       'a1655faa-8a18-4c1f-bfe9-6ba4e3a9e157']},
#     {'uuid': '0020e50a-3d28-4008-80ef-2585cb54d9de',
#      'generation': 94,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['d2b799c5-aaca-4643-a0ae-1be6ad7b7046',
#       'f9f62411-0875-4e99-828e-2c63a467853d']},
#     {'uuid': '50534519-f864-4d9b-9a39-2732a693dcac',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['6fa73d44-c4da-4e60-841a-18eb06130d46',
#       '1b808a0d-43c5-4a4e-b0f8-e7562f0a0059']},
#     {'uuid': '3ef8c179-4e7b-45c9-a560-92e67b6f9553',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['222beea4-7336-4b23-a364-a4b5c091197b',
#       'a62025f2-396d-4e9f-b10a-77b4873ef7a3']},
#     {'uuid': '42551751-965e-4bba-9847-4e11aada2fba',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['9cdbc0e8-81ed-41e5-acee-b4c2346437f7',
#       '222beea4-7336-4b23-a364-a4b5c091197b']},
#     {'uuid': '0a474c7f-76a0-4c50-81c9-302eccb12ede',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['a62025f2-396d-4e9f-b10a-77b4873ef7a3',
#       '2af10dd6-a0a5-4fe5-9a16-fa4f0f052489']},
#     {'uuid': '6fa73d44-c4da-4e60-841a-18eb06130d46',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['0020e50a-3d28-4008-80ef-2585cb54d9de',
#       'e7096c06-3508-4283-8320-3db9a2a37eab']},
#     {'uuid': '62924ebe-da60-4c04-a600-f483c6398202',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['6371dc9c-abf5-4d61-8919-bd592e82aea4',
#       '29c7d8c6-d3c6-4e56-9925-bbd67d72db08']}],
#    'best': 128.6118153846142,
#    'average': 126.60952434232446,
#    'median': 126.40929523809551,
#    'std': 0.6331800232188045}]}

# %%
import sys
del sys.modules["ExperimentBase"]
