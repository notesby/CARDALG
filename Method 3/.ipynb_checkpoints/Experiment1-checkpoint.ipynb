# %%
import random
import helpers
import numpy as np
import pandas as pd
from copy import copy
from genetic import Experiment,Population,Chromosome,Gen
from joblib import Parallel, delayed,parallel_backend
import time

# %%
class Experiment1(Experiment):
    def __init__(self,data,name,path):
        self.data = data
        self.radious = 2
        self.neighborhood = helpers.moore([self.radious])
        self.neighborhoodWLevels = helpers.mooreWLevels([self.radious])
        self.paddingType = 1
        self.paddingValue = -1
        self.antMaxSize = len(self.neighborhood)#(self.radious*2)+1
        self.antMinSize = 2
        self.noChromosomes = 20
        self.noChilds = 5
        self.noIterations = 50
        self.k = 2
        self.mutationRate = .1
        self.goals = []
        self.setup()
        Experiment.__init__(self,name,path)
        
    def setup(self):
        start = time.time()
        self.problem = self.getProblem()
        print(time.time()-start)
        self.matrix = self.getMatrix()
        print(time.time()-start)
        self.domain = self.getDomain()
        self.goals = list(self.problem.keys())
        
    
    def getProblem(self):
        problem = {}
        dataSize = np.shape(self.data)
        stateSize = dataSize[1:]
        noStates = dataSize[0]
        for iState in range(1,noStates):
            currentState = self.data[iState-1].reshape(-1)
            for cell in helpers.multiDimensionalGenerator(stateSize):
                index = tuple([iState]+cell)
                cls = self.data[index]
                if cls not in problem:
                    problem[cls] = {}
                neighbors = helpers.getNeighbors(cell,self.neighborhood,stateSize)
                values = helpers.getNeighborsValue(currentState,neighbors,self.paddingType,self.paddingValue)
                values = [values[key] for key in values]
                strvalues = str(values)
                if strvalues not in problem[cls]:
                    problem[cls][strvalues] = [None,0]
                problem[cls][str(values)][0] = values
                problem[cls][str(values)][1] += 1
        return problem
        
    def getMatrixSub1(self,dic,key):
        backend = 'threading'
        with parallel_backend(backend):
            vals = Parallel(n_jobs=4,backend=backend)(delayed(self.getMatrixSub2)(dic,key,key2) for key2 in dic[key])
        return vals
        
    def getMatrixSub2(self,dic,key,key2):
        #matrix = []
        temp = copy(dic[key][key2])
        if type(temp) == np.ndarray:
            temp = np.append(temp,key)
        else:
            temp.append(key)
        #matrix.append(temp)
        return temp
        
        
    def getMatrix(self):
        matrix = []
        dic = self.problem
        backend = 'threading'
        with parallel_backend(backend):
            vals = Parallel(n_jobs=4,backend=backend)(delayed(self.getMatrixSub1)(dic,key) for key in dic)
        for val in vals:
            matrix += val
        return matrix
    
    def getDomain(self):
        domain = {}
        for row in self.matrix:
            for j,col in enumerate(row[0]):
                if j not in domain:
                    domain[j] = []
                if col not in domain[j]:
                    domain[j].append(col)
        for key in domain:
            domain[key].sort()
        return domain
    
    def setupWorld(self,world):
        world.verbose = 1
        for goal in self.goals:
            population = Population(self.setupPopulation,self.selection,self.regulation,self.fitness,goal)
            world.populations.append(population)
    
    def setupPopulation(self,population):
        setup = lambda x: self.setupChromosome(x,population.goal)
        crossover = lambda p1,p2: self.crossover(p1,p2,population)
        for i in range(self.noChromosomes):
            chromosome = Chromosome(setup,self.express,crossover,self.mutate,population.generation)
            population.chromosomes.append(chromosome)
    
    def setupChromosome(self,chromosome,goal):
        for key in self.domain.keys():
            chromosome.genes.append(Gen(key,random.choice(self.domain[key])))
    
    def getTotalMatch(self,phenotype,goal):
        total = 0
        matchProportion = eval(phenotype)
        for row in self.matrix:
            total+= matchProportion(row[0]) * row[1]
        return total
                    
    def fitness(self,phenotype,goal):
        return self.getTotalMatch(phenotype,goal)
    
    def tournament(self,chromosomes):
        best = None
        for i in range(self.k+1):
            ind = random.randint(0, len(chromosomes)-1)
            if (best == None) or chromosomes[ind] > chromosomes[best]:
                best = ind
        return chromosomes[best]
    
    def selection(self,chromosomes):
        parents = []
        for i in range(self.noChilds):
            parent1 = self.tournament(chromosomes)
            parent2 = self.tournament(chromosomes)
            parents.append([parent1,parent2])
        return parents
    
    def crossover(self,parent1,parent2,population):
        setup = lambda x: self.setupChromosome(x,population.goal)
        crossover = lambda p1,p2: self.crossover(p1,p2,population)
        chromosome = Chromosome(setup,self.express,crossover,self.mutate,population.generation)
        chromosome.parents = [parent1,parent2]
        iGenes = list(self.domain.keys())
        #random.shuffle(iGenes)
        mid = len(iGenes)//2
        genes = [Gen(parent1.genes[x].identifier,parent1.genes[x].value) for x in iGenes[:mid]]
        genes += [Gen(parent2.genes[x].identifier,parent2.genes[x].value) for x in iGenes[mid:]]
        chromosome.genes = genes
        return [chromosome]
    
    def mutate(self,chromosome):
        if random.random() < self.mutationRate:
            index = random.randint(0,len(chromosome.genes)-1)
            identifier = chromosome.genes[index].identifier
            chromosome.genes[index].value = random.choice(self.domain[identifier])
    
    def regulation(self,population):
        population.chromosomes = sorted(population.chromosomes,key = lambda x:x.fitness,reverse = True)
        mid = self.noChromosomes // 2
        indexes = [x for x in range(1,len(population.chromosomes))]
        random.shuffle(indexes)
        indexes = indexes[:self.noChromosomes]
        firstHalf = indexes[:mid]
        secondHalf = indexes[mid:]
        selected = [population.chromosomes[0]]
        selected += (np.array(population.chromosomes)[firstHalf]).tolist()
        selected += (np.array(population.chromosomes)[secondHalf]).tolist()
        population.chromosomes = selected
    
    def express(self,chromosome):
        rule = "lambda x: ("
        terms = []
        for gen in chromosome.genes:
            if gen.value != -1:
                terms.append("int(x[{}] == {})".format(gen.identifier,gen.value))
        if (len(terms) > 0):
            rule += " + ".join(terms) + ") / {}".format(len(chromosome.genes))
        else:
            rule += "0"
        return rule
    
    def run(self):
        super().run()
        fileName = "{}.json".format(0)
        self.saveState(fileName)
        for i in range(1,self.noIterations):
            fileName = "{}.json".format(i)
            self.world.nextGeneration()
            self.saveState(fileName)
        
    def toDict(self):
        temp = {}
        temp["data"] = self.data.tolist()
        temp["radious"] = self.radious
        temp["neighborhood"] = [x.tolist() for x in self.neighborhood]
        temp["paddingType"] = self.paddingType
        temp["paddingValue"] = self.paddingValue
        temp["antMaxSize"] = self.antMaxSize
        temp["antMinSize"] = self.antMinSize
        temp["noChromosomes"] = self.noChromosomes
        temp["noChilds"] = self.noChilds
        temp["k"] = self.k
        temp["mutationRate"] = self.mutationRate
        return temp

# %%
class Experiment2(Experiment1):
    def __init__(self,data,name,path):
        Experiment1.__init__(self,data,name,path)
        
    def getTotalMatch(self,phenotype,goal):
        totalPos = 0
        totalNeg = 0
        matchProportion = eval(phenotype)
        #pll = lambda fun,row: fun(row[0])*row[1]
        #backend = 'threading'
        #res = Parallel(n_jobs=4,backend=backend)(delayed(pll)(matchProportion,row) for row in self.matrix)
        for row in self.matrix:
            res = matchProportion(row[0])
            if row[2] == goal:
                totalPos += res * row[1]
            #else:
            #    totalNeg -= res * row[1] * 0.5
        total = totalPos
        #total = sum(res)
        return total
    
    def setup(self):
        self.radious = 2
        self.neighborhood = helpers.moore([self.radious,self.radious])
        self.mutationRate = .2
        self.noChromosomes = 5
        self.noIterations = 20
        super().setup()

# %%
class Transformer():
    def __init__(self,experiment):
        self.experiment = experiment
    
    def getModel(self):
        rules = self.getRules()
        model = CAModel(rules,self.experiment.neighborhood,self.experiment.paddingType,self.experiment.paddingValue)
        return model
    
    def getRules(self):
        rules = {}
        for population in self.experiment.world.populations:
            goal = population.goal
            rules[goal] = None
            bestChromosomes = []+population.chromosomes[0:2]
            terms = {}
            for chromosome in bestChromosomes:
                print(chromosome)
                for gen in chromosome.genes:
                    if gen.identifier not in terms:
                        terms[gen.identifier] = set()
                    terms[gen.identifier].add(gen.value)
            lmstr = "lambda x: "
            temp = []
            for key in terms:
                temp.append("x[{}] in {}".format(key,terms[key]))
            lmstr += " and ".join(temp)
            print(lmstr)
            fun = eval(lmstr)
            rules[goal]= fun
        return rules

# %%
class CAModel():
    def __init__(self,rules,neighborhood,paddingType,paddingValue):
        self.paddingType = 1
        self.paddingValue = -1
        self.rules = rules
        self.neighborhood = neighborhood
        
    def run(self,initialState,noSteps):
        size = np.shape(initialState)
        initialState = initialState.reshape(-1)
        currentStep = copy(initialState)
        for step in range(noSteps):
            nextStep = copy(currentStep)#np.zeros(shape=np.shape(currentStep))
            for cell in helpers.multiDimensionalGenerator(size):
                neighbors = helpers.getNeighbors(cell,self.neighborhood,size)
                A = helpers.getNeighborsValue(currentStep,neighbors,self.paddingType,self.paddingValue)
                for op in self.rules:
                    res = self.rules[op](A)
                    if res:
                        xi = cell
                        tmpCell = eval(helpers.getExpr(size))
                        nextStep[tmpCell] = op
            yield step,nextStep
            currentStep = nextStep

# %%
dataframe = pd.read_csv("data/2_square.csv")
data  = dataframe.values
exp = Experiment1(data,"Experiment1","path")
exp.run()
# Out:
# {'generation': 1, 'elapsedTime': 0.10808587074279785}
# {'generation': 2, 'elapsedTime': 0.21439409255981445}
# {'generation': 3, 'elapsedTime': 0.21311688423156738}
# {'generation': 4, 'elapsedTime': 0.20574188232421875}
# {'generation': 5, 'elapsedTime': 0.2094578742980957}
# {'generation': 6, 'elapsedTime': 0.2136058807373047}
# {'generation': 7, 'elapsedTime': 0.20790815353393555}
# {'generation': 8, 'elapsedTime': 0.20926499366760254}
# {'generation': 9, 'elapsedTime': 0.20650696754455566}
# {'generation': 10, 'elapsedTime': 0.10593676567077637}
# {'generation': 11, 'elapsedTime': 0.20690608024597168}
# {'generation': 12, 'elapsedTime': 0.2086167335510254}
# {'generation': 13, 'elapsedTime': 0.20724105834960938}
# {'generation': 14, 'elapsedTime': 0.2076258659362793}
# {'generation': 15, 'elapsedTime': 0.20905303955078125}
# {'generation': 16, 'elapsedTime': 0.2055501937866211}
# {'generation': 17, 'elapsedTime': 0.10686588287353516}
# {'generation': 18, 'elapsedTime': 0.21000385284423828}
# {'generation': 19, 'elapsedTime': 0.10654425621032715}
# {'generation': 20, 'elapsedTime': 0.20944738388061523}
# {'generation': 21, 'elapsedTime': 0.21001386642456055}
# {'generation': 22, 'elapsedTime': 0.2072610855102539}
# {'generation': 23, 'elapsedTime': 0.20818305015563965}
# {'generation': 24, 'elapsedTime': 0.20521187782287598}
# {'generation': 25, 'elapsedTime': 0.20878219604492188}
# {'generation': 26, 'elapsedTime': 0.31719398498535156}
# {'generation': 27, 'elapsedTime': 0.21169614791870117}
# {'generation': 28, 'elapsedTime': 0.209456205368042}
# {'generation': 29, 'elapsedTime': 0.20603489875793457}
# {'generation': 30, 'elapsedTime': 0.21097683906555176}
# {'generation': 31, 'elapsedTime': 0.20500707626342773}
# {'generation': 32, 'elapsedTime': 0.20624518394470215}
# {'generation': 33, 'elapsedTime': 0.20940399169921875}
# {'generation': 34, 'elapsedTime': 0.2092909812927246}
# {'generation': 35, 'elapsedTime': 0.1074368953704834}
# {'generation': 36, 'elapsedTime': 0.21192216873168945}
# {'generation': 37, 'elapsedTime': 0.20858216285705566}
# {'generation': 38, 'elapsedTime': 0.2081437110900879}
# {'generation': 39, 'elapsedTime': 0.3247950077056885}
# {'generation': 40, 'elapsedTime': 0.20847487449645996}
# {'generation': 41, 'elapsedTime': 0.2052450180053711}
# {'generation': 42, 'elapsedTime': 0.20676398277282715}
# {'generation': 43, 'elapsedTime': 0.20828700065612793}
# {'generation': 44, 'elapsedTime': 0.2177588939666748}
# {'generation': 45, 'elapsedTime': 0.2063140869140625}
# {'generation': 46, 'elapsedTime': 0.2110919952392578}
# {'generation': 47, 'elapsedTime': 0.2164440155029297}
# {'generation': 48, 'elapsedTime': 0.2082531452178955}
# {'generation': 49, 'elapsedTime': 0.20883703231811523}

# %%
data  = np.load("data/wildfire.npy")
exp2 = Experiment2(data,"Experiment2","2dfire")
exp2.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-79b8392bdb45> in <module>
#       1 data  = np.load("data/wildfire.npy")
# ----> 2 exp2 = Experiment2(data,"Experiment2","2dfire")
#       3 exp2.run()
#
# <ipython-input-9-bc7a5e1015d3> in __init__(self, data, name, path)
#       1 class Experiment2(Experiment1):
#       2     def __init__(self,data,name,path):
# ----> 3         Experiment1.__init__(self,data,name,path)
#       4
#       5     def getTotalMatch(self,phenotype,goal):
#
# <ipython-input-8-b40e35b1b842> in __init__(self, data, name, path)
#      15         self.mutationRate = .1
#      16         self.goals = []
# ---> 17         self.setup()
#      18         Experiment.__init__(self,name,path)
#      19
#
# <ipython-input-9-bc7a5e1015d3> in setup(self)
#      26         self.noChromosomes = 5
#      27         self.noIterations = 20
# ---> 28         super().setup()
#
# <ipython-input-8-b40e35b1b842> in setup(self)
#      20     def setup(self):
#      21         self.problem = self.getProblem()
# ---> 22         self.matrix = self.getMatrix()
#      23         self.domain = self.getDomain()
#      24         self.goals = list(self.problem.keys())
#
# <ipython-input-8-b40e35b1b842> in getMatrix(self)
#      65
#      66     def getMatrix(self):
# ---> 67         start = time.time()
#      68         matrix = []
#      69         dic = self.problem
#
# NameError: name 'time' is not defined

# %%
transformer = Transformer(exp2)
model = transformer.getModel()

# %%
for i in model.run(data[0],10):
    print(i)

# %%
exp2.world.populations[0].chromosomes[1].toDict()

# %%
exp.world.verbose

# %%
sum([10,5,2,3,1])

# %%
import joblib
joblib.__version__
