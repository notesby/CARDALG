# %%
import random
import helpers
import numpy as np
import pandas as pd
from copy import copy
from genetic import Experiment,Population,Chromosome,Gen
from joblib import Parallel, delayed,parallel_backend
import time
from ExperimentBase2 import ExperimentBaseModel,Transformer,CAModel
from Visualization import Visualization
import matplotlib.pyplot as plt
import math

# %%
class Experiment1(ExperimentBaseModel):
    def __init__(self,data,name,path,verbose):
        ExperimentBaseModel.__init__(self,data,name,path,verbose)
        self.mem = {}
    
    def setupChromosome(self,chromosome,goal):
        keys = list(self.domain.keys())
        keys = sorted(keys)
        for key in keys:
            noChoices = random.randint(1,len(self.domain[key])//10)
            vals = set(random.choices(self.domain[key],k=noChoices))
            chromosome.genes.append(Gen(key,vals))
    
    def mutate(self,chromosome):
        if random.random() < self.mutationRate:
            index = random.randint(0,len(chromosome.genes)-1)
            identifier = chromosome.genes[index].identifier
            proportion =  len(self.domain[identifier]) - len(chromosome.genes[index].value)
            if proportion < random.random():
                val = random.choice(self.domain[identifier])
                chromosome.genes[index].value.add(val)
            else:
                if len(chromosome.genes[index].value) > 0:
                    el = random.choice(list(chromosome.genes[index].value))
                    chromosome.genes[index].value.remove(el)
    
    def crossover(self,parent1,parent2,population):
        setup = lambda x: self.setupChromosome(x,population.goal)
        crossover = lambda p1,p2: self.crossover(p1,p2,population)
        chromosome1 = Chromosome(setup,self.express,crossover,self.mutate,population.generation)
        chromosome2 = Chromosome(setup,self.express,crossover,self.mutate,population.generation)
        chromosome1.parents = [parent1,parent2]
        chromosome2.parents = [parent1,parent2]
        iGenes = list(range(len(parent1.genes)))#list(self.domain.keys())
        random.shuffle(iGenes)
        mid = len(iGenes)//2
        genes1 = [Gen(parent1.genes[x].identifier,copy(parent1.genes[x].value)) for x in iGenes[:mid]]
        genes1 += [Gen(parent2.genes[x].identifier,copy(parent2.genes[x].value)) for x in iGenes[mid:]]
        chromosome1.genes = sorted(genes1,key=lambda x: x.identifier)
        genes2 = [Gen(parent2.genes[x].identifier,copy(parent2.genes[x].value)) for x in iGenes[:mid]]
        genes2 += [Gen(parent1.genes[x].identifier,copy(parent1.genes[x].value)) for x in iGenes[mid:]]
        chromosome2.genes = sorted(genes2,key=lambda x: x.identifier)
        return [chromosome1,chromosome2]
    
    def express(self,chromosome):
        rule = "lambda summary2,goal: ["
        pos = []
        neg = []
        posMatch = []
        negMatch = []
        notZero = 0
        for gen in chromosome.genes:
            temp2 = []
            temp3 = []
            isZero = True
            for val in gen.value:
                if val != self.paddingValue:
                    isZero=False
                    temp = f"summary2[{gen.identifier}]['{val}'][goal] if goal in summary2[{gen.identifier}]['{val}'] else set()"
                    temp2.append(temp)
                    for goal in self.goals:
                        if goal != self.paddingValue:
                            temp3.append(f"summary2[{gen.identifier}]['{val}']['{goal}'] if goal != '{goal}' and '{goal}' in summary2[{gen.identifier}]['{val}'] else set()")
            notZero += 1 if not isZero else 0
            pos.append(f"set([]).union(*[{','.join(temp2)}])")
            neg.append(f"set([]).union(*[{','.join(temp3)}])")
        rule += f"[{','.join(pos)}],[{','.join(neg)}],{notZero if notZero > 0 else 100000}"+"]"
        return rule
    
    def getTotalMatch(self,phenotype,goal):
        totalNeg = 0
        totalPos = 0
        matchProportion = eval(phenotype)
        totalPosMatch,totalNegMatch,noChromosomes = matchProportion(self.summarized2,goal)
        countPosMatch = 0
        for row in totalPosMatch:
            for col in row:
                countPosMatch += self.matrix[col][1]
        countPosMatch = countPosMatch / noChromosomes
        countNegMatch = 0
        for row in totalNegMatch:
            for col in row:
                countNegMatch += self.matrix[col][1]
        countNegMatch = countNegMatch / noChromosomes
        totalPos = self.summarized["total"][goal]
        totalNeg = self.summarized["total"]["total"]-self.summarized["total"][goal]
        totalExamples = totalNeg+totalPos
        posProp = (totalPos/totalExamples) 
        negProp = (totalNeg/totalExamples) 
        total = (countPosMatch * negProp) + (-1*countNegMatch * posProp)
        maxTotal = (totalPos * negProp)
        res = total/maxTotal
        return res
    
    def regulation(self,population):
        population.chromosomes = sorted(population.chromosomes,key = lambda x:x.fitness,reverse = True)
        mid = self.noChromosomes // 2
        indexes = [x for x in range(1,len(population.chromosomes))]
        random.shuffle(indexes)
        indexes = indexes[:self.noChromosomes]
        firstHalf = indexes[:mid]
        secondHalf = indexes[mid:]
        selected = [population.chromosomes[0]]
        selected += (np.array(population.chromosomes)[firstHalf]).tolist()
        selected += (np.array(population.chromosomes)[secondHalf]).tolist()
        population.chromosomes = selected
    
    def setup(self):
        self.radious = 6
        self.neighborhood = helpers.moore([self.radious])
        self.mutationRate = .5
        self.noChromosomes = 20
        self.noIterations = 100
        self.paddingValue = "@"
        super().setup()

# %%
class Testing1():
    def __init__(self,data,model,verbose=0):
        self.data = data
        self.model = model
        self.verbose = verbose
    
    def testRow(self,row_prev,row,row_pred):
        totalMatchDynamic = 0
        totalMatchStatic = 0
        totalStatic = 0
        totalDynamic = 0
        for cell0,cell1,cell2 in zip(row_prev,row,row_pred):
            totalMatchDynamic += (cell0 != cell1 and cell1 == cell2)
            totalMatchStatic += (cell0 == cell1 and cell1 == cell2)
            totalStatic += (cell0 == cell1)
            totalDynamic += (cell0 != cell1)
        totalStatic = totalStatic if totalStatic > 0 else 0
        totalDynamic = totalDynamic if totalDynamic > 0 else 0
        return [totalStatic,totalDynamic,totalMatchStatic,totalMatchDynamic]
            
    def run(self):
        res = []
        backend = "threading"
        with Parallel(n_jobs=4,backend=backend) as parallel:
            if self.verbose >= 1: print("Testing:")
            for i in range(1,len(data)):
                if self.verbose >= 1: print(f"state {i}/{len(data)}")
                prediction = next(model.run(data[i-1],1))
                rowsTotal = parallel(delayed(self.testRow)(row0,row1,row2) for row0,row1,row2 in zip(data[i-1],data[i],prediction[1]))
                summation = np.sum(rowsTotal,axis=0)
                if self.verbose >= 1: 
                    print(f"Static : {summation[2]}/{summation[0]}")
                    print(f"Dynamic : {summation[3]}/{summation[1]}")
                totalStatic = summation[2]/summation[0] if summation[0] > 0 else 0
                totalDynamic = summation[3]/summation[1] if summation[1] > 0 else 0
                res.append([totalStatic,totalDynamic])
        self.result = np.array(res)
    
    def plot(self):
        plt.plot(range(len(self.result)),self.result[:,0])
        plt.plot(range(len(self.result)),self.result[:,1])
        return plt

# %% [markdown]
# dataframe = pd.read_csv("data/2_square.csv")
# data  = dataframe.values
# exp = Experiment1(data,"Experiment1","path")
# exp.run()

# %%
data = "Había una vez un pueblo pequeño. Un pueblo con casas de piedras, calles retorcidas y muchos, muchos gatos. Los gatos vivían allí felices, de casa en casa durante el día, de tejado en tejado durante la noche. La convivencia entre las personas y los gatos era perfecta. Los humanos les dejaban campar a sus anchas por sus casas, les acariciaban el lomo, y le daban de comer. A cambio, los felinos perseguían a los ratones cuando estos trataban de invadir las casas y les regalaban su compañía las tardes de lluvia. Y no había quejas… Hasta que llegó Misifú. Al principio, este gato de pelaje blanco y largos bigotes hizo exactamente lo mismo que el resto: merodeaba por los tejados, perseguía ratones, se dejaba acariciar las tardes de lluvia. Pero pronto, el gato Misifú se aburrió de hacer siempre lo mismo, de que la vida gatuna en aquel pueblo de piedra se limitara a aquella rutina y dejó de salir a cazar ratones. Se pasaba las noches mirando a la luna. Te vas a quedar tonto de tanto mirarla le decían sus amigos. Pero Misifú no quería escucharles. No era la luna lo que le tenía enganchado, sino aquel aire de magia que tenían las noches en los que su luz invadía todos los rincones. ¿No ves que no conseguirás nada? Por más que la mires, la luna no bajará a estar contigo. Pero Misifú no quería que la luna bajara a hacerle compañía. Le valía con sentir la dulzura con la que impregnaba el cielo cuando brillaba con todo su esplendor. Porque aunque nadie parecía entenderlo, al gato Misifú le gustaba lo que esa luna redonda y plateada le hacía sentir, lo que le hacía pensar, lo que le hacía soñar. Mira la luna. Es grande, brillante y está tan lejos. ¿No podremos llegar nosotros ahí donde está ella? ¿No podremos salir de aquí, ir más allá? preguntaba Misifú a su amiga Ranina. Ranina se estiraba con elegancia y le lanzaba un gruñido. ¡Ay que ver, Misifú! ¡Cuántos pájaros tienes en la cabeza! Pero Misifú no tenía pájaros sino sueños, muchos y quería cumplirlos todos… Tendríamos que viajar, conocer otros lugares, perseguir otros animales y otras vidas. ¿Es que nuestra existencia va a ser solo esto? Muy pronto los gatos de aquel pueblo dejaron de hacerle caso. Hasta su amiga Ranina se cansó de escucharle suspirar. Tal vez por eso, tal vez porque la luna le dio la clave, el gato Misifú desapareció un día del pueblo de piedra. Nadie consiguió encontrarle. Se ha marchado a buscar sus sueños. ¿Habrá llegado hasta la luna? se preguntaba con curiosidad Ranina… Nunca más se supo del gato Misifú, pero algunas noches de luna llena hay quien mira hacia el cielo y puede distinguir entre las manchas oscuras de la luna unos bigotes alargados."
data = np.array([np.array(list(w.ljust(12," "))) for w in data.split(" ")])
maxLength = -1
for i,w in enumerate(data):
    if len(w) > len(data[maxLength]):
        maxLength = i
print(len(data[maxLength]))
# Out:
# 12

# %%
#data  = np.load("data/data_gray.npy")
#data = data[:,50:100,50:250]
print(np.shape(data))
train = math.floor(len(data) * 0.8)
print(np.shape(data[:train]))
exp2 = Experiment1(data[:train],"Experiment5","text",verbose=2)
exp2.run()
# Out:
# (472, 12)
# (377, 12)
# start setup
# Start 1 (12,)Start 2 (12,)
# Start 3 (12,)
# Start 4 (12,)
#
# middle 0.11911511421203613middle 0.11661505699157715
# End 3 0.11726617813110352
# Start 5 (12,)
#
# End 1 0.12051200866699219
# Start 6 (12,)
# middle 0.13205218315124512
# End 2 0.13250303268432617
# Start 7 (12,)
# middle 0.12967586517333984
# End 4 0.13036084175109863
# Start 8 (12,)
# middle 0.10909581184387207
# End 6 0.10938191413879395
# Start 9 (12,)
# middle 0.11186790466308594
# End 5 0.11289596557617188
# Start 10 (12,)
# middle 0.1064000129699707
# middle 0.10628175735473633End 7 0.10821914672851562
# Start 11 (12,)
#
# End 8 0.10831880569458008
# Start 12 (12,)
# middle 0.1095280647277832middle 0.1077120304107666
# End 9 0.10992908477783203
# Start 13 (12,)
#
# End 10 0.1089169979095459
# Start 14 (12,)
# middle 0.10680103302001953middle 0.1052548885345459
# End 11 0.10768008232116699
# Start 15 (12,)
#
# End 12 0.10645675659179688
# Start 16 (12,)
# middle 0.10368490219116211
# End 14 0.1040189266204834
# Start 17 (12,)
# middle 0.11098599433898926
# End 13 0.11133003234863281
# Start 18 (12,)
# middle 0.10469317436218262
# End 16 0.10521602630615234
# Start 19 (12,)
# middle 0.10756111145019531
# End 15 0.1081380844116211
# Start 20 (12,)
# middle 0.10503196716308594
# End 17 0.10527396202087402
# Start 21 (12,)
# middle 0.10915112495422363middle 0.1066598892211914
# End 18 0.10952901840209961
# Start 22 (12,)
# middle 0.1058359146118164
# End 19 0.10868692398071289
# Start 23 (12,)
#
# End 20 0.10829615592956543
# Start 24 (12,)
# middle 0.10661911964416504
# End 21 0.10685205459594727
# Start 25 (12,)
# middle 0.10824322700500488middle 0.11026597023010254middle 0.10698294639587402
# End 23 0.10896515846252441
# Start 26 (12,)
#
# End 24 0.10815787315368652
# Start 27 (12,)
#
# End 22 0.1126718521118164
# Start 28 (12,)
# middle 0.10856175422668457
# End 25 0.10883569717407227
# Start 29 (12,)
# middle 0.10384297370910645
# End 28 0.10410785675048828
# Start 30 (12,)
# middle 0.10870885848999023
# End 26 0.10922598838806152
# Start 31 (12,)
# middle 0.1111900806427002
# End 27 0.11182689666748047
# Start 32 (12,)
# middle 0.10434079170227051
# End 29 0.10491394996643066
# Start 33 (12,)
# middle 0.10301589965820312
# End 30 0.10325884819030762
# Start 34 (12,)
# middle 0.10535001754760742
# End 31 0.10586714744567871
# Start 35 (12,)
# middle 0.10580587387084961
# End 32 0.10632896423339844
# Start 36 (12,)
# middle 0.10548090934753418
# End 33 0.10574889183044434
# Start 37 (12,)
# middle 0.10303306579589844
# End 34 0.10320782661437988
# Start 38 (12,)
# middle 0.10495424270629883
# End 35 0.10517120361328125
# Start 39 (12,)
# middle 0.10757780075073242
# End 36 0.10779190063476562
# Start 40 (12,)
# middle 0.10571885108947754
# End 37 0.10816788673400879
# Start 41 (12,)
# middle 0.1040201187133789
# End 38 0.10493183135986328
# Start 42 (12,)
# middle 0.11117196083068848middle 0.10494422912597656
# End 39 0.11201095581054688
# Start 43 (12,)
#
# End 40 0.10623002052307129
# Start 44 (12,)
# middle 0.11287498474121094
# End 41 0.11327791213989258
# Start 45 (12,)
# middle 0.1109468936920166
# End 42 0.1120750904083252
# Start 46 (12,)
# middle 0.10860896110534668middle 0.10830521583557129
# End 43 0.10961008071899414
# Start 47 (12,)
#
# End 44 0.10919809341430664
# Start 48 (12,)
# middle 0.10691308975219727
# End 45 0.10825872421264648
# Start 49 (12,)
# middle 0.1080770492553711
# End 46 0.10863518714904785
# Start 50 (12,)
# middle 0.10500621795654297
# End 48 0.10588288307189941
# Start 51 (12,)
# middle 0.10847592353820801
# End 47 0.10907125473022461
# Start 52 (12,)
# middle 0.10431218147277832middle 0.10709071159362793
# End 50 0.10466527938842773
# Start 53 (12,)
#
# End 49 0.10779881477355957
# Start 54 (12,)
# middle 0.10545110702514648
# End 51 0.10561609268188477
# Start 55 (12,)
# middle 0.10539913177490234
# End 52 0.10620999336242676
# Start 56 (12,)
# middle 0.1034078598022461
# End 54 0.10394501686096191
# Start 57 (12,)
# middle 0.10739612579345703
# End 53 0.10863709449768066
# Start 58 (12,)
# middle 0.10475397109985352
# End 55 0.10573315620422363
# Start 59 (12,)
# middle 0.10525989532470703
# End 56 0.10583376884460449
# Start 60 (12,)
# middle 0.10492801666259766
# End 57 0.1051788330078125
# Start 61 (12,)
# middle 0.1057281494140625
# End 58 0.10626006126403809
# Start 62 (12,)
# middle 0.1074669361114502middle 0.11099863052368164
# End 60 0.10786890983581543
# Start 63 (12,)
#
# End 59 0.1131126880645752
# Start 64 (12,)
# middle 0.10366582870483398
# End 61 0.10466575622558594
# Start 65 (12,)
# middle 0.10454773902893066
# End 62 0.10494780540466309
# Start 66 (12,)
# middle 0.10662603378295898
# End 64 0.10714101791381836
# Start 67 (12,)
# middle 0.1104118824005127
# End 63 0.11072301864624023
# Start 68 (12,)
# middle 0.10649919509887695middle 0.11238670349121094
# End 66 0.10692214965820312
# Start 69 (12,)
#
# End 65 0.11366462707519531
# Start 70 (12,)
# middle 0.10725998878479004middle 0.10911917686462402
# End 68 0.10762310028076172
# Start 71 (12,)
#
# End 67 0.11025428771972656
# Start 72 (12,)
# middle 0.10533881187438965
# End 69 0.10557293891906738
# Start 73 (12,)
# middle 0.10614776611328125
# End 70 0.10742974281311035
# Start 74 (12,)
# middle 0.10757303237915039middle 0.10865902900695801
# End 72 0.10791492462158203
# Start 75 (12,)
#
# End 71 0.10973691940307617
# Start 76 (12,)
# middle 0.10884571075439453
# End 73 0.10916972160339355
# Start 77 (12,)
# middle 0.10942387580871582
# End 74 0.1102139949798584
# Start 78 (12,)
# middle 0.10431790351867676
# End 76 0.10458707809448242
# Start 79 (12,)
# middle 0.10663390159606934
# End 75 0.1069021224975586
# Start 80 (12,)
# middle 0.10718989372253418
# End 77 0.10747194290161133
# Start 81 (12,)
# middle 0.10385894775390625
# End 78 0.1046440601348877
# Start 82 (12,)
# middle 0.1053929328918457middle 0.10428786277770996
# End 79 0.1062779426574707
# Start 83 (12,)
#
# End 80 0.1066439151763916
# Start 84 (12,)
# middle 0.10936307907104492
# End 81 0.10967302322387695
# Start 85 (12,)
# middle 0.11077404022216797
# End 82 0.11112785339355469
# Start 86 (12,)
# middle 0.10784506797790527
# End 83 0.10842394828796387
# Start 87 (12,)
# middle 0.10858893394470215
# End 84 0.11072587966918945
# Start 88 (12,)
# middle 0.1043860912322998
# End 85 0.1057591438293457
# Start 89 (12,)
# middle 0.10853123664855957
# End 86 0.10914421081542969
# Start 90 (12,)
# middle 0.10744214057922363
# End 87 0.10806894302368164
# Start 91 (12,)
# middle 0.10990023612976074
# End 88 0.11013317108154297
# Start 92 (12,)
# middle 0.10391116142272949
# End 89 0.10422396659851074
# Start 93 (12,)
# middle 0.1052999496459961
# End 90 0.10554313659667969
# Start 94 (12,)
# middle 0.10585379600524902
# End 91 0.10612607002258301
# Start 95 (12,)
# middle 0.10267782211303711
# End 92 0.1029059886932373
# Start 96 (12,)
# middle 0.10482192039489746
# End 93 0.10507869720458984
# Start 97 (12,)
# middle 0.10345792770385742
# End 94 0.10367298126220703
# Start 98 (12,)
# middle 0.1039121150970459middle 0.10693788528442383
# End 96 0.10431814193725586
# Start 99 (12,)
#
# End 95 0.1096048355102539
# Start 100 (12,)
# middle 0.10408401489257812
# End 97 0.10437679290771484
# Start 101 (12,)
# middle 0.10856890678405762
# End 98 0.10885882377624512
# Start 102 (12,)
# middle 0.10476899147033691
# middle 0.10782980918884277
# End 99 0.10811209678649902
# Start 103 (12,)
# End 100 0.1068582534790039
# Start 104 (12,)
# middle 0.10304379463195801
# End 101 0.10353469848632812
# Start 105 (12,)
# middle 0.10281109809875488
# End 102 0.10301995277404785
# Start 106 (12,)
# middle 0.10571026802062988
# End 103 0.10633707046508789
# Start 107 (12,)
# middle 0.1054840087890625
# End 104 0.10605311393737793
# Start 108 (12,)
# middle 0.1078498363494873
# End 105 0.10819196701049805
# Start 109 (12,)
# middle 0.10643577575683594
# End 106 0.10712981224060059
# Start 110 (12,)
# middle 0.10794901847839355
# End 107 0.10842227935791016
# Start 111 (12,)
# middle 0.1116340160369873
# End 108 0.11236000061035156
# Start 112 (12,)
# middle 0.11194491386413574
# End 109 0.11256694793701172
# Start 113 (12,)
# middle 0.10520291328430176
# End 110 0.10576796531677246
# Start 114 (12,)
# middle 0.12552809715270996
# middle 0.12268590927124023End 111 0.1291642189025879
# End 112 0.12415385246276855
# Start 115 (12,)
#
# Start 116 (12,)
# middle 0.11401104927062988middle 0.11911892890930176
# End 114 0.11451911926269531
# Start 117 (12,)
#
# End 113 0.12144088745117188
# Start 118 (12,)
# middle 0.1095888614654541
# End 115 0.10988402366638184
# Start 119 (12,)
# middle 0.11086010932922363
# End 116 0.11137580871582031
# Start 120 (12,)
# middle 0.10646772384643555
# End 117 0.10692405700683594
# Start 121 (12,)
# middle 0.10632991790771484
# End 118 0.10685491561889648
# Start 122 (12,)
# middle 0.10315895080566406middle 0.10854721069335938
#
# End 119 0.10874509811401367
# Start 123 (12,)
# End 120 0.10514712333679199
# Start 124 (12,)
# middle 0.10835003852844238middle 0.1066887378692627
# End 121 0.1089329719543457
# Start 125 (12,)
#
# End 122 0.1090388298034668
# Start 126 (12,)
# middle 0.10717105865478516
# End 123 0.10820198059082031
# Start 127 (12,)middle 0.10692501068115234
#
# End 124 0.10805106163024902
# Start 128 (12,)
# middle 0.10474514961242676middle 0.10701394081115723
# End 126 0.10564994812011719
# Start 129 (12,)
#
# End 125 0.1093289852142334
# Start 130 (12,)
# middle 0.10867094993591309
# End 128 0.10901188850402832
# Start 131 (12,)
# middle 0.11690115928649902
# End 127 0.11819314956665039
# Start 132 (12,)
# middle 0.11191201210021973
# End 129 0.11226987838745117
# Start 133 (12,)
# middle 0.11390280723571777
# End 130 0.1144871711730957
# Start 134 (12,)
# middle 0.11205005645751953
# End 131 0.11241602897644043
# Start 135 (12,)
# middle 0.11705231666564941
# End 132 0.11795616149902344
# Start 136 (12,)
# middle 0.10434317588806152
# End 133 0.10480999946594238
# Start 137 (12,)
# middle 0.10647201538085938
# End 134 0.10678696632385254
# Start 138 (12,)
# middle 0.11487388610839844
# End 135 0.11512207984924316
# Start 139 (12,)
# middle 0.11037993431091309
# End 136 0.11058306694030762
# Start 140 (12,)
# middle 0.10377025604248047
# End 137 0.10404729843139648
# Start 141 (12,)
# middle 0.1091468334197998
# End 138 0.10942602157592773
# Start 142 (12,)
# middle 0.10677218437194824
# End 139 0.10700225830078125
# Start 143 (12,)
# middle 0.10426998138427734
# End 140 0.10523414611816406
# Start 144 (12,)
# middle 0.10419583320617676
# End 141 0.10455775260925293
# Start 145 (12,)
# middle 0.11024188995361328
# End 142 0.1114039421081543
# Start 146 (12,)
# middle 0.1027078628540039
# End 143 0.10354399681091309
# Start 147 (12,)
# middle 0.10382986068725586
# End 144 0.10413885116577148
# Start 148 (12,)
# middle 0.11162185668945312
# End 145 0.11188673973083496
# Start 149 (12,)
# middle 0.10959005355834961
# End 146 0.10986685752868652
# Start 150 (12,)
# middle 0.10956573486328125
# End 147 0.10986900329589844
# Start 151 (12,)
# middle 0.10781192779541016
# End 148 0.10806679725646973
# Start 152 (12,)
# middle 0.1065981388092041
# End 149 0.1068880558013916
# Start 153 (12,)
# middle 0.10386419296264648
# End 150 0.10419583320617676
# Start 154 (12,)
# middle 0.10596513748168945
# End 151 0.10636115074157715
# Start 155 (12,)
# middle 0.10492610931396484
# End 152 0.1052711009979248
# Start 156 (12,)
# middle 0.1079709529876709
# End 153 0.10823392868041992
# Start 157 (12,)
# middle 0.12233996391296387
# middle 0.14139294624328613End 154 0.17766618728637695
# middle 0.1560211181640625
# End 156 0.15767288208007812Start 158 (12,)
#
#
# Start 159 (12,)
# middle 0.11270403861999512End 155 0.1685788631439209
# End 157 0.11348605155944824
# Start 160 (12,)
#
# Start 161 (12,)
# middle 0.11017894744873047
# End 159 0.11053299903869629
# Start 162 (12,)
# middle 0.1218099594116211middle 0.11357307434082031
# End 158 0.12384605407714844
# Start 163 (12,)
# middle 0.1131582260131836
#
# End 160 0.11921000480651855
# Start 164 (12,)
# End 161 0.11751031875610352
# Start 165 (12,)
# middle 0.12197089195251465
# middle 0.11599016189575195End 162 0.12317681312561035
# Start 166 (12,)
#
# End 163 0.1190481185913086
# Start 167 (12,)middle 0.11516594886779785
# middle 0.1132516860961914
#
# End 165 0.11385393142700195
# Start 168 (12,)
# End 164 0.11934328079223633
# Start 169 (12,)
# middle 0.10903596878051758
# End 167 0.10935020446777344
# Start 170 (12,)
# middle 0.11449313163757324
# End 166 0.1171572208404541
# Start 171 (12,)
# middle 0.11169099807739258middle 0.11478805541992188
# End 169 0.11242818832397461
# Start 172 (12,)
#
# End 168 0.11587715148925781
# Start 173 (12,)
# middle 0.12301993370056152middle 0.11417508125305176
# middle 0.11945009231567383middle 0.11571407318115234End 170 0.12441086769104004
# End 171 0.12001299858093262
# Start 174 (12,)
#
#
#
# End 173 0.11862301826477051
# Start 175 (12,)
# End 172 0.12169504165649414Start 176 (12,)
#
# Start 177 (12,)
# middle 0.11870598793029785
# End 175 0.11953902244567871
# Start 178 (12,)
# middle 0.11886191368103027
# End 176 0.11925196647644043
# Start 179 (12,)
# middle 0.1169271469116211
# End 177 0.11735296249389648
# Start 180 (12,)
# middle 0.12864303588867188
# End 174 0.12967801094055176
# Start 181 (12,)
# middle 0.11066722869873047
# End 178 0.11100125312805176
# Start 182 (12,)
# middle 0.1079092025756836middle 0.11109781265258789
# End 180 0.10926008224487305
# Start 183 (12,)
#
# End 179 0.11371183395385742
# Start 184 (12,)
# middle 0.11207866668701172
# End 181 0.11294269561767578
# Start 185 (12,)
# middle 0.10968804359436035
# End 182 0.1100001335144043
# Start 186 (12,)
# middle 0.10808491706848145
# End 183 0.11786389350891113
# Start 187 (12,)
# middle 0.11814093589782715
# End 184 0.11894583702087402
# Start 188 (12,)
# middle 0.11589407920837402
# End 185 0.11859703063964844
# Start 189 (12,)
# middle 0.11917877197265625
# End 186 0.11955976486206055
# Start 190 (12,)
# middle 0.11285233497619629
# End 187 0.11364603042602539
# Start 191 (12,)
# middle 0.11484193801879883
# End 188 0.11566495895385742
# Start 192 (12,)
# middle 0.1153109073638916
# End 189 0.11838674545288086
# Start 193 (12,)
# middle 0.1031038761138916
# End 190 0.10346293449401855
# Start 194 (12,)
# middle 0.11288785934448242
# End 191 0.11464309692382812
# Start 195 (12,)
# middle 0.11502408981323242
# End 192 0.1158299446105957
# Start 196 (12,)
# middle 0.11176514625549316
# End 193 0.11288213729858398
# Start 197 (12,)
# middle 0.10652589797973633
# End 194 0.10708189010620117
# Start 198 (12,)
# middle 0.11230802536010742
# End 195 0.1127171516418457
# Start 199 (12,)
# middle 0.1160130500793457
# End 196 0.11663579940795898
# Start 200 (12,)
# middle 0.11465311050415039
# End 197 0.11730098724365234
# Start 201 (12,)
# middle 0.10531783103942871
# End 198 0.10564708709716797
# Start 202 (12,)
# middle 0.10673308372497559
# End 199 0.1070709228515625
# Start 203 (12,)
# middle 0.11418414115905762
# End 200 0.11449313163757324
# Start 204 (12,)
# middle 0.11422419548034668
# End 201 0.11498427391052246
# Start 205 (12,)
# middle 0.10717320442199707
# End 202 0.10752105712890625
# Start 206 (12,)
# middle 0.1111898422241211
# End 203 0.11155009269714355
# Start 207 (12,)
# middle 0.10731291770935059
# End 204 0.10753107070922852
# Start 208 (12,)
# middle 0.11566901206970215
# End 205 0.11593484878540039
# Start 209 (12,)
# middle 0.10757875442504883
# End 206 0.10789704322814941
# Start 210 (12,)
# middle 0.10359621047973633
# End 207 0.10393810272216797
# Start 211 (12,)
# middle 0.10757994651794434
# End 208 0.1087028980255127
# Start 212 (12,)
# middle 0.10981512069702148
# End 209 0.11011600494384766
# Start 213 (12,)
# middle 0.10673093795776367
# End 210 0.10703110694885254
# Start 214 (12,)
# middle 0.1072530746459961
# End 211 0.1074979305267334
# Start 215 (12,)
# middle 0.10986995697021484
# End 212 0.11010098457336426
# Start 216 (12,)
# middle 0.10510492324829102
# End 213 0.10530805587768555
# Start 217 (12,)
# middle 0.10314702987670898
# End 214 0.1034390926361084
# Start 218 (12,)
# middle 0.10794711112976074
# End 215 0.10835003852844238
# Start 219 (12,)
# middle 0.1071329116821289
# End 216 0.1073610782623291
# Start 220 (12,)
# middle 0.10296320915222168
# End 217 0.1032102108001709
# Start 221 (12,)
# middle 0.10377025604248047
# End 218 0.1040191650390625
# Start 222 (12,)
# middle 0.1078348159790039
# End 219 0.10830378532409668
# Start 223 (12,)
# middle 0.10327291488647461
# End 220 0.10352611541748047
# Start 224 (12,)
# middle 0.10754799842834473
# End 221 0.10826802253723145
# Start 225 (12,)
# middle 0.10725283622741699
# End 222 0.10783195495605469
# Start 226 (12,)
# middle 0.10907816886901855
# End 223 0.10983419418334961
# Start 227 (12,)
# middle 0.10317707061767578
# End 224 0.10341596603393555
# Start 228 (12,)
# middle 0.10780167579650879
# End 225 0.10802388191223145
# Start 229 (12,)
# middle 0.10717201232910156
# End 226 0.10739493370056152
# Start 230 (12,)
# middle 0.10797691345214844
# End 227 0.10824990272521973
# Start 231 (12,)
# middle 0.10648107528686523
# End 228 0.10741376876831055
# Start 232 (12,)
# middle 0.10508537292480469
# End 229 0.10538339614868164
# Start 233 (12,)
# middle 0.10308313369750977
# End 230 0.10331225395202637
# Start 234 (12,)
# middle 0.1057579517364502
# End 231 0.10600924491882324
# Start 235 (12,)
# middle 0.10424494743347168
# End 232 0.10442495346069336
# Start 236 (12,)
# middle 0.10629916191101074
# End 233 0.1065530776977539
# Start 237 (12,)
# middle 0.10447525978088379
# End 234 0.1047520637512207
# Start 238 (12,)
# middle 0.10667300224304199
# End 235 0.10693597793579102
# Start 239 (12,)
# middle 0.10335016250610352
# End 236 0.10421109199523926
# Start 240 (12,)
# middle 0.10491323471069336
# End 237 0.10522317886352539
# Start 241 (12,)
# middle 0.10726189613342285
# End 238 0.10747790336608887
# Start 242 (12,)
# middle 0.10319709777832031
# End 239 0.10342025756835938
# Start 243 (12,)
# middle 0.10442090034484863
# End 240 0.10489177703857422
# Start 244 (12,)
# middle 0.10480523109436035
# End 241 0.10502409934997559
# Start 245 (12,)
# middle 0.10717272758483887
# End 242 0.10749292373657227
# Start 246 (12,)
# middle 0.10512685775756836
# End 243 0.10546398162841797
# Start 247 (12,)
# middle 0.10626506805419922
# End 244 0.10662508010864258
# Start 248 (12,)
# middle 0.1078348159790039
# End 245 0.10806083679199219
# Start 249 (12,)
# middle 0.1083521842956543
# End 246 0.10858702659606934
# Start 250 (12,)
# middle 0.10625004768371582
# End 247 0.10647892951965332
# Start 251 (12,)
# middle 0.10739517211914062
# End 248 0.10763406753540039
# Start 252 (12,)
# middle 0.10567498207092285
# End 249 0.10604000091552734
# Start 253 (12,)
# middle 0.10791802406311035
# End 250 0.10827422142028809
# Start 254 (12,)
# middle 0.10721468925476074
# End 251 0.10748481750488281
# Start 255 (12,)
# middle 0.1082909107208252
# End 252 0.10855388641357422
# Start 256 (12,)
# middle 0.11016082763671875
# End 253 0.11040782928466797
# Start 257 (12,)
# middle 0.10590815544128418
# End 254 0.10612320899963379
# Start 258 (12,)
# middle 0.10907888412475586
# End 255 0.10934901237487793
# Start 259 (12,)
# middle 0.10291719436645508
# End 256 0.10326600074768066
# Start 260 (12,)
# middle 0.10522985458374023
# End 257 0.10548686981201172
# Start 261 (12,)
# middle 0.10462784767150879
# End 258 0.10487508773803711
# Start 262 (12,)
# middle 0.10765480995178223
# middle 0.10572385787963867End 259 0.10890507698059082
# End 260 0.10643601417541504
# Start 263 (12,)
#
# Start 264 (12,)
# middle 0.1069800853729248
# End 261 0.10721421241760254
# Start 265 (12,)
# middle 0.10485625267028809
# End 262 0.10525393486022949
# Start 266 (12,)
# middle 0.10853385925292969
# End 263 0.1087498664855957
# Start 267 (12,)
# middle 0.10787487030029297
# End 264 0.10822105407714844
# Start 268 (12,)
# middle 0.10658502578735352
# End 265 0.10680603981018066
# Start 269 (12,)
# middle 0.10557699203491211
# End 266 0.10577893257141113
# Start 270 (12,)
# middle 0.10741400718688965
# End 267 0.10799384117126465
# Start 271 (12,)
# middle 0.11165213584899902
# End 268 0.1122899055480957
# Start 272 (12,)
# middle 0.10888910293579102
# End 269 0.1091010570526123
# Start 273 (12,)
# middle 0.10529208183288574
# End 270 0.10552096366882324
# Start 274 (12,)
# middle 0.10462784767150879
# End 271 0.10485410690307617
# Start 275 (12,)
# middle 0.12425875663757324middle 0.1795668601989746
# End 274 0.12559056282043457
# End 272 0.1800539493560791
# Start 276 (12,)
#
# Start 277 (12,)
# middle 0.1652207374572754
# End 273 0.16580486297607422
# Start 278 (12,)
# middle 0.1032869815826416
# End 275 0.10348272323608398
# Start 279 (12,)
# middle 0.1111898422241211middle 0.1105949878692627
# End 276 0.11159396171569824
# Start 280 (12,)
#
# End 277 0.11382889747619629
# Start 281 (12,)
# middle 0.11436176300048828
# End 278 0.11454892158508301
# Start 282 (12,)
# middle 0.10611414909362793
# End 279 0.1074068546295166
# Start 283 (12,)
# middle 0.10651803016662598
# End 280 0.10673213005065918
# Start 284 (12,)
# middle 0.10864090919494629
# End 281 0.1089169979095459
# Start 285 (12,)
# middle 0.10861897468566895
# End 282 0.1132192611694336
# Start 286 (12,)
# middle 0.10444188117980957
# End 283 0.1048729419708252
# Start 287 (12,)
# middle 0.10474801063537598
# End 284 0.10507082939147949
# Start 288 (12,)
# middle 0.10260796546936035
# End 285 0.10298395156860352
# Start 289 (12,)
# middle 0.10431718826293945
# End 286 0.10481715202331543
# Start 290 (12,)
# middle 0.10786581039428711
# End 287 0.10810685157775879
# Start 291 (12,)
# middle 0.10518288612365723
# End 288 0.10558509826660156
# Start 292 (12,)
# middle 0.10692715644836426
# End 289 0.10745382308959961
# Start 293 (12,)
# middle 0.10732817649841309
# End 290 0.1075892448425293
# Start 294 (12,)
# middle 0.1070089340209961
# End 291 0.10722613334655762
# Start 295 (12,)
# middle 0.10622191429138184
# End 292 0.10648608207702637
# Start 296 (12,)
# middle 0.1076662540435791
# End 293 0.10876202583312988
# Start 297 (12,)
# middle 0.10541582107543945
# End 294 0.10620999336242676
# Start 298 (12,)
# middle 0.11292386054992676
# End 295 0.11565184593200684
# Start 299 (12,)
# middle 0.10689687728881836
# End 296 0.10737085342407227
# Start 300 (12,)
# middle 0.10739779472351074
# End 298 0.10778379440307617
# Start 301 (12,)
# middle 0.11524105072021484
# End 297 0.12101316452026367
# Start 302 (12,)
# middle 0.1086428165435791
# End 299 0.10908079147338867
# Start 303 (12,)
# middle 0.10980510711669922
# End 300 0.11006903648376465
# Start 304 (12,)
# middle 0.11221098899841309
# End 301 0.11242198944091797
# Start 305 (12,)
# middle 0.10802102088928223
# End 302 0.1082160472869873
# Start 306 (12,)
# middle 0.10718011856079102
# End 303 0.10750102996826172
# Start 307 (12,)
# middle 0.10534191131591797
# End 304 0.10571908950805664
# Start 308 (12,)
# middle 0.1054677963256836
# End 305 0.10575199127197266
# Start 309 (12,)
# middle 0.10850811004638672
# End 306 0.10911798477172852
# Start 310 (12,)
# middle 0.10314393043518066
# End 307 0.10362410545349121
# Start 311 (12,)
# middle 0.10680818557739258
# End 308 0.10704421997070312
# Start 312 (12,)
# middle 0.10683798789978027
# End 309 0.10706901550292969
# Start 313 (12,)
# middle 0.10299396514892578
# End 310 0.10328412055969238
# Start 314 (12,)
# middle 0.10611200332641602
# End 311 0.10698294639587402
# Start 315 (12,)
# middle 0.10762882232666016
# End 312 0.10795283317565918
# Start 316 (12,)
# middle 0.10843610763549805
# End 313 0.10878515243530273
# Start 317 (12,)
# middle 0.10893511772155762
# End 314 0.10943222045898438
# Start 318 (12,)
# middle 0.10715293884277344
# End 315 0.10771989822387695
# Start 319 (12,)
# middle 0.1079249382019043
# End 316 0.10843205451965332
# Start 320 (12,)
# middle 0.10394406318664551
# End 318 0.10417008399963379
# Start 321 (12,)
# middle 0.1083676815032959
# End 317 0.10882782936096191
# Start 322 (12,)
# middle 0.10673308372497559
# End 319 0.10753822326660156
# Start 323 (12,)
# middle 0.10803890228271484
# End 320 0.10842585563659668
# Start 324 (12,)
# middle 0.10883402824401855middle 0.10731887817382812
# End 322 0.10782885551452637
# Start 325 (12,)
#
# End 321 0.11196398735046387
# Start 326 (12,)
# middle 0.10614418983459473
# End 323 0.10693717002868652
# Start 327 (12,)
# middle 0.10846400260925293
# End 324 0.1086881160736084
# Start 328 (12,)
# middle 0.10656619071960449
# End 325 0.10680007934570312
# Start 329 (12,)
# middle 0.10855507850646973
# End 326 0.10904717445373535
# Start 330 (12,)
# middle 0.10853123664855957
# End 327 0.10909199714660645
# Start 331 (12,)
# middle 0.10633206367492676
# End 328 0.10665512084960938
# Start 332 (12,)
# middle 0.10613775253295898
# End 329 0.10639595985412598
# Start 333 (12,)
# middle 0.10399198532104492
# End 330 0.10513186454772949
# Start 334 (12,)
# middle 0.1058511734008789
# End 331 0.10679388046264648
# Start 335 (12,)
# middle 0.10722780227661133
# End 332 0.1074838638305664
# Start 336 (12,)
# middle 0.10714197158813477middle 0.11075091361999512
# End 333 0.11110210418701172
# Start 337 (12,)
#
# End 334 0.11060810089111328
# Start 338 (12,)
# middle 0.1069941520690918
# End 335 0.10724496841430664
# Start 339 (12,)
# middle 0.10515785217285156
# End 336 0.10538387298583984
# Start 340 (12,)
# middle 0.10618185997009277
# End 337 0.10641908645629883
# Start 341 (12,)
# middle 0.1072549819946289
# middle 0.11123013496398926
# End 338 0.1115579605102539
# Start 342 (12,)
# End 339 0.10893797874450684
# Start 343 (12,)
# middle 0.10409688949584961
# End 340 0.10441708564758301
# Start 344 (12,)
# middle 0.10731887817382812
# End 341 0.1075587272644043
# Start 345 (12,)
# middle 0.10691666603088379middle 0.10808706283569336
# End 342 0.10845279693603516
#
# End 343 0.10776185989379883
# Start 346 (12,)
# Start 347 (12,)
# middle 0.10575985908508301
# End 344 0.10619807243347168
# Start 348 (12,)
# middle 0.10334277153015137
# End 345 0.10354900360107422
# Start 349 (12,)
# middle 0.10610604286193848
# End 346 0.1063699722290039
# Start 350 (12,)
# middle 0.10843086242675781
# End 347 0.10941958427429199
# Start 351 (12,)
# middle 0.10748410224914551
# End 348 0.10775184631347656
# Start 352 (12,)
# middle 0.10476422309875488
# End 349 0.10681605339050293
# Start 353 (12,)
# middle 0.10839509963989258middle 0.10391783714294434
# End 351 0.10447883605957031
# Start 354 (12,)
#
# End 350 0.11081814765930176
# Start 355 (12,)
# middle 0.10716891288757324
# End 352 0.1073758602142334
# Start 356 (12,)
# middle 0.1062779426574707
# End 353 0.10651087760925293
# Start 357 (12,)
# middle 0.10656428337097168middle 0.1084139347076416
#
# End 354 0.10886764526367188
# Start 358 (12,)
# End 355 0.10807418823242188
# Start 359 (12,)
# middle 0.10705780982971191
# End 356 0.10735678672790527
# Start 360 (12,)
# middle 0.10716080665588379
# End 357 0.10750699043273926
# Start 361 (12,)
# middle 0.10652709007263184
# End 358 0.10687899589538574
# Start 362 (12,)
# middle 0.10948824882507324
# End 359 0.10968399047851562
# Start 363 (12,)
# middle 0.1094369888305664
# End 360 0.10967302322387695
# Start 364 (12,)
# middle 0.10676407814025879
# End 361 0.10699319839477539
# Start 365 (12,)
# middle 0.1068577766418457
# End 362 0.10711908340454102
# Start 366 (12,)
# middle 0.10535097122192383
# End 363 0.10558605194091797
# Start 367 (12,)
# middle 0.10746026039123535
# End 364 0.10792708396911621
# Start 368 (12,)
# middle 0.10634994506835938
# End 365 0.10658097267150879
# Start 369 (12,)
# middle 0.11008810997009277
# End 366 0.11051607131958008
# Start 370 (12,)
# middle 0.11023116111755371
# End 367 0.11058807373046875
# Start 371 (12,)
# middle 0.10677719116210938
# End 368 0.10712504386901855
# Start 372 (12,)
# middle 0.10894608497619629
# End 369 0.10927700996398926
# Start 373 (12,)
# middle 0.10497784614562988
# End 371 0.10563993453979492
# Start 374 (12,)
# middle 0.10968685150146484
# End 370 0.11059880256652832
# Start 375 (12,)
# middle 0.10863304138183594
# End 372 0.10970687866210938
# Start 376 (12,)
# middle 0.10795903205871582
# End 373 0.10827898979187012
# middle 0.10988116264343262
# End 374 0.11042499542236328
# middle 0.11542487144470215
# End 375 0.11642074584960938
# middle 0.11185908317565918
# End 376 0.1121370792388916
# 10.52663803100586
# (2907, 3)
# 12.089071035385132
# 12.136719703674316
# 12.175083875656128
# end setup
# config saved at text/14_01_20_16_29_10/config.json
# iteration 1
# goal =  goal = n
# goal = ugoal = a
#
#
# goal n elapsed time: 6.317130088806152goal   elapsed time: 6.3766350746154785
#
# goal = z
# goal = e
# goal a elapsed time: 7.180798053741455
# goal = v
# goal u elapsed time: 8.677197694778442
# goal = o
# goal e elapsed time: 9.141326189041138goal v elapsed time: 7.953956127166748
# goal = l
#
# goal z elapsed time: 9.684736967086792goal = b
#
# goal = p
# goal o elapsed time: 9.144825220108032
# goal = U
# goal p elapsed time: 6.862462997436523
# goal = .
# goal l elapsed time: 8.17762303352356goal b elapsed time: 7.736180067062378
# goal = ñ
#
# goal U elapsed time: 5.986593008041382goal = q
#
# goal = c
# goal . elapsed time: 6.198034048080444
# goal = s
# goal c elapsed time: 6.593950033187866
# goal q elapsed time: 7.335472106933594goal = d
#
# goal ñ elapsed time: 7.718506097793579goal = ,
#
# goal = r
# goal s elapsed time: 9.441190958023071goal d elapsed time: 7.229754209518433
#
# goal = i
# goal = ygoal , elapsed time: 7.352514982223511goal r elapsed time: 7.147397041320801
#
# goal = t
#
# goal = h
# goal i elapsed time: 7.152294874191284goal t elapsed time: 6.9850239753723145
# goal = m
#
# goal = g
# goal y elapsed time: 7.670203924179077
# goal = L
# goal h elapsed time: 10.010542154312134
# goal = í
# goal m elapsed time: 8.27071499824524
# goal = f
# goal L elapsed time: 7.7679829597473145goal g elapsed time: 8.727633953094482
#
# goal = jgoal = A
#
# goal í elapsed time: 6.182330846786499
# goal = Y
# goal f elapsed time: 6.711955308914185goal A elapsed time: 6.359204053878784
#
# goal = …
# goal Y elapsed time: 6.135572910308838goal = H
#
# goal = ó
# goal j elapsed time: 7.484302043914795
# goal = ú
# goal H elapsed time: 6.6224260330200195
# goal … elapsed time: 7.216559886932373goal = M
# goal = x
# goal ú elapsed time: 5.580941200256348
# goal = :
#
# goal ó elapsed time: 8.45046615600586
# goal = P
# goal M elapsed time: 5.639172077178955
# goal = S
# goal : elapsed time: 6.215415000915527
# goal = T
# goal x elapsed time: 7.621409177780151
# goal = Ngoal P elapsed time: 5.748167037963867
#
# goal = ¿
# goal S elapsed time: 6.645460367202759
# goal = á
# goal T elapsed time: 6.68056321144104
# goal = ?goal ¿ elapsed time: 5.933138132095337
# goal = E
#
# goal N elapsed time: 8.455775022506714
# goal = R
# goal á elapsed time: 5.77188515663147
# goal = ¡
# goal E elapsed time: 5.377953052520752goal ? elapsed time: 5.560589075088501
#
# goal = !goal = C
#
# goal R elapsed time: 7.038229942321777
# goal ¡ elapsed time: 5.7181408405303955
# goal C elapsed time: 5.474530220031738
# goal ! elapsed time: 5.520187139511108
# {'generation': 1, 'elapsedTime': 94.5395188331604, 'fitness': {' ': [0.015874987495727855, 0.017777925465632102, 0.05776752731763782], 'n': [0.009122975133201297, 0.016598384862380394, 0.05571164316627113], 'u': [5.954211140231501e-05, -0.00131908677568204, 0.027311808822519077], 'a': [0.009181993354767055, 0.019977337045957964, 0.04838073762790617], 'z': [0.011270449156924506, -0.01169640570306497, 0.06863192301594077], 'e': [0.010911002577669252, -0.0005163817663817648, 0.047320156695156705], 'v': [0.0007937466649761407, -0.020359474327936007, 0.043331202593127616], 'o': [0.005260754391946151, 0.005268057983770533, 0.029320891245627728], 'l': [0.0013217963566131909, -0.0007355395638774399, 0.03275965128826164], 'b': [0.0068891587100431365, 0.0014502282060810494, 0.0369646209111092], 'p': [-0.0007865171964301248, -0.012510597239331329, 0.035698840119469714], 'U': [0.03189693136489855, 0.042647886363248816, 0.17562198386849243], '.': [0.01793893436432411, -0.018910710670176148, 0.05312972105845154], 'ñ': [0.009521597404420311, 0.011484687083888149, 0.07827170610126669], 'q': [-0.002905766868109167, -0.00561949201556695, 0.027759261256139037], 'c': [0.0007148707580709819, 0.0014215457985490344, 0.02749830569845126], 's': [0.007043427058661157, 0.0072233511191012, 0.029922509599138752], 'd': [0.007420309171746974, 0.029850230613760822, 0.06069388786429665], ',': [0.017783973785116675, 0.026958006850885095, 0.04917408663764488], 'r': [0.0097386276678146, 0.029036881244234137, 0.06446167348367295], 'i': [0.00703755128045199, -0.02992786401698636, 0.06452082711239909], 'y': [-0.004632546465879796, 0.0008547008547008567, 0.04323076923076923], 't': [-0.005616386012069464, -0.020605630879911453, 0.033532789153292754], 'h': [-0.0028523990473256163, 0.030416623874567804, 0.04859470747321215], 'm': [0.0018633214503750235, 0.0045501373626373595, 0.052953296703296696], 'g': [0.0029140959432790723, 0.02260417994137887, 0.08582897922773036], 'L': [0.01587565668089182, -0.0006484199030782883, 0.06574636543580643], 'í': [0.006325305957658898, 0.02283011106540518, 0.03397093102975455], 'f': [0.004393733842745176, -0.0055139261982185776, 0.05439506061590043], 'j': [0.0132300015581474, -0.002965909146433822, 0.07928065709301813], 'A': [0.015817571206792766, 0.03751471416142075, 0.10018851186515858], 'Y': [0.0254218674746274, -0.053663693876507, 0.14492352028375083], '…': [0.009011719987329747, -0.04439706634828586, 0.06900903974074707], 'H': [-0.01741002660976059, 0.028289821462067086, 0.10379755469536008], 'ó': [0.008304785084558872, 0.02986619353884823, 0.06667007864612653], 'ú': [0.011437120950886495, 0.017369176116955872, 0.09310242747187684], 'M': [-0.02532391239919554, -0.011726750067855996, 0.038669377110416424], 'x': [0.0028819419063321554, -0.01147876513730172, 0.09710046051509467], ':': [0.032283992270691446, 0.06733966543321454, 0.12618726872772543], 'P': [0.00017206741574251708, -0.003960531257468671, 0.06939465328280242], 'S': [-0.014450161036283845, -0.009412888153743838, 0.07516668656105589], 'T': [0.00015431722748796123, -0.013917789527545618, 0.06670362158167037], 'N': [0.01728652521687127, 0.01750733738311378, 0.11222783427752372], '¿': [-0.005884175471575647, -0.006747264123040521, 0.0766671216981776], 'á': [0.0040975276759372715, 0.007921265762225335, 0.050979052045244846], '?': [0.0032607883095904433, -0.012866015971606033, 0.06001296839806157], 'E': [0.001090846822554141, -0.029490022172949, 0.11043976348854398], 'R': [0.004184230403742602, -0.055483540849394504, 0.09776564898516117], '¡': [-0.002282947404898622, 0.04306668940815283, 0.13644891693672181], '!': [0.00961331105455274, 0.022735800784581275, 0.06657001535050315], 'C': [0.017727727825267173, 0.0136930238903194, 0.10840168477056086]}}
# iteration 2
# goal =  goal = n
# goal = ugoal = a
#
#
# goal n elapsed time: 1.858778715133667goal u elapsed time: 1.9996039867401123
#
# goal = zgoal = egoal a elapsed time: 2.1749231815338135goal   elapsed time: 2.179725170135498
#
#
#
# goal = v
# goal = o
# goal z elapsed time: 2.247519016265869goal e elapsed time: 2.2021331787109375
#
# goal o elapsed time: 2.264090061187744goal = l
# goal v elapsed time: 2.3161661624908447
# goal = b
# goal = p
# goal = U
#
# goal p elapsed time: 1.2759590148925781
# goal = .
# goal l elapsed time: 1.9215366840362549goal U elapsed time: 1.9727978706359863
#
# goal b elapsed time: 2.190443992614746goal = ñgoal = q
#
#
# goal = c
# goal . elapsed time: 1.5303659439086914
# goal = s
# goal c elapsed time: 1.8952739238739014goal q elapsed time: 2.188399076461792
# goal = d
# goal ñ elapsed time: 2.239609956741333
#
# goal = ,
# goal = r
# goal s elapsed time: 1.6446290016174316
# goal = i
# goal , elapsed time: 2.0187008380889893
# goal = y
# goal r elapsed time: 2.2523510456085205goal d elapsed time: 2.5705127716064453
# goal = t
#
# goal = h
# goal i elapsed time: 2.6248230934143066
# goal = m
# goal y elapsed time: 1.6705918312072754
# goal = g
# goal h elapsed time: 1.584822177886963
# goal t elapsed time: 1.9888360500335693goal = L
# goal m elapsed time: 1.8003089427947998
# goal = í
#
# goal = f
# goal g elapsed time: 1.5119328498840332
# goal = j
# goal L elapsed time: 1.3899710178375244
# goal í elapsed time: 1.9361827373504639
# goal = A
# goal f elapsed time: 1.6633679866790771goal = Y
#
# goal = …goal j elapsed time: 1.4542021751403809
# goal = H
#
# goal A elapsed time: 0.969202995300293
# goal = ó
# goal H elapsed time: 1.6018586158752441
# goal = ú
# goal Y elapsed time: 2.406273126602173
# goal … elapsed time: 2.2784440517425537goal = M
#
# goal = x
# goal ó elapsed time: 1.7763619422912598
# goal = :
# goal ú elapsed time: 2.320178985595703goal x elapsed time: 1.8292298316955566goal M elapsed time: 1.924901008605957
#
# goal = P
# goal = S
#
# goal = T
# goal : elapsed time: 1.9927663803100586
# goal = Ngoal S elapsed time: 1.3551337718963623
#
# goal = ¿
# goal P elapsed time: 1.3577418327331543
# goal = á
# goal T elapsed time: 2.997825860977173goal ¿ elapsed time: 1.6933128833770752goal N elapsed time: 1.9074029922485352
#
#
# goal = ?goal = E
# goal = Rgoal á elapsed time: 1.842545986175537
#
# goal = ¡
#
# goal ¡ elapsed time: 1.1346700191497803
# goal = !goal R elapsed time: 1.3762891292572021
#
# goal = C
# goal ? elapsed time: 1.7273190021514893
# goal E elapsed time: 1.9032459259033203
# goal ! elapsed time: 1.0506298542022705
# goal C elapsed time: 1.175260066986084
# {'generation': 2, 'elapsedTime': 26.441354036331177, 'fitness': {' ': [0.029158662766003225, -0.004615678571017765, 0.0694495744672693], 'n': [0.014168064221289129, -0.01069330641437301, 0.05571164316627113], 'u': [0.005363391641375215, -0.0030046616292388564, 0.027311808822519077], 'a': [0.009719951378845442, 0.02858316677770374, 0.05590119407574436], 'z': [0.01392497976452313, 0.02031198546181899, 0.0781866302399044], 'e': [0.01172669922669923, 0.020557336182336194, 0.05634793447293448], 'v': [0.004557427203504547, -0.0014505810880868105, 0.043331202593127616], 'o': [0.007344911757547592, 0.019074422050347824, 0.029320891245627728], 'l': [0.004757672105537684, -0.002493524405422678, 0.04607117073057127], 'b': [0.016006913108362383, 0.008978487963995203, 0.0369646209111092], 'p': [0.006491468145855283, 0.02208909643604888, 0.035698840119469714], 'U': [0.055198742241526544, -0.022679603703766857, 0.17562198386849243], '.': [0.024785836534166144, 0.047278463926570806, 0.05552665597209028], 'ñ': [0.01591262217094441, 0.005326231691078569, 0.07827170610126669], 'q': [0.006476157863630781, 0.0025690188491258948, 0.03219750811187029], 'c': [0.002314569431690036, -0.00490186152821831, 0.02749830569845126], 's': [0.01096107958196609, 0.025831610037832985, 0.03267332834641714], 'd': [0.02050178941020004, 0.03791563691003031, 0.06546192581887429], ',': [0.025920962347686604, -0.0034510222312289273, 0.06057020840985507], 'r': [0.01566329730449135, 0.04415310128749302, 0.06830462443904088], 'i': [0.010668681140815787, -0.0007911877462783688, 0.077245309982309], 'y': [0.013629900963234298, 0.04323076923076923, 0.04892307692307692], 't': [-0.0022299468117813453, -0.03163911178749309, 0.03783031267293857], 'h': [0.0007652314060858781, 0.0341081556034827, 0.05407780174135315], 'm': [0.007100271999825568, 0.052953296703296696, 0.0556833791208791], 'g': [0.007531254799319028, -0.007200203899579457, 0.08582897922773036], 'L': [0.021208328051717584, 0.05358991422656019, 0.06574636543580643], 'í': [0.013852909073497309, 0.02622377622377622, 0.03631907308377897], 'f': [0.009314089351858738, -0.0008312061189199588, 0.055902107224035685], 'j': [0.015363612581423667, -0.026395329140993882, 0.07928065709301813], 'A': [0.02394844011610479, -0.018151730726581026, 0.10018851186515858], 'Y': [0.04718087892550318, 0.05828487628531965, 0.16043610568106245], '…': [0.019503482474657646, 0.015504008186935021, 0.09273409517311956], 'H': [-0.0015760551672766234, 0.05533482257046877, 0.129052060774517], 'ó': [0.015115001309279423, -0.01670163945613047, 0.08543596567548664], 'ú': [0.024132210300061102, 0.017369176116955872, 0.09310242747187684], 'M': [-0.010753130617665366, 0.0006785599723641057, 0.038669377110416424], 'x': [0.012062869379942557, -0.025737676957189152, 0.10508272215589289], ':': [0.04111764242555641, 0.06261616902273076, 0.12894974677284587], 'P': [0.013662085066878675, 0.015364129878111239, 0.0915190003072826], 'S': [0.0008338726472178071, -0.028528554132633048, 0.0955271728936105], 'T': [0.004381255600767798, -0.01125703564727955, 0.10245608050486099], 'N': [0.03167987612308819, -0.010545355265852157, 0.11222783427752372], '¿': [0.011209416877118739, 0.0025140490979000296, 0.10211475894705709], 'á': [0.011113565589354129, 0.0016813040358131435, 0.050979052045244846], '?': [0.011068912355513957, 0.021619684663162924, 0.06001296839806157], 'E': [0.019540351247668324, -0.013269657172096197, 0.11043976348854398], 'R': [0.018401111084037917, -0.018676445505713794, 0.10790835181079084], '¡': [0.0031068524970964025, -0.025609756097560974, 0.13644891693672181], '!': [0.015596124742466203, 0.020535561998976635, 0.1321848882824492], 'C': [0.030584510688700446, 0.05859181829033304, 0.1209820438927067]}}
# iteration 3
# goal =  goal = n
# goal = ugoal = a
#
#
# goal n elapsed time: 1.7916460037231445goal a elapsed time: 1.9787518978118896goal   elapsed time: 1.9816980361938477
# goal = z
#
#
# goal = egoal u elapsed time: 2.045858144760132goal = v
#
# goal = o
#
# goal e elapsed time: 1.6057028770446777goal z elapsed time: 1.725370168685913
#
# goal = l
# goal v elapsed time: 1.9080612659454346goal = b
#
# goal = pgoal o elapsed time: 2.075687885284424
#
# goal = U
# goal l elapsed time: 2.0211660861968994goal p elapsed time: 1.9578139781951904
#
# goal = .goal = ñgoal U elapsed time: 2.05460786819458
#
# goal b elapsed time: 2.226628065109253
#
# goal = q
# goal = c
# goal c elapsed time: 1.5562918186187744goal ñ elapsed time: 1.564518928527832
# goal = s
#
# goal = dgoal . elapsed time: 1.9758460521697998
# goal q elapsed time: 2.0330209732055664
# goal = ,
#
# goal = r
# goal s elapsed time: 1.515643835067749
# goal = i
# goal d elapsed time: 1.7903079986572266
# goal , elapsed time: 1.8284308910369873goal = y
#
# goal r elapsed time: 1.9757719039916992goal = t
#
# goal = h
# goal y elapsed time: 1.499964952468872
# goal t elapsed time: 1.7983119487762451goal = mgoal i elapsed time: 2.4122400283813477
#
#
# goal = g
# goal = L
# goal h elapsed time: 2.4033260345458984
# goal = í
# goal m elapsed time: 1.7480709552764893
# goal g elapsed time: 2.028557777404785goal L elapsed time: 1.9737448692321777goal = f
# goal = j
#
# goal = A
# goal í elapsed time: 1.0853240489959717
#
# goal = Y
# goal A elapsed time: 1.4630241394042969
# goal = …
# goal Y elapsed time: 2.1330907344818115
# goal = H
# goal j elapsed time: 2.779188871383667goal f elapsed time: 3.046531915664673
# goal = ó
#
# goal = ú
# goal … elapsed time: 2.1015172004699707
# goal = M
# goal H elapsed time: 1.3707702159881592
# goal = x
# goal ó elapsed time: 1.9196159839630127
# goal ú elapsed time: 1.869795799255371
# goal = :
# goal = P
# goal M elapsed time: 1.7120487689971924
# goal = S
# goal x elapsed time: 1.7417991161346436
# goal = T
# goal P elapsed time: 1.7472810745239258
# goal = Ngoal S elapsed time: 1.5022661685943604
#
# goal = ¿
# goal : elapsed time: 2.6730668544769287
# goal = ágoal N elapsed time: 1.6367809772491455
# goal T elapsed time: 2.535407066345215
# goal = ?
# goal ¿ elapsed time: 1.7395408153533936
# goal = E
#
# goal = R
# goal á elapsed time: 1.7018060684204102
# goal = ¡
# goal ? elapsed time: 1.4360899925231934
# goal = !goal E elapsed time: 1.571554183959961
#
# goal = C
# goal ¡ elapsed time: 1.246122121810913
# goal R elapsed time: 2.2203762531280518
# goal ! elapsed time: 1.6398799419403076
# goal C elapsed time: 1.7496740818023682
# {'generation': 3, 'elapsedTime': 26.311853885650635, 'fitness': {' ': [0.04367398830218874, 0.05308602292087099, 0.08149482723290193], 'n': [0.025934534097140548, 0.039352982921494715, 0.05804714039741263], 'u': [0.009699784655494108, 0.028764696408439348, 0.034182052445863045], 'a': [0.013170560943156986, 0.05590119407574436, 0.05838612642076998], 'z': [0.020764280554989294, 0.01180434437926113, 0.0781866302399044], 'e': [0.016776048026048027, 0.02678062678062678, 0.05634793447293448], 'v': [0.00948227690359471, 0.0069488974677746505, 0.056387439034825015], 'o': [0.011072516175047563, 0.0004491968410671308, 0.03418545133187985], 'l': [0.007399539718643565, 0.0056921834850990165, 0.04872254179701955], 'b': [0.021449936853132685, 0.03673974978322803, 0.05840932262336944], 'p': [0.007709006034525121, -0.018718276588336875, 0.048195385770737405], 'U': [0.08618912553738534, 0.12763671708473304, 0.32173206236606805], '.': [0.029229759352253776, 0.0005046178765555174, 0.060489640278059], 'ñ': [0.023756897292183582, -0.01686640035508211, 0.09971889332741532], 'q': [0.009853992594211786, 0.007327641136740158, 0.03223181813725971], 'c': [0.003796867050354809, 0.001622589019814297, 0.02749830569845126], 's': [0.012446861703335785, -8.706644422539797e-05, 0.03808498874527002], 'd': [0.026160192941680947, 0.0308621028379561, 0.06599655506695895], ',': [0.029881653575320206, 0.05044512375475986, 0.06321975456913999], 'r': [0.019900569843781118, 0.027553148562506357, 0.06830462443904088], 'i': [0.020886637566270988, -0.0007911877462783688, 0.07724909398435749], 'y': [0.019663546330212996, 0.03558974358974359, 0.04892307692307692], 't': [0.0029779404498379305, -0.01704309629219702, 0.03783031267293857], 'h': [0.010477839917092256, 0.04732806134675292, 0.06595688838679495], 'm': [0.01056731586865515, -0.002695741758241757, 0.059014423076923055], 'g': [0.021001440787664822, 0.054040740704433855, 0.09184773374113249], 'L': [0.03447317372561383, 0.05994471367142174, 0.08646167497099175], 'í': [0.019416517578282284, 0.02283011106540518, 0.042539364230540694], 'f': [0.015309501034895392, -0.0008312061189199588, 0.06658660157882554], 'j': [0.024499958002149453, 0.04543166926448381, 0.10701459500925929], 'A': [0.03218193920123395, 0.03720763601003122, 0.10018851186515858], 'Y': [0.048593497440759685, -0.021946353358457106, 0.16043610568106245], '…': [0.025833872951389582, -0.01818181818181818, 0.09273409517311956], 'H': [0.016748639670386516, -0.01597803659430793, 0.14542230104189757], 'ó': [0.024399715018477496, 0.033249739836566185, 0.08543596567548664], 'ú': [0.03784512310267195, 0.00995696133351551, 0.09678265783949623], 'M': [-0.0026408252590797506, 0.004458566084149033, 0.038669377110416424], 'x': [0.019991390723098044, 0.01113764284495993, 0.10508272215589289], ':': [0.04961887665279375, 0.0029926845488804994, 0.1684600037515134], 'P': [0.026493301293567598, 0.016166478882857046, 0.09464304004916523], 'S': [0.015138885843829315, -0.05390242654707297, 0.10074518697883805], 'T': [0.016310654115532168, -0.05094661436124851, 0.10245608050486099], 'N': [0.04939637903258134, 0.020271653812026492, 0.12040133779264213], '¿': [0.02792397019326922, -0.017558528428093648, 0.10211475894705709], 'á': [0.0159464061285474, 0.0058566563009033006, 0.05263643508867854], '?': [0.024743083250181746, 0.04288103201146679, 0.06079789775441949], 'E': [0.024529603188139775, -0.026641651031894937, 0.11043976348854398], 'R': [0.03183456110285378, 0.02541361077946444, 0.10790835181079084], '¡': [0.012624841283377871, 0.09414975268633806, 0.15319660014781966], '!': [0.03032570410619191, -0.01879583830803343, 0.1434589800443459], 'C': [0.039553226152649786, 0.0673538757112244, 0.13469638320004093]}}
# iteration 4
# goal =  goal = n
# goal = ugoal = a
#
#
# goal a elapsed time: 1.460434913635254
# goal n elapsed time: 1.6772711277008057
# goal = zgoal = e
# goal u elapsed time: 2.075751781463623
# goal   elapsed time: 2.0787301063537598
# goal = v
#
# goal = o
# goal e elapsed time: 1.5252931118011475
# goal z elapsed time: 2.2665188312530518goal o elapsed time: 1.8011372089385986goal = l
# goal = b
#
#
# goal v elapsed time: 2.109457015991211
# goal = pgoal = U
#
# goal l elapsed time: 1.3154609203338623
# goal = .
# goal b elapsed time: 1.7955009937286377
# goal = ñ
# goal p elapsed time: 2.0335071086883545
# goal U elapsed time: 2.0905258655548096goal = q
#
# goal = c
# goal ñ elapsed time: 1.165431022644043
# goal = sgoal . elapsed time: 2.1892480850219727
#
# goal = d
# goal q elapsed time: 1.9047062397003174goal c elapsed time: 1.76170015335083
# goal = ,
#
# goal = r
# goal d elapsed time: 1.8753020763397217
# goal = i
# goal s elapsed time: 2.3014230728149414
# goal = y
# goal , elapsed time: 1.915208101272583
# goal = t
# goal r elapsed time: 2.1899073123931885
# goal = h
# goal i elapsed time: 1.583956003189087
# goal = m
# goal h elapsed time: 1.673048973083496
# goal = ggoal t elapsed time: 2.3900341987609863
#
# goal = L
# goal y elapsed time: 2.7590949535369873
# goal = í
# goal m elapsed time: 1.874830961227417
# goal = fgoal g elapsed time: 1.6529080867767334
#
# goal = j
# goal L elapsed time: 1.637058973312378
# goal = A
# goal í elapsed time: 1.7771189212799072
# goal = Y
# goal j elapsed time: 1.685795783996582
# goal = …
# goal f elapsed time: 2.3128602504730225
# goal = H
# goal A elapsed time: 1.9747331142425537goal Y elapsed time: 1.965318202972412
# goal = ó
#
# goal = ú
# goal … elapsed time: 1.5223791599273682
# goal = M
# goal ó elapsed time: 1.9088037014007568
# goal = x
# goal H elapsed time: 2.1321730613708496
# goal = :goal ú elapsed time: 2.2450902462005615
#
# goal = P
# goal M elapsed time: 1.5098888874053955
# goal = S
# goal x elapsed time: 1.9704771041870117
# goal = T
# goal : elapsed time: 2.586024045944214
# goal = Ngoal P elapsed time: 2.839520215988159
#
# goal S elapsed time: 2.4770560264587402
# goal = ¿
# goal = ágoal T elapsed time: 1.3444499969482422
#
# goal = ?
# goal ¿ elapsed time: 1.1275429725646973
# goal = E
# goal N elapsed time: 2.4418210983276367
# goal ? elapsed time: 1.9899539947509766goal = Rgoal á elapsed time: 1.9958620071411133
#
#
# goal = ¡
# goal = !
# goal E elapsed time: 1.2786056995391846
# goal = C
# goal R elapsed time: 1.3939290046691895
# goal ! elapsed time: 1.8121531009674072
# goal ¡ elapsed time: 2.0875449180603027
# goal C elapsed time: 1.0239291191101074
# ...
# goal ¿ elapsed time: 0.1544938087463379
# goal = R
# goal ? elapsed time: 0.19505691528320312
# goal = ¡
# goal E elapsed time: 0.18709492683410645
# goal = !
# goal R elapsed time: 0.18356084823608398
# goal á elapsed time: 0.34709596633911133
# goal = C
# goal ¡ elapsed time: 0.1126561164855957
# goal ! elapsed time: 0.08877086639404297
# goal C elapsed time: 0.08244681358337402
# {'generation': 97, 'elapsedTime': 4.019330024719238, 'fitness': {' ': [0.34768114772451275, 0.3477741040424012, 0.3477741040424012], 'n': [0.2026206929791321, 0.2123586486109172, 0.2123586486109172], 'u': [0.1141222639853659, 0.1135433900935592, 0.11673377355451763], 'a': [0.14007203663166357, 0.1416981271744763, 0.1416981271744763], 'z': [0.38742742379970857, 0.48990011098779135, 0.48990011098779135], 'e': [0.343603946208113, 0.350925925925926, 0.350925925925926], 'v': [0.4146680251633467, 0.0, 0.4837793626905712], 'o': [0.12651820478675235, 0.12802387333943446, 0.12969658675118942], 'l': [0.28530200218816626, 0.28443838934302146, 0.2992103138560904], 'b': [0.16554889018657132, 0.16674842066146414, 0.16674842066146414], 'p': [0.20873439527156876, 0.21318171669812658, 0.21318171669812658], 'U': [0.9986602414556307, 0.9986699179782753, 0.9995566393260917], '.': [0.33571573192954035, 0.3309273132212998, 0.34006883984612263], 'ñ': [0.49109124342146965, 0.5156458055925432, 0.5415002219263204], 'q': [0.20581113801452788, 0.22747546833184656, 0.22747546833184656], 'c': [0.22283248650868615, 0.22282179520926562, 0.2230463124970968], 's': [0.1269217157063935, 0.13118377925146738, 0.13118377925146738], 'd': [0.28309892077605336, 0.2832306284977689, 0.2832306284977689], ',': [0.3258390535502703, 0.3421310062277838, 0.3421310062277838], 'r': [0.25390499505953434, 0.2559637509885651, 0.2559637509885651], 'i': [0.27169752670219205, 0.2750972279272883, 0.2750972279272883], 'y': [0.207047619047619, 0.20855555555555555, 0.20855555555555555], 't': [0.1783430398538313, 0.17880695443645087, 0.17880695443645087], 'h': [0.22366741781517033, 0.21210997379221677, 0.24862780002966914], 'm': [0.28044749149659853, 0.2810267857142857, 0.2810267857142857], 'g': [0.5441570026761818, 0.544157002676182, 0.544157002676182], 'L': [0.3922768693398684, 0.47182786157941436, 0.47182786157941436], 'í': [0.19599178055060404, 0.19925356506238856, 0.19925356506238856], 'f': [0.4234095164999411, 0.4231079962028641, 0.4332168608995981], 'j': [0.38658451375214387, 0.3865845137521438, 0.3865845137521438], 'A': [0.3773813924179859, 0.49689509869150583, 0.6640053226879574], 'Y': [0.9886045750599068, 0.9889159831522945, 0.9889159831522945], '…': [0.4943001443001444, 0.49368070953436805, 0.49467849223946786], 'H': [0.9466806008592753, 0.994014630902239, 0.994014630902239], 'ó': [0.36910711205455055, 0.3692060323796852, 0.3949138759518001], 'ú': [0.49222912966252236, 0.4922291296625222, 0.4922291296625222], 'M': [0.5402324376341697, 0.5402324376341697, 0.5402324376341697], 'x': [0.5142223630028511, 0.5113082039911309, 0.5410199556541021], ':': [0.7517162632436408, 0.7937264464641987, 0.9587674573265351], 'P': [0.32527001035656167, 0.3291167332445628, 0.3291167332445628], 'S': [0.9949013522500549, 0.9949013522500554, 0.9949013522500554], 'T': [0.4717558863900327, 0.4953436807095344, 0.4953436807095344], 'N': [0.47658659737186815, 0.48624667258207627, 0.48624667258207627], '¿': [0.591324417965944, 0.5962732919254659, 0.5962732919254659], 'á': [0.24808656470140245, 0.2562268621353472, 0.2562268621353472], '?': [0.24947535950197888, 0.2497781721384206, 0.2497781721384206], 'E': [0.7323038749868019, 0.7440133037694013, 0.7441241685144124], 'R': [0.4441558441558442, 0.4909090909090909, 0.4909090909090909], '¡': [0.4272410516312954, 0.0, 0.4984478935698448], '!': [0.5490022172949002, 0.5490022172949002, 0.5490022172949002], 'C': [0.8951346444141834, 0.9893593438262026, 0.9893593438262026]}}
# iteration 98
# goal =  goal = ngoal = u
# goal = a
#
#
# goal   elapsed time: 0.35340213775634766goal n elapsed time: 0.43598484992980957
#
# goal = z
# goal = e
# goal a elapsed time: 0.5415937900543213
# goal = vgoal u elapsed time: 0.670008659362793
#
# goal z elapsed time: 0.20592379570007324
# goal = ogoal = l
#
# goal e elapsed time: 0.272083044052124
# goal = b
# goal v elapsed time: 0.3948071002960205
# goal = p
# goal l elapsed time: 0.4204378128051758
# goal = Ugoal b elapsed time: 0.42812609672546387
#
# goal = .
# goal o elapsed time: 0.6347000598907471
# goal = ñ
# goal . elapsed time: 0.1879100799560547
# goal = q
# goal U elapsed time: 0.3148632049560547
# goal p elapsed time: 0.41693687438964844goal = c
#
# goal = s
# goal ñ elapsed time: 0.1488950252532959
# goal q elapsed time: 0.07356119155883789
# goal = d
# goal c elapsed time: 0.22004413604736328goal = ,
#
# goal = r
# goal d elapsed time: 0.3099970817565918
# goal = i
# goal , elapsed time: 0.15664887428283691
# goal = y
# goal s elapsed time: 0.42735815048217773
# goal = t
# goal y elapsed time: 0.09749078750610352
# goal = h
# goal i elapsed time: 0.4564507007598877
# goal = mgoal h elapsed time: 0.47974395751953125
# goal r elapsed time: 0.7434289455413818
#
# goal = ggoal t elapsed time: 0.5818221569061279goal = L
#
# goal = í
#
# goal L elapsed time: 0.12746024131774902
# goal = f
# goal m elapsed time: 0.28313112258911133
# goal = j
# goal f elapsed time: 0.14581918716430664
# goal = Agoal g elapsed time: 0.3414928913116455
#
# goal í elapsed time: 0.3563220500946045
# goal = Y
# goal = …
# goal j elapsed time: 0.1993410587310791
# goal = H
# goal A elapsed time: 0.12890291213989258goal … elapsed time: 0.08545088768005371
#
# goal Y elapsed time: 0.12653589248657227goal = ógoal = ú
#
# goal = M
#
# goal M elapsed time: 0.022006988525390625
# goal = x
# goal ú elapsed time: 0.07703304290771484goal H elapsed time: 0.16994094848632812
#
# goal = :goal = P
#
# goal x elapsed time: 0.11906194686889648goal P elapsed time: 0.1597151756286621
# goal = S
#
# goal ó elapsed time: 0.28784775733947754goal = T
#
# goal : elapsed time: 0.22320795059204102goal = N
#
# goal = ¿
# goal T elapsed time: 0.10050320625305176
# goal = ágoal S elapsed time: 0.16443800926208496
# goal N elapsed time: 0.12246513366699219
#
# goal = ?goal = E
#
# goal ¿ elapsed time: 0.2010209560394287
# goal = R
# goal ? elapsed time: 0.14890384674072266
# goal = ¡goal á elapsed time: 0.25463223457336426
#
# goal = !
# goal E elapsed time: 0.23969507217407227
# goal = C
# goal ! elapsed time: 0.06570982933044434goal ¡ elapsed time: 0.08956694602966309
# goal R elapsed time: 0.2002410888671875
#
# goal C elapsed time: 0.06368398666381836
# {'generation': 98, 'elapsedTime': 3.7978811264038086, 'fitness': {' ': [0.34774669739628966, 0.3477741040424012, 0.3477741040424012], 'n': [0.20267346084042992, 0.2123586486109172, 0.2123586486109172], 'u': [0.1139633688192232, 0.11673377355451763, 0.11673377355451763], 'a': [0.1401950727733539, 0.1416981271744763, 0.1416981271744763], 'z': [0.4238631301577234, 0.48990011098779135, 0.48990011098779135], 'e': [0.34359843474426827, 0.350925925925926, 0.350925925925926], 'v': [0.4146680251633467, 0.0, 0.4837793626905712], 'o': [0.12954782807342957, 0.12947509216063682, 0.12969658675118942], 'l': [0.28530200218816626, 0.2992103138560904, 0.2992103138560904], 'b': [0.16574059327682514, 0.16674842066146414, 0.16674842066146414], 'p': [0.2070070784069445, 0.21318171669812658, 0.21318171669812658], 'U': [0.9987446911078037, 0.9986699179782753, 0.9995566393260917], '.': [0.33745697509617334, 0.34006883984612263, 0.34006883984612263], 'ñ': [0.5168769682751039, 0.5156458055925432, 0.5415002219263204], 'q': [0.2274754683318466, 0.22747546833184656, 0.22747546833184656], 'c': [0.22284317780810664, 0.22282179520926562, 0.2230463124970968], 's': [0.1269217157063935, 0.13118377925146738, 0.13118377925146738], 'd': [0.28034456794157936, 0.2832306284977689, 0.2832306284977689], ',': [0.3095471008727568, 0.3421310062277838, 0.3421310062277838], 'r': [0.2539049950595344, 0.2559637509885651, 0.2559637509885651], 'i': [0.271697526702192, 0.2750972279272883, 0.2750972279272883], 'y': [0.20161375661375652, 0.20855555555555555, 0.20855555555555555], 't': [0.17312132436907623, 0.17880695443645087, 0.17880695443645087], 'h': [0.22883338866872466, 0.18770212134698114, 0.24862780002966914], 'm': [0.2607727465986394, 0.14330357142857142, 0.2810267857142857], 'g': [0.5182447644535065, 0.544157002676182, 0.544157002676182], 'L': [0.392652920381403, 0.47182786157941436, 0.47182786157941436], 'í': [0.19453551622669268, 0.18204099821746877, 0.19925356506238856], 'f': [0.42434052654003795, 0.4234412554785805, 0.4332168608995981], 'j': [0.3858124396935298, 0.3865845137521438, 0.3865845137521438], 'A': [0.39387574058232744, 0.3308198417978857, 0.6640053226879574], 'Y': [0.9886045750599068, 0.9889159831522945, 0.9889159831522945], '…': [0.4944268468658714, 0.49467849223946786, 0.49467849223946786], 'H': [0.9466806008592753, 0.994014630902239, 0.994014630902239], 'ó': [0.3705724353761613, 0.3692060323796852, 0.3949138759518001], 'ú': [0.49222912966252236, 0.4922291296625222, 0.4922291296625222], 'M': [0.5402324376341697, 0.5402324376341697, 0.5402324376341697], 'x': [0.49410305142012473, 0.511419068736142, 0.5410199556541021], ':': [0.81712955632264, 0.7937264464641987, 0.9587674573265351], 'P': [0.32527001035656167, 0.3291167332445628, 0.3291167332445628], 'S': [0.9949013522500549, 0.9949013522500554, 0.9949013522500554], 'T': [0.4717558863900327, 0.4953436807095344, 0.4953436807095344], 'N': [0.47235074153885165, 0.48624667258207627, 0.48624667258207627], '¿': [0.5962732919254657, 0.5962732919254659, 0.5962732919254659], 'á': [0.24670375776550799, 0.22718791648156372, 0.2562268621353472], '?': [0.2495493021225053, 0.2497781721384206, 0.2497781721384206], 'E': [0.7323355506282336, 0.49767184035476714, 0.7441241685144124], 'R': [0.42077922077922086, 0.4909090909090909, 0.4909090909090909], '¡': [0.4272410516312954, 0.4984478935698448, 0.4984478935698448], '!': [0.5490022172949002, 0.5490022172949002, 0.5490022172949002], 'C': [0.8951346444141834, 0.9893593438262026, 0.9893593438262026]}}
# iteration 99
# goal =  goal = n
# goal = u
# goal = a
#
# goal u elapsed time: 0.5912361145019531
# goal   elapsed time: 0.6186940670013428goal n elapsed time: 0.6568341255187988goal = z
#
# goal = e
# goal a elapsed time: 0.6919009685516357
# goal = v
#
# goal = o
# goal v elapsed time: 0.10287117958068848
# goal z elapsed time: 0.16510486602783203
# goal = l
# goal = bgoal e elapsed time: 0.18198680877685547
#
# goal = p
# goal o elapsed time: 0.5895040035247803
# goal = U
# goal b elapsed time: 0.5815651416778564goal p elapsed time: 0.5617480278015137goal l elapsed time: 0.6515130996704102
# goal = .
#
# goal = ñ
#
# goal = q
# goal q elapsed time: 0.05178213119506836
# goal U elapsed time: 0.17632699012756348goal = cgoal . elapsed time: 0.10719823837280273
#
# goal = s
#
# goal = d
# goal ñ elapsed time: 0.14765477180480957
# goal = ,
# goal , elapsed time: 0.11654925346374512goal s elapsed time: 0.23636603355407715
# goal = r
# goal = i
#
# goal c elapsed time: 0.3976740837097168
# goal = y
# goal d elapsed time: 0.40163707733154297
# goal = t
# goal r elapsed time: 0.34561920166015625
# goal y elapsed time: 0.36196303367614746goal i elapsed time: 0.46358704566955566
#
# goal = h
# goal = mgoal = g
#
# goal t elapsed time: 0.49999523162841797
# goal = L
# goal m elapsed time: 0.4225001335144043goal g elapsed time: 0.3984200954437256
# goal = í
#
# goal = fgoal h elapsed time: 0.44908809661865234
#
# goal = j
# goal L elapsed time: 0.13954710960388184
# goal = A
# goal A elapsed time: 0.1173861026763916goal f elapsed time: 0.16934418678283691
# goal = Y
#
# goal í elapsed time: 0.19159388542175293goal = …
#
# goal = H
# goal j elapsed time: 0.31714797019958496
# goal Y elapsed time: 0.1534137725830078
# goal = ó
# goal … elapsed time: 0.14287829399108887goal = ú
# goal = M
#
# goal H elapsed time: 0.14565014839172363
# goal = x
# goal M elapsed time: 0.13640189170837402
# goal = :
# goal ú elapsed time: 0.17151308059692383
# goal = P
# goal x elapsed time: 0.2270960807800293goal ó elapsed time: 0.31012392044067383
# goal : elapsed time: 0.16034293174743652
#
# goal = S
# goal = T
# goal = N
# goal S elapsed time: 0.031707048416137695
# goal = ¿
# goal P elapsed time: 0.23950719833374023
# goal = á
# goal N elapsed time: 0.17308688163757324
# goal T elapsed time: 0.1819000244140625
# goal = ?goal = E
#
# goal ¿ elapsed time: 0.17339801788330078
# goal = R
# goal ? elapsed time: 0.1027669906616211
# goal = ¡
# goal E elapsed time: 0.13586783409118652
# goal = !
# goal R elapsed time: 0.15422582626342773
# goal = C
# goal á elapsed time: 0.2504391670227051
# goal ¡ elapsed time: 0.13961005210876465goal C elapsed time: 0.06524300575256348goal ! elapsed time: 0.13040804862976074
#
#
# {'generation': 99, 'elapsedTime': 3.9770729541778564, 'fitness': {' ': [0.34311704710794233, 0.3477741040424012, 0.3477741040424012], 'n': [0.20267346084042992, 0.2123586486109172, 0.2123586486109172], 'u': [0.11388284055380204, 0.11673377355451763, 0.11673377355451763], 'a': [0.14013252540634286, 0.1416981271744763, 0.1416981271744763], 'z': [0.4547388766827486, 0.39727287141271606, 0.48990011098779135], 'e': [0.3436838624338626, 0.350925925925926, 0.350925925925926], 'v': [0.4146680251633467, 0.4837793626905712, 0.4837793626905712], 'o': [0.12651385502218335, 0.12969658675118942, 0.12969658675118942], 'l': [0.2937503103639948, 0.2992103138560904, 0.2992103138560904], 'b': [0.16600431774344812, 0.16674842066146414, 0.16674842066146414], 'p': [0.20941087267276148, 0.21318171669812658, 0.21318171669812658], 'U': [0.9513578800322317, 0.9968410551984039, 0.9995566393260917], '.': [0.32256915319276125, 0.3309273132212998, 0.34006883984612263], 'ñ': [0.5218016190053472, 0.5415002219263204, 0.5415002219263204], 'q': [0.2274754683318466, 0.22747546833184656, 0.22747546833184656], 'c': [0.2228645604069477, 0.22282179520926562, 0.2230463124970968], 's': [0.13104279243620234, 0.13118377925146738, 0.13118377925146738], 'd': [0.27782907128958356, 0.2832306284977689, 0.2832306284977689], ',': [0.3095471008727568, 0.3421310062277838, 0.3421310062277838], 'r': [0.25051349096434394, 0.2528901269179286, 0.2559637509885651], 'i': [0.271697526702192, 0.2750972279272883, 0.2750972279272883], 'y': [0.20312169312169306, 0.20855555555555555, 0.20855555555555555], 't': [0.16869540082219942, 0.17880695443645087, 0.17880695443645087], 'h': [0.23505938547104546, 0.2482272659842753, 0.24862780002966914], 'm': [0.25421449829931975, 0.2810267857142857, 0.2810267857142857], 'g': [0.5182447644535065, 0.544157002676182, 0.544157002676182], 'L': [0.39977605949211986, 0.47182786157941436, 0.47182786157941436], 'í': [0.19537373030020086, 0.1930704099821747, 0.19925356506238856], 'f': [0.42434052654003795, 0.41366565005756306, 0.4332168608995981], 'j': [0.3813289655568764, 0.3865845137521438, 0.3865845137521438], 'A': [0.4969306536838141, 0.6640053226879574, 0.6640053226879574], 'Y': [0.8947335085663617, 0.9889159831522945, 0.9889159831522945], '…': [0.4710625417942491, 0.49467849223946786, 0.49467849223946786], 'H': [0.9466806008592753, 0.994014630902239, 0.994014630902239], 'ó': [0.3735145229822542, 0.3625341908775044, 0.4003104901308494], 'ú': [0.49222912966252236, 0.4922291296625222, 0.4922291296625222], 'M': [0.5402324376341697, 0.5402324376341697, 0.5402324376341697], 'x': [0.4997413155949742, 0.5410199556541021, 0.5410199556541021], ':': [0.8407226778984703, 0.9587674573265351, 0.9587674573265351], 'P': [0.32527001035656167, 0.3291167332445628, 0.3291167332445628], 'S': [0.9949013522500549, 0.9949013522500554, 0.9949013522500554], 'T': [0.4717558863900327, 0.4953436807095344, 0.4953436807095344], 'N': [0.4842343769806061, 0.48624667258207627, 0.48624667258207627], '¿': [0.5962732919254657, 0.5962732919254659, 0.5962732919254659], 'á': [0.24061016973056062, 0.22718791648156372, 0.2562268621353472], '?': [0.23781003084463603, 0.2497781721384206, 0.2497781721384206], 'E': [0.7323461091753775, 0.7440133037694013, 0.7441241685144124], 'R': [0.4441558441558442, 0.4909090909090909, 0.4909090909090909], '¡': [0.4272410516312954, 0.4984478935698448, 0.4984478935698448], '!': [0.5490022172949002, 0.5490022172949002, 0.5490022172949002], 'C': [0.8951346444141834, 0.9893593438262026, 0.9893593438262026]}}

# %%
transformer = Transformer(exp2)
model = transformer.getModel()

# %%
prediction = []
for it in model.run(data[0],50):
    prediction.append(it[1])

# %%
helpers.animate(prediction)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img18d155ace3764d9489f048f75a9c9e3b">
#   <div class="anim-controls">
#     <input id="_anim_slider18d155ace3764d9489f048f75a9c9e3b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim18d155ace3764d9489f048f75a9c9e3b.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim18d155ace3764d9489f048f75a9c9e3b.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select18d155ace3764d9489f048f75a9c9e3b" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_18d155ace3764d9489f048f75a9c9e3b"
#              >
#       <label for="_anim_radio1_18d155ace3764d9489f048f75a9c9e3b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_18d155ace3764d9489f048f75a9c9e3b"
#              checked>
#       <label for="_anim_radio2_18d155ace3764d9489f048f75a9c9e3b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_18d155ace3764d9489f048f75a9c9e3b"
#              >
#       <label for="_anim_radio3_18d155ace3764d9489f048f75a9c9e3b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img18d155ace3764d9489f048f75a9c9e3b";
#     var slider_id = "_anim_slider18d155ace3764d9489f048f75a9c9e3b";
#     var loop_select_id = "_anim_loop_select18d155ace3764d9489f048f75a9c9e3b";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8QZhcZAAAgAElEQVR4nOzdQYhdZ/038N+tNymIlrTaGSZz66Im\
# yBg1rRkNgkpjCIKURGxpKy5GWmf+Czepmxb0tbjRKCoWdDOXLIJKC3aRSJoG2gYX/0IIF1pdpEjA\
# FHvvG9qmbRDRkun0votKqE36co7eX55zZj6f3VzPPOd7nuc5Z5Jvj5POeDweBwAAAAAATNg1pQMA\
# AAAAALA2KaABAAAAAEihgAYAAAAAIIUCGgAAAACAFApoAAAAAABSKKABAAAAAEihgAYAAAAAIIUC\
# GgAAAACAFApoAAAAAABSKKABAAAAAEihgAYAAAAAIIUCGgAAAACAFApoAAAAAABSKKABAAAAAEih\
# gAYAAAAAIIUCGgAAAACAFApoAAAAAABSKKABAAAAAEihgAYAAAAAIIUCGgAAAACAFApoAAAAAABS\
# KKABAAAAAEihgAYAAAAAIIUCGg

# %%
test1 = Testing1(data,model,verbose=1)
test1.run()
test1.plot()
# Out:
# Testing:
# state 1/472
# [7 5 0 0]
# state 2/472
# [9 3 0 0]
# state 3/472
# [9 3 0 0]
# state 4/472
# [6 6 0 0]
# state 5/472
# [5 7 0 0]
# state 6/472
# [4 8 0 0]
# state 7/472
# [6 6 0 0]
# state 8/472
# [6 6 0 0]
# state 9/472
# [8 4 0 0]
# state 10/472
# [7 5 0 0]
# state 11/472
# [4 8 0 0]
# state 12/472
# [4 8 0 0]
# state 13/472
# [ 2 10  0  0]
# state 14/472
# [ 2 10  0  0]
# state 15/472
# [5 7 0 0]
# state 16/472
# [11  1  0  0]
# state 17/472
# [6 6 0 0]
# state 18/472
# [6 6 0 0]
# state 19/472
# [7 5 0 0]
# state 20/472
# [6 6 0 0]
# state 21/472
# [7 5 0 0]
# state 22/472
# [5 7 0 0]
# state 23/472
# [5 7 0 0]
# state 24/472
# [8 4 0 0]
# state 25/472
# [8 4 0 0]
# state 26/472
# [8 4 0 0]
# state 27/472
# [6 6 0 0]
# state 28/472
# [5 7 0 0]
# state 29/472
# [8 4 0 0]
# state 30/472
# [9 3 0 0]
# state 31/472
# [7 5 0 0]
# state 32/472
# [6 6 0 0]
# state 33/472
# [6 6 0 0]
# state 34/472
# [6 6 0 0]
# state 35/472
# [5 7 0 0]
# state 36/472
# [6 6 0 0]
# state 37/472
# [6 6 0 0]
# state 38/472
# [ 1 11  0  0]
# state 39/472
# [ 1 11  0  0]
# state 40/472
# [7 5 0 0]
# state 41/472
# [4 8 0 0]
# state 42/472
# [4 8 0 0]
# state 43/472
# [9 3 0 0]
# state 44/472
# [7 5 0 0]
# state 45/472
# [7 5 0 0]
# state 46/472
# [3 9 0 0]
# state 47/472
# [3 9 0 0]
# state 48/472
# [5 7 0 0]
# state 49/472
# [5 7 0 0]
# state 50/472
# [6 6 0 0]
# state 51/472
# [5 7 0 0]
# state 52/472
# [6 6 0 0]
# state 53/472
# [9 3 0 0]
# state 54/472
# [6 6 0 0]
# state 55/472
# [6 6 0 0]
# state 56/472
# [9 3 0 0]
# state 57/472
# [7 5 0 0]
# state 58/472
# [7 5 0 0]
# state 59/472
# [ 1 11  0  0]
# state 60/472
# [ 1 11  0  0]
# state 61/472
# [7 5 0 0]
# state 62/472
# [7 5 0 0]
# state 63/472
# [10  2  0  0]
# state 64/472
# [7 5 0 0]
# state 65/472
# [8 4 0 0]
# state 66/472
# [6 6 0 0]
# state 67/472
# [6 6 0 0]
# state 68/472
# [5 7 0 0]
# state 69/472
# [5 7 0 0]
# state 70/472
# [5 7 0 0]
# state 71/472
# [3 9 0 0]
# state 72/472
# [ 2 10  0  0]
# state 73/472
# [9 3 0 0]
# state 74/472
# [5 7 0 0]
# state 75/472
# [5 7 0 0]
# state 76/472
# [6 6 0 0]
# state 77/472
# [4 8 0 0]
# state 78/472
# [4 8 0 0]
# state 79/472
# [5 7 0 0]
# state 80/472
# [5 7 0 0]
# state 81/472
# [9 3 0 0]
# state 82/472
# [7 5 0 0]
# state 83/472
# [9 3 0 0]
# state 84/472
# [4 8 0 0]
# state 85/472
# [3 9 0 0]
# state 86/472
# [4 8 0 0]
# state 87/472
# [4 8 0 0]
# state 88/472
# [7 5 0 0]
# state 89/472
# [6 6 0 0]
# state 90/472
# [5 7 0 0]
# state 91/472
# [5 7 0 0]
# state 92/472
# [10  2  0  0]
# state 93/472
# [7 5 0 0]
# state 94/472
# [6 6 0 0]
# state 95/472
# [6 6 0 0]
# state 96/472
# [7 5 0 0]
# state 97/472
# [8 4 0 0]
# state 98/472
# [5 7 0 0]
# state 99/472
# [5 7 0 0]
# state 100/472
# [ 2 10  0  0]
# state 101/472
# [ 2 10  0  0]
# state 102/472
# [9 3 0 0]
# state 103/472
# [8 4 0 0]
# state 104/472
# [7 5 0 0]
# state 105/472
# [6 6 0 0]
# state 106/472
# [6 6 0 0]
# state 107/472
# [6 6 0 0]
# state 108/472
# [5 7 0 0]
# state 109/472
# [7 5 0 0]
# state 110/472
# [ 1 11  0  0]
# state 111/472
# [ 1 11  0  0]
# state 112/472
# [7 5 0 0]
# state 113/472
# [7 5 0 0]
# state 114/472
# [9 3 0 0]
# state 115/472
# [6 6 0 1]
# state 116/472
# [4 8 0 0]
# state 117/472
# [4 8 0 0]
# state 118/472
# [10  2  0  0]
# state 119/472
# [4 8 0 0]
# state 120/472
# [4 8 0 0]
# state 121/472
# [3 9 0 0]
# state 122/472
# [4 8 0 0]
# state 123/472
# [7 5 0 0]
# state 124/472
# [3 9 0 0]
# state 125/472
# [3 9 0 0]
# state 126/472
# [7 5 0 0]
# state 127/472
# [6 6 0 0]
# state 128/472
# [5 7 0 0]
# state 129/472
# [5 7 0 1]
# state 130/472
# [5 7 0 0]
# state 131/472
# [5 7 0 0]
# state 132/472
# [8 4 0 0]
# state 133/472
# [6 6 0 0]
# state 134/472
# [6 6 0 0]
# state 135/472
# [5 7 0 0]
# state 136/472
# [5 7 0 0]
# state 137/472
# [7 5 0 0]
# state 138/472
# [5 7 0 0]
# state 139/472
# [5 7 0 0]
# state 140/472
# [6 6 0 0]
# state 141/472
# [6 6 0 0]
# state 142/472
# [9 3 0 0]
# state 143/472
# [9 3 0 0]
# state 144/472
# [8 4 0 0]
# state 145/472
# [6 6 0 0]
# state 146/472
# [6 6 0 0]
# state 147/472
# [7 5 0 0]
# state 148/472
# [7 5 0 0]
# state 149/472
# [6 6 0 0]
# state 150/472
# [6 6 0 0]
# state 151/472
# [6 6 0 0]
# state 152/472
# [4 8 0 0]
# state 153/472
# [4 8 0 0]
# state 154/472
# [6 6 0 0]
# state 155/472
# [5 7 0 0]
# state 156/472
# [6 6 0 0]
# state 157/472
# [8 4 0 0]
# state 158/472
# [10  2  0  0]
# state 159/472
# [7 5 0 0]
# state 160/472
# [7 5 0 0]
# state 161/472
# [7 5 0 0]
# state 162/472
# [5 7 0 0]
# state 163/472
# [4 8 0 1]
# state 164/472
# [6 6 0 0]
# state 165/472
# [8 4 0 0]
# state 166/472
# [6 6 0 0]
# state 167/472
# [5 7 0 0]
# state 168/472
# [5 7 0 0]
# state 169/472
# [10  2  0  0]
# state 170/472
# [8 4 0 0]
# state 171/472
# [7 5 0 0]
# state 172/472
# [9 3 0 0]
# state 173/472
# [9 3 0 0]
# state 174/472
# [6 6 0 0]
# state 175/472
# [6 6 0 0]
# state 176/472
# [7 5 0 0]
# state 177/472
# [7 5 0 0]
# state 178/472
# [5 7 0 0]
# state 179/472
# [5 7 0 0]
# state 180/472
# [7 5 0 0]
# state 181/472
# [6 6 0 0]
# state 182/472
# [5 7 0 0]
# state 183/472
# [5 7 0 0]
# state 184/472
# [6 6 0 0]
# state 185/472
# [6 6 0 0]
# state 186/472
# [6 6 0 0]
# state 187/472
# [ 0 12  0  0]
# state 188/472
# [ 0 12  0  0]
# state 189/472
# [9 3 0 0]
# state 190/472
# [9 3 0 0]
# state 191/472
# [9 3 0 0]
# state 192/472
# [9 3 0 0]
# state 193/472
# [9 3 0 0]
# state 194/472
# [9 3 0 0]
# state 195/472
# [8 4 0 0]
# state 196/472
# [ 1 11  0  0]
# state 197/472
# [ 1 11  0  0]
# state 198/472
# [7 5 0 0]
# state 199/472
# [9 3 0 0]
# state 200/472
# [8 4 0 0]
# state 201/472
# [7 5 0 0]
# state 202/472
# [7 5 0 0]
# state 203/472
# [6 6 0 0]
# state 204/472
# [6 6 0 0]
# state 205/472
# [6 6 0 0]
# state 206/472
# [6 6 0 0]
# state 207/472
# [9 3 0 0]
# state 208/472
# [9 3 0 0]
# state 209/472
# [10  2  0  0]
# state 210/472
# [10  2  0  0]
# state 211/472
# [5 7 0 0]
# state 212/472
# [5 7 0 0]
# state 213/472
# [8 4 0 0]
# state 214/472
# [3 9 0 0]
# state 215/472
# [3 9 0 0]
# state 216/472
# [9 3 0 0]
# state 217/472
# [9 3 0 0]
# state 218/472
# [9 3 0 0]
# state 219/472
# [ 2 10  0  0]
# state 220/472
# [ 1 11  0  1]
# state 221/472
# [7 5 0 0]
# state 222/472
# [9 3 0 0]
# state 223/472
# [9 3 0 0]
# state 224/472
# [9 3 0 0]
# state 225/472
# [6 6 0 0]
# state 226/472
# [6 6 0 0]
# state 227/472
# [9 3 0 0]
# state 228/472
# [8 4 0 0]
# state 229/472
# [6 6 0 0]
# state 230/472
# [6 6 0 0]
# state 231/472
# [7 5 0 0]
# state 232/472
# [4 8 0 0]
# state 233/472
# [4 8 0 0]
# state 234/472
# [6 6 0 0]
# state 235/472
# [6 6 0 0]
# state 236/472
# [6 6 0 0]
# state 237/472
# [9 3 0 0]
# state 238/472
# [9 3 0 0]
# state 239/472
# [9 3 0 0]
# state 240/472
# [7 5 0 0]
# state 241/472
# [6 6 0 0]
# state 242/472
# [5 7 0 0]
# state 243/472
# [3 9 0 0]
# state 244/472
# [3 9 0 0]
# state 245/472
# [7 5 0 0]
# state 246/472
# [7 5 0 0]
# state 247/472
# [7 5 0 0]
# state 248/472
# [6 6 0 0]
# state 249/472
# [5 7 0 0]
# state 250/472
# [5 7 0 0]
# state 251/472
# [9 3 0 0]
# state 252/472
# [9 3 0 0]
# state 253/472
# [ 2 10  0  0]
# state 254/472
# [ 2 10  0  0]
# state 255/472
# [7 5 0 0]
# state 256/472
# [7 5 0 0]
# state 257/472
# [4 8 0 0]
# state 258/472
# [4 8 0 0]
# state 259/472
# [9 3 0 0]
# state 260/472
# [8 4 0 0]
# state 261/472
# [ 2 10  0  0]
# state 262/472
# [ 2 10  0  0]
# state 263/472
# [9 3 0 0]
# state 264/472
# [6 6 0 0]
# state 265/472
# [6 6 0 0]
# state 266/472
# [ 2 10  0  0]
# state 267/472
# [ 1 11  0  0]
# state 268/472
# [8 4 0 0]
# state 269/472
# [6 6 0 0]
# state 270/472
# [6 6 0 0]
# state 271/472
# [5 7 0 0]
# state 272/472
# [5 7 0 0]
# state 273/472
# [9 3 0 0]
# state 274/472
# [9 3 0 0]
# state 275/472
# [8 4 0 0]
# state 276/472
# [5 7 0 0]
# state 277/472
# [5 7 0 0]
# state 278/472
# [4 8 0 0]
# state 279/472
# [4 8 0 0]
# state 280/472
# [7 5 0 0]
# state 281/472
# [5 7 0 0]
# state 282/472
# [5 7 0 0]
# state 283/472
# [9 3 0 0]
# state 284/472
# [9 3 0 0]
# state 285/472
# [7 5 0 0]
# state 286/472
# [6 6 0 0]
# state 287/472
# [5 7 0 0]
# state 288/472
# [9 3 0 0]
# state 289/472
# [9 3 0 0]
# state 290/472
# [7 5 0 0]
# state 291/472
# [6 6 0 0]
# state 292/472
# [7 5 0 0]
# state 293/472
# [8 4 0 0]
# state 294/472
# [8 4 0 0]
# state 295/472
# [7 5 0 0]
# state 296/472
# [5 7 0 0]
# state 297/472
# [4 8 0 0]
# state 298/472
# [3 9 0 0]
# state 299/472
# [8 4 0 0]
# state 300/472
# [8 4 0 0]
# state 301/472
# [6 6 0 0]
# state 302/472
# [6 6 0 1]
# state 303/472
# [4 8 0 0]
# state 304/472
# [4 8 0 0]
# state 305/472
# [5 7 0 0]
# state 306/472
# [4 8 0 0]
# state 307/472
# [7 5 0 0]
# state 308/472
# [7 5 0 1]
# state 309/472
# [8 4 0 0]
# state 310/472
# [7 5 0 1]
# state 311/472
# [4 8 0 0]
# state 312/472
# [4 8 0 0]
# state 313/472
# [7 5 0 0]
# state 314/472
# [7 5 0 0]
# state 315/472
# [7 5 0 0]
# state 316/472
# [9 3 0 0]
# state 317/472
# [7 5 0 1]
# state 318/472
# [ 2 10  0  0]
# state 319/472
# [ 2 10  0  0]
# state 320/472
# [6 6 0 0]
# state 321/472
# [10  2  0  0]
# state 322/472
# [7 5 0 0]
# state 323/472
# [5 7 0 0]
# state 324/472
# [11  1  1  0]
# state 325/472
# [6 6 0 0]
# state 326/472
# [4 8 0 0]
# state 327/472
# [4 8 0 0]
# state 328/472
# [3 9 0 0]
# state 329/472
# [3 9 0 0]
# state 330/472
# [10  2  0  0]
# state 331/472
# [6 6 0 0]
# state 332/472
# [5 7 0 0]
# state 333/472
# [4 8 0 0]
# state 334/472
# [4 8 0 0]
# state 335/472
# [9 3 0 0]
# state 336/472
# [8 4 0 0]
# state 337/472
# [5 7 0 1]
# state 338/472
# [4 8 0 1]
# state 339/472
# [4 8 0 0]
# state 340/472
# [5 7 0 0]
# state 341/472
# [6 6 0 0]
# state 342/472
# [10  2  0  0]
# state 343/472
# [6 6 0 1]
# state 344/472
# [5 7 0 0]
# state 345/472
# [6 6 0 0]
# state 346/472
# [6 6 0 0]
# state 347/472
# [7 5 0 0]
# state 348/472
# [5 7 0 0]
# state 349/472
# [5 7 0 0]
# state 350/472
# [6 6 0 0]
# state 351/472
# [8 4 0 0]
# state 352/472
# [6 6 0 0]
# state 353/472
# [6 6 0 0]
# state 354/472
# [3 9 0 0]
# state 355/472
# [ 2 10  0  0]
# state 356/472
# [ 2 10  0  0]
# state 357/472
# [ 2 10  0  0]
# state 358/472
# [5 7 0 0]
# state 359/472
# [5 7 0 0]
# state 360/472
# [6 6 0 0]
# state 361/472
# [4 8 0 0]
# state 362/472
# [3 9 0 0]
# state 363/472
# [4 8 0 0]
# state 364/472
# [4 8 0 0]
# state 365/472
# [4 8 0 0]
# state 366/472
# [7 5 0 0]
# state 367/472
# [8 4 0 0]
# state 368/472
# [6 6 0 0]
# state 369/472
# [9 3 0 0]
# state 370/472
# [7 5 0 0]
# state 371/472
# [4 8 0 0]
# state 372/472
# [ 2 10  0  0]
# state 373/472
# [10  2  0  0]
# state 374/472
# [9 3 0 0]
# state 375/472
# [9 3 0 0]
# state 376/472
# [8 4 0 0]
# state 377/472
# [7 5 0 0]
# state 378/472
# [6 6 0 0]
# state 379/472
# [6 6 0 0]
# state 380/472
# [7 5 0 0]
# state 381/472
# [7 5 0 0]
# state 382/472
# [7 5 0 0]
# state 383/472
# [7 5 0 0]
# state 384/472
# [6 6 0 0]
# state 385/472
# [7 5 0 0]
# state 386/472
# [5 7 0 0]
# state 387/472
# [6 6 0 0]
# state 388/472
# [9 3 0 0]
# state 389/472
# [7 5 0 0]
# state 390/472
# [7 5 0 0]
# state 391/472
# [6 6 0 0]
# state 392/472
# [6 6 0 0]
# state 393/472
# [7 5 0 0]
# state 394/472
# [7 5 0 0]
# state 395/472
# [ 2 10  0  0]
# state 396/472
# [4 8 0 0]
# state 397/472
# [3 9 0 0]
# state 398/472
# [9 3 0 0]
# state 399/472
# [9 3 0 0]
# state 400/472
# [8 4 0 0]
# state 401/472
# [8 4 0 0]
# state 402/472
# [9 3 0 0]
# state 403/472
# [6 6 0 0]
# state 404/472
# [6 6 0 0]
# state 405/472
# [9 3 0 0]
# state 406/472
# [9 3 0 0]
# state 407/472
# [9 3 0 0]
# state 408/472
# [9 3 0 0]
# state 409/472
# [6 6 0 0]
# state 410/472
# [7 5 0 0]
# state 411/472
# [8 4 0 0]
# state 412/472
# [6 6 0 0]
# state 413/472
# [ 2 10  0  0]
# state 414/472
# [ 1 11  0  0]
# state 415/472
# [9 3 0 0]
# state 416/472
# [10  2  0  0]
# state 417/472
# [6 6 0 0]
# state 418/472
# [6 6 0 0]
# state 419/472
# [5 7 0 0]
# state 420/472
# [5 7 0 0]
# state 421/472
# [3 9 0 0]
# state 422/472
# [ 0 12  0  0]
# state 423/472
# [ 0 12  0  0]
# state 424/472
# [10  2  0  0]
# state 425/472
# [5 7 0 0]
# state 426/472
# [4 8 0 0]
# state 427/472
# [6 6 0 0]
# state 428/472
# [8 4 0 0]
# state 429/472
# [7 5 0 0]
# state 430/472
# [5 7 0 0]
# state 431/472
# [5 7 0 0]
# state 432/472
# [6 6 0 0]
# state 433/472
# [8 4 0 0]
# state 434/472
# [8 4 0 0]
# state 435/472
# [7 5 0 0]
# state 436/472
# [ 2 10  0  0]
# state 437/472
# [ 2 10  0  0]
# state 438/472
# [3 9 0 0]
# state 439/472
# [3 9 0 1]
# state 440/472
# [6 6 0 0]
# state 441/472
# [7 5 0 0]
# state 442/472
# [9 3 0 0]
# state 443/472
# [9 3 0 0]
# state 444/472
# [8 4 0 0]
# state 445/472
# [8 4 0 0]
# state 446/472
# [5 7 0 0]
# state 447/472
# [5 7 0 0]
# state 448/472
# [5 7 0 0]
# state 449/472
# [5 7 0 0]
# state 450/472
# [6 6 0 0]
# state 451/472
# [8 4 0 0]
# state 452/472
# [8 4 0 0]
# state 453/472
# [7 5 0 0]
# state 454/472
# [7 5 0 0]
# state 455/472
# [7 5 0 0]
# state 456/472
# [7 5 0 0]
# state 457/472
# [7 5 0 0]
# state 458/472
# [7 5 0 0]
# state 459/472
# [7 5 0 0]
# state 460/472
# [7 5 0 0]
# state 461/472
# [ 2 10  0  0]
# state 462/472
# [ 2 10  0  0]
# state 463/472
# [7 5 0 0]
# state 464/472
# [6 6 0 0]
# state 465/472
# [7 5 0 0]
# state 466/472
# [5 7 0 0]
# state 467/472
# [10  2  0  0]
# state 468/472
# [9 3 0 0]
# state 469/472
# [8 4 0 0]
# state 470/472
# [5 7 0 0]
# state 471/472
# [ 2 10  0  0]
# <module 'matplotlib.pyplot' from '/Users/hectormoreno/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
visualization = Visualization("2dfire_exp3/18_12_19_09_50_39")

# %%
visualization.getFitnessGraph("0")

# %%
visualization.getFitnessGraph("1")

# %%
visualization.getFitnessGraph("2")

# %%
transformer.lmstr
# Out:
# {0: 'lambda x: (x[12] in {0} if x[12] != -1 else True) and (x[13] in {0, 2} if x[13] != -1 else True)',
#  1: 'lambda x: (x[8] in {1, 2} if x[8] != -1 else True) and (x[12] in {1} if x[12] != -1 else True)',
#  2: 'lambda x: (x[12] in {1} if x[12] != -1 else True) and (x[17] in {2} if x[17] != -1 else True)'}

# %%
exp2.world.toDict()
# Out:
# {'generation': 99,
#  'populations': [{'generation': 99,
#    'goal': '0',
#    'chromosomes': [{'uuid': '69864558-f3a0-41fa-b837-91d64974b952',
#      'generation': 95,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['a485cef6-0869-408f-8601-d9cbcac30fae',
#       'a485cef6-0869-408f-8601-d9cbcac30fae']},
#     {'uuid': '182f4b4e-87bb-4751-b0ba-3f156dd5a6fd',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{0, -1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '7486.437653846154',
#      'parents': ['4bcd7154-bb7c-4af8-a230-286a6a428c8f',
#       '69864558-f3a0-41fa-b837-91d64974b952']},
#     {'uuid': '482d63f0-7313-4b18-8682-081f2061ce97',
#      'generation': 92,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': '{0}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{0, -1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '6731.394871794457',
#      'parents': ['59925098-05ee-4771-af15-ea2ed6b9d4a8',
#       'f20a68f8-87a5-4e9f-afbd-482d8950c66a']},
#     {'uuid': '5185e8d8-8f45-4c1d-b3ed-538ab3811685',
#      'generation': 96,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '8885.048290598605',
#      'parents': ['88f74373-0441-4885-b8e9-7d425e76fcc0',
#       '69864558-f3a0-41fa-b837-91d64974b952']},
#     {'uuid': 'e9afd745-9726-4bce-9728-f0656764555e',
#      'generation': 95,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '8885.048290598605',
#      'parents': ['50f25052-f8e8-4ec9-928f-965511d569d3',
#       'a485cef6-0869-408f-8601-d9cbcac30fae']},
#     {'uuid': '91612b63-7105-4926-ad83-9047f8bc4ca2',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['6795e1da-4c8d-43d6-84a1-e70e83d83311',
#       'c87f3ec5-2f80-4331-896f-539320a97a3e']},
#     {'uuid': 'd1b07e71-5a51-4bc5-99b1-4e097272ef71',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': '{0}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '10108.858307692593',
#      'parents': ['6795e1da-4c8d-43d6-84a1-e70e83d83311',
#       'c87f3ec5-2f80-4331-896f-539320a97a3e']},
#     {'uuid': '81268ffc-2218-4eaf-835c-c51d9fc21908',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '8885.048290598605',
#      'parents': ['5185e8d8-8f45-4c1d-b3ed-538ab3811685',
#       '5185e8d8-8f45-4c1d-b3ed-538ab3811685']},
#     {'uuid': 'b4203eb7-13f4-4996-b9c0-53500c103b7a',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['91612b63-7105-4926-ad83-9047f8bc4ca2',
#       '6795e1da-4c8d-43d6-84a1-e70e83d83311']},
#     {'uuid': 'f97fccb4-32e8-43ca-9915-ab79656068d6',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{-1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{-1}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '13307.67558974359',
#      'parents': ['d1b07e71-5a51-4bc5-99b1-4e097272ef71',
#       '91612b63-7105-4926-ad83-9047f8bc4ca2']},
#     {'uuid': '70eeebe3-9bcb-429f-9eaf-dd27126cac75',
#      'generation': 91,
#      'genes': [{'identifier': '0', 'value': 'set()'},
#       {'identifier': '1', 'value': '{0}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{-1}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': '{0, 2}'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{0}'},
#       {'identifier': '13', 'value': '{0, -1}'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': '{2, -1}'},
#       {'identifier': '18', 'value': '{-1}'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '6731.394871794457',
#      'parents': ['c1dbfea8-c450-48eb-b01a-d0a266836985',
#       'aa5e8f39-82cd-4755-b6b6-fed4e1436cea']}],
#    'best': 13307.67558974359,
#    'average': 10085.812085081621,
#    'median': 10108.858307692593,
#    'std': 2613.0551099648296},
#   {'generation': 99,
#    'goal': '1',
#    'chromosomes': [{'uuid': '0f84120e-a534-4252-a4ac-89af40e49a1d',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['cc5b7e32-cef8-400e-9ec2-8f790824549a',
#       'c2c934b8-e298-43e4-aaee-350d52255e73']},
#     {'uuid': '99204fcb-79d5-416c-8924-5bbb95956610',
#      'generation': 96,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['c2c934b8-e298-43e4-aaee-350d52255e73',
#       '458a8c45-27a7-4a3e-98d7-324057c58065']},
#     {'uuid': '7d81459a-fb85-4de1-8493-21afe3a5ca42',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['0f84120e-a534-4252-a4ac-89af40e49a1d',
#       '0f84120e-a534-4252-a4ac-89af40e49a1d']},
#     {'uuid': 'c4eee5ec-98bd-426c-aa5c-d757a3e49c8e',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['00ec00a2-2d27-4c22-ba95-9f7195fc31d6',
#       '00ec00a2-2d27-4c22-ba95-9f7195fc31d6']},
#     {'uuid': 'e5c6d47b-b38d-4fa6-a572-aa6b396fa804',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['146612d3-1e53-4695-b21d-e500863ae5ae',
#       'cc5b7e32-cef8-400e-9ec2-8f790824549a']},
#     {'uuid': 'b41ba72f-6739-48f9-aff6-6fe6696c41b9',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['e5c6d47b-b38d-4fa6-a572-aa6b396fa804',
#       '0f84120e-a534-4252-a4ac-89af40e49a1d']},
#     {'uuid': '00ec00a2-2d27-4c22-ba95-9f7195fc31d6',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['0f84120e-a534-4252-a4ac-89af40e49a1d',
#       '50808483-b942-4941-b778-366292302f00']},
#     {'uuid': '418b2a63-cc3d-4414-bbaf-0fee52ca6d54',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': 'set()'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['e5c6d47b-b38d-4fa6-a572-aa6b396fa804',
#       '00ec00a2-2d27-4c22-ba95-9f7195fc31d6']},
#     {'uuid': 'de13735e-09e5-4f58-9146-342b7d3942b0',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': '{-1}'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6815.082687179489',
#      'parents': ['0f84120e-a534-4252-a4ac-89af40e49a1d',
#       '99204fcb-79d5-416c-8924-5bbb95956610']},
#     {'uuid': '9124a335-d7d4-472b-8493-c1519b6b24b9',
#      'generation': 90,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['458a8c45-27a7-4a3e-98d7-324057c58065',
#       'e4004a24-4442-4d22-b15e-e1819601fee0']},
#     {'uuid': 'cc5b7e32-cef8-400e-9ec2-8f790824549a',
#      'generation': 95,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{1, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': '{-1}'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': '{-1}'},
#       {'identifier': '8', 'value': '{1}'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': 'set()'},
#       {'identifier': '11', 'value': 'set()'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{-1}'},
#       {'identifier': '16', 'value': '{-1}'},
#       {'identifier': '17', 'value': 'set()'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': 'set()'},
#       {'identifier': '21', 'value': '{1, 2}'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': '{1, -1}'},
#       {'identifier': '24', 'value': 'set()'}],
#      'fitness': '6802.002434871851',
#      'parents': ['c2c934b8-e298-43e4-aaee-350d52255e73',
#       '458a8c45-27a7-4a3e-98d7-324057c58065']}],
#    'best': 6815.082687179489,
#    'average': 6810.326231794892,
#    'median': 6815.082687179489,
#    'std': 6.2921990349071395},
#   {'generation': 99,
#    'goal': '2',
#    'chromosomes': [{'uuid': '11e2e040-f2ff-4f73-8e01-73b08dc3b406',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{-1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '128.6118153846142',
#      'parents': ['a97eaa26-f4bd-4937-b868-996df2de2f24',
#       '6fa73d44-c4da-4e60-841a-18eb06130d46']},
#     {'uuid': '2af10dd6-a0a5-4fe5-9a16-fa4f0f052489',
#      'generation': 96,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['29c7d8c6-d3c6-4e56-9925-bbd67d72db08',
#       '0020e50a-3d28-4008-80ef-2585cb54d9de']},
#     {'uuid': '1b808a0d-43c5-4a4e-b0f8-e7562f0a0059',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['29c7d8c6-d3c6-4e56-9925-bbd67d72db08',
#       '29c7d8c6-d3c6-4e56-9925-bbd67d72db08']},
#     {'uuid': 'a62025f2-396d-4e9f-b10a-77b4873ef7a3',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['a97eaa26-f4bd-4937-b868-996df2de2f24',
#       'a1655faa-8a18-4c1f-bfe9-6ba4e3a9e157']},
#     {'uuid': '0020e50a-3d28-4008-80ef-2585cb54d9de',
#      'generation': 94,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['d2b799c5-aaca-4643-a0ae-1be6ad7b7046',
#       'f9f62411-0875-4e99-828e-2c63a467853d']},
#     {'uuid': '50534519-f864-4d9b-9a39-2732a693dcac',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['6fa73d44-c4da-4e60-841a-18eb06130d46',
#       '1b808a0d-43c5-4a4e-b0f8-e7562f0a0059']},
#     {'uuid': '3ef8c179-4e7b-45c9-a560-92e67b6f9553',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['222beea4-7336-4b23-a364-a4b5c091197b',
#       'a62025f2-396d-4e9f-b10a-77b4873ef7a3']},
#     {'uuid': '42551751-965e-4bba-9847-4e11aada2fba',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['9cdbc0e8-81ed-41e5-acee-b4c2346437f7',
#       '222beea4-7336-4b23-a364-a4b5c091197b']},
#     {'uuid': '0a474c7f-76a0-4c50-81c9-302eccb12ede',
#      'generation': 99,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': 'set()'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['a62025f2-396d-4e9f-b10a-77b4873ef7a3',
#       '2af10dd6-a0a5-4fe5-9a16-fa4f0f052489']},
#     {'uuid': '6fa73d44-c4da-4e60-841a-18eb06130d46',
#      'generation': 98,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['0020e50a-3d28-4008-80ef-2585cb54d9de',
#       'e7096c06-3508-4283-8320-3db9a2a37eab']},
#     {'uuid': '62924ebe-da60-4c04-a600-f483c6398202',
#      'generation': 97,
#      'genes': [{'identifier': '0', 'value': '{-1}'},
#       {'identifier': '1', 'value': '{-1}'},
#       {'identifier': '2', 'value': 'set()'},
#       {'identifier': '3', 'value': '{0, 2}'},
#       {'identifier': '4', 'value': 'set()'},
#       {'identifier': '5', 'value': 'set()'},
#       {'identifier': '6', 'value': 'set()'},
#       {'identifier': '7', 'value': 'set()'},
#       {'identifier': '8', 'value': 'set()'},
#       {'identifier': '9', 'value': 'set()'},
#       {'identifier': '10', 'value': '{0, -1}'},
#       {'identifier': '11', 'value': '{2}'},
#       {'identifier': '12', 'value': '{1}'},
#       {'identifier': '13', 'value': 'set()'},
#       {'identifier': '14', 'value': 'set()'},
#       {'identifier': '15', 'value': '{0, 2}'},
#       {'identifier': '16', 'value': 'set()'},
#       {'identifier': '17', 'value': '{2}'},
#       {'identifier': '18', 'value': 'set()'},
#       {'identifier': '19', 'value': 'set()'},
#       {'identifier': '20', 'value': '{0}'},
#       {'identifier': '21', 'value': 'set()'},
#       {'identifier': '22', 'value': 'set()'},
#       {'identifier': '23', 'value': 'set()'},
#       {'identifier': '24', 'value': '{-1}'}],
#      'fitness': '126.40929523809551',
#      'parents': ['6371dc9c-abf5-4d61-8919-bd592e82aea4',
#       '29c7d8c6-d3c6-4e56-9925-bbd67d72db08']}],
#    'best': 128.6118153846142,
#    'average': 126.60952434232446,
#    'median': 126.40929523809551,
#    'std': 0.6331800232188045}]}

# %%
import sys
del sys.modules["ExperimentBase"]
